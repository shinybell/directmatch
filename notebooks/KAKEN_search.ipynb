# %%
import requests
from pprint import pprint
import xml.etree.ElementTree as ET

def make_request(url, method='GET', data=None, headers=None):

    if headers is None:
        headers = {}

    if method.upper() == 'GET':
        response = requests.get(url, headers=headers)
    elif method.upper() == 'POST':
        response = requests.post(url, data=data, headers=headers)
    else:
        raise ValueError("Unsupported HTTP method: {}".format(method))

    return response


# https://nrid.nii.ac.jp/opensearch/?(パラメータ=値)& (パラメータ=値)&…&(パラメータ=値)
def build_url(base_url, **params):
    query_string = '&'.join(f"{key}={value}" for key, value in params.items())
    return f"{base_url}?{query_string}" if query_string else base_url

def fetch_data(base_url, **params):
    url = build_url(base_url, **params)
    response = make_request(url)

    if response.status_code == 200:
        return response
    else:
        response.raise_for_status()  # Raise an error for bad responses

def parse_xml_response(xml_content):
    """XMLレスポンスをパースしてPythonオブジェクトに変換する"""
    root = ET.fromstring(xml_content)
    return root

# メインロジックを実行
base_url = "https://nrid.nii.ac.jp/opensearch/"
params = {
    'kw': 'ディープラーニング',
    'appid': 'gu782hFEjCChFcYxyeb9'
}

data = fetch_data(base_url, **params)

# レスポンスの内容を確認
print("レスポンスのContent-Type:", data.headers.get('Content-Type'))
print("レスポンスの先頭1000文字:")
print(data._content[:1000])

try:
    # XMLとして解析を試みる
    xml_root = parse_xml_response(data._content)
    print("XMLとしての解析に成功")
except ET.ParseError as e:
    print(f"XMLとしての解析に失敗: {e}")

    # UTF-8でデコードしてから解析を試みる
    try:
        xml_content_decoded = data._content.decode('utf-8')
        xml_root = parse_xml_response(xml_content_decoded)
        print("デコード後のXMLとしての解析に成功")
    except Exception as e:
        print(f"デコード後の解析にも失敗: {e}")
else:
    # XMLの内容を表示
    print("XMLのルートタグ:", xml_root.tag)
    print("XMLのルート属性:", xml_root.attrib)
# Out:
# レスポンスのContent-Type: text/html; charset=UTF-8
# レスポンスの先頭1000文字:
# b'<!DOCTYPE html>\n<html>\n  <head>\n   \n    <!-- meta -->\n    <meta charset="UTF-8">\n    <meta http-equiv="Pragma" content="no-cache" />\n    <meta http-equiv="Cache-Control" content="no-cache" />\n    <meta http-equiv="Cache-Control" content="no-store" />\n    <meta http-equiv="Cache-Control" content="must-revalidate" />\n    <meta http-equiv="Expires" content="0" />\n    \n    <meta name="ROBOTS" content="NONE" />\n    <meta name="ROBOTS" content="NOINDEX,NOFOLLOW" />\n    <meta name="ROBOTS" content="NOARCHIVE" />\n    \n    <link rel="shortcut icon" href="/static/images/favicon_kakenhi.ico" type="image/vnd.microsoft.ico" />\n    <link rel="icon" href="/static/images/favicon_kakenhi.ico" type="image/vnd.microsoft.ico" />\n    <!-- Bootstrap core CSS -->\n    <link id="switch_style" href="/static/css/bootstrap-modal.css?1691548633" rel="stylesheet" />\n    <!-- Custom styles for this template -->\n    <link href="/static/css/chosentree.css?1697515897" rel="stylesheet" />\n\t<link href="/static/css/treese'
# XMLとしての解析に失敗: mismatched tag: line 46, column 5
# デコード後の解析にも失敗: mismatched tag: line 46, column 5

# %%
pprint(data._content)
# xmlとして保存
with open('response.xml', 'wb') as f:
    f.write(data._content)
# Out:
# (b'<!DOCTYPE html>\n<html>\n  <head>\n   \n    <!-- meta -->\n    <meta char'
#  b'set="UTF-8">\n    <meta http-equiv="Pragma" content="no-cache" />\n    <me'
#  b'ta http-equiv="Cache-Control" content="no-cache" />\n    <meta http-equiv'
#  b'="Cache-Control" content="no-store" />\n    <meta http-equiv="Cache-Contr'
#  b'ol" content="must-revalidate" />\n    <meta http-equiv="Expires" content='
#  b'"0" />\n    \n    <meta name="ROBOTS" content="NONE" />\n    <meta name="RO'
#  b'BOTS" content="NOINDEX,NOFOLLOW" />\n    <meta name="ROBOTS" content="NOA'
#  b'RCHIVE" />\n    \n    <link rel="shortcut icon" href="/static/images/favic'
#  b'on_kakenhi.ico" type="image/vnd.microsoft.ico" />\n    <link rel="icon" h'
#  b'ref="/static/images/favicon_kakenhi.ico" type="image/vnd.microsoft.ico" '
#  b'/>\n    <!-- Bootstrap core CSS -->\n    <link id="switch_style" href="/st'
#  b'atic/css/bootstrap-modal.css?1691548633" rel="stylesheet" />\n    <!-- Cu'
#  b'stom styles for this template -->\n    <link href="/static/css/chosentree'
#  b'.css?1697515897" rel="stylesheet" />\n\t<link href="/static/css/treeselect'
#  b'.css?1697515897" rel="stylesheet" />\n    <link href="/static/css/cinii.c'
#  b'ss?1735186047" rel="stylesheet" />\n    <link href="/static/css/dropzone.'
#  b'css?1691548633" rel="stylesheet" />\n    <link href="/static/css/font-awe'
#  b'some.css?1691548633" rel="stylesheet" />\n    <link href="/static/css/jqu'
#  b'ery-ui.min.css?1691548633" rel="stylesheet" />\n    <link href="/static/c'
#  b'ss/box-flex.css?1691548633" rel="stylesheet" />\n    <!-- HTML5 shim and '
#  b'Respond.js IE8 support of HTML5 elements and media queries -->\n    <!--['
#  b'if lt IE 9]>\n    <script type="text/javascript" src="/static/js/html5shi'
#  b'v.js?1691548633"></script>\n    <script type="text/javascript" src="/stat'
#  b'ic/js/respond.min.js?1691548634"></script>\n    <![endif]-->\n    <script '
#  b'nonce="UmqelrVo1EH9Wpt8lOoHoA==" type="text/javascript">\n    //<![CDATA['
#  b'\n    var static_url="/static/";\n    var fault_mode="False";\n    //]]'
#  b">\n\n    if(navigator.userAgent.match(/(iPad)/)){\n        document.write('"
#  b'<meta name="viewport" content="width=980">\');\n    }\n    else{\n        do'
#  b'cument.write(\'<meta name="viewport" content="width=device-width">\');\n   '
#  b' }\n   </script>\n    <script type="text/javascript" src="/static/js/jquer'
#  b'y.min.js?1691548633"></script>\n    <script type="text/javascript" src="/'
#  b'static/js/common.js?1691548633"></script>\n\n    <!-- <script type="text/j'
#  b'avascript" src="/static/js/changeDisplayMode.js?1691548633"></script>\n -'
#  b'->\n    <script type="text/javascript" src="/static/js/jquery-ui.min.js?1'
#  b'691548633"></script>\n    <script type="text/javascript" src="/static/js/'
#  b'search.js?1728349713"></script>\n    <!--[if IE 8.0]>\n      <link href="/'
#  b'static/css/cinii-ie8.css?1691548633" rel="stylesheet" type="text/css" />'
#  b'\n    <![endif]-->\n  <title>KAKEN &mdash; \xe7\xa0\x94\xe7\xa9\xb6\xe8'
#  b'\x80\x85\xe3\x82\x92\xe3\x81\x95\xe3\x81\x8c\xe3\x81\x99 | \xe3\x83\x87'
#  b'\xe3\x82\xa3\xe3\x83\xbc\xe3\x83\x97\xe3\x83\xa9\xe3\x83\xbc\xe3'
#  b'\x83\x8b\xe3\x83\xb3\xe3\x82\xb0</title>\n  </head>\n  <body class="kakenh'
#  b'i grants topscreen with_sidenavi ja">\n  \n\n<div id="content">\n  <form id='
#  b'"search" method="post" action="." autoclass="form-signin" class="form-vertic'
#  b'al"><input type=\'hidden\' name=\'csrfmiddlewaretoken\' value=\'Gj7PCVVp9'
#  b"oUCyCwjuJywkT9FVXiAHUjkDfyyYnRUtyYrEolso94l0fryKiGTrJnR' />\n  <input typ"
#  b'e="hidden" name="lang" id="lang" value="ja" />\n  <input type="hidden" na'
#  b'me="url_lang" id="url_lang" value="" />\n    <nav class="navbar navbar-he'
#  b'ader">\n      <div class="navbar-topcontent">\n        <!--\xe3\x83\x96'
#  b'\xe3\x83\xa9\xe3\x83\xb3\xe3\x83\x89\xe5\x90\x8d \xe3\x83\xad'
#  b'\xe3\x82\xb4\xe5\x90\x8d\xe3\x81\xae\xe8\xa1\xa8\xe7\xa4\xba-->\n        <'
#  b'a href="/index/" class="navbar-brand headerlogo"></a>\n        <!--\xe3\x83'
#  b'\x88\xe3\x82\xb0\xe3\x83\xab\xe3\x83\x9c\xe3\x82\xbf\xe3\x83\xb3'
#  b'\xe3\x81\xae\xe8\xa8\xad\xe7\xbd\xae-->\n        <button class="navbar-toggl'
#  b'er button-menu collapsed" type="button" data-bs-toggle="collapse" data-bs-ta'
#  b'rget="#nav-content" aria-controls="nav-content" aria-expanded="false" aria-l'
#  b'abel="\xe3\x83\xa1\xe3\x83\x8b\xe3\x83\xa5\xe3\x83\xbc">\n          <span'
#  b' class="navbar-toggler-icon"></span>\n        </button>\n        <button t'
#  b'ype="button" class="navbar-toggler button-search collapsed" data-bs-toggle="'
#  b'collapse" data-bs-target="#searchbox">\n          \xe6\xa4\x9c\xe7\xb4\xa2\n'
#  b'        </button>\n        <div id="nav-content" class="collapse navbar-c'
#  b'ollapse headermenu">\n        <ul class="nav navbar-nav menu-service-list'
#  b' btn-group">\n        \xe3\x80\x80<li><a href="/index/">\xe7\xa0'
#  b'\x94\xe7\xa9\xb6\xe8\xaa\xb2\xe9\xa1\x8c\xe3\x82\x92\xe3\x81\x95'
#  b'\xe3\x81\x8c\xe3\x81\x99</a></li>\n          <li class="active"><a href="/i'
#  b'ndex/">\xe7\xa0\x94\xe7\xa9\xb6\xe8\x80\x85\xe3\x82\x92\xe3\x81\x95\xe3\x81'
#  b'\x8c\xe3\x81\x99</a></li>\n          </ul>\n          <ul class="nav navba'
#  b'r-nav menu-kaken-use-list btn-group">\n            <li><a href="/" target'
#  b'="_blank">KAKEN\xe3\x81\xae\xe4\xbd\xbf\xe3\x81\x84\xe6\x96\xb9</a></li>'
#  b'\n          </ul>\n          <ul class="nav navbar-nav menu-utility-list b'
#  b'tn-group">\n            \n                <li class="menu-utility-item">\n '
#  b'                 <select class="form-control" name="langChange" id="langChan'
#  b'ge">\n                  \n                    <option value="ja" selected='
#  b'"selected">\xe6\x97\xa5\xe6\x9c\xac\xe8\xaa\x9e</option>\n                  '
#  b'\n                    <option value="en">\xe8\x8b\xb1\xe8\xaa\x9e</option>\n'
#  b'                  \n                  </select>\n                </li>\n   '
#  b'         \n          </ul>\n        </div>\n      </div>\n    </nav>\n  \n'
#  b'\n<div class="container body-wrap">\n\n<div id="searchbox" class="searchbox'
#  b' lower-page">\n  <div class="kakenhi_search">\n    <div class="searchformc'
#  b'ontents container-fluid">\n      <div class="searchboxheader col-xs-12 co'
#  b'l-sm-3">\n        <div class="col-xs-12 col-sm-12">\n        </div>\n      '
#  b'</div>\n      <div class="form-tabcontent form-kakenhi col-xs-12 col-sm-9'
#  b'">\n        <div class="col-xs-12 col-sm-6">\n          <div class="row ro'
#  b'w-textform">\n            <div class="col-xs-9 col-sm-9 col-form">\n      '
#  b'        <input id="text_kywd_0" name="kw" type="text" class="main_srchterm s'
#  b'earchforminput input_simple" placeholder="\xe3\x83\x95\xe3\x83\xaa'
#  b'\xe3\x83\xbc\xe3\x83\xaf\xe3\x83\xbc\xe3\x83\x89" value="\xe3\x83\x87'
#  b'\xe3\x82\xa3\xe3\x83\xbc\xe3\x83\x97\xe3\x83\xa9\xe3\x83\xbc\xe3'
#  b'\x83\x8b\xe3\x83\xb3\xe3\x82\xb0" />\n            </div>\n            <div'
#  b' class="col-xs-3 col-sm-3">\n              <input type="button" class="bt'
#  b'n searchbtn" id="search_simple" value="\xe6\xa4\x9c\xe7\xb4\xa2" />\n      '
#  b'      </div>\n          </div>\n        </div>\n        <div class="col-xs-'
#  b'12 col-sm-6 fulltext-area">\n          <div class="col-sm-11 col-sm-offse'
#  b't-1">\n\n              <a class="link-page underline link_pointer" id="sea'
#  b'rchAdvanced"><i class="fa fa-chevron-right"></i> \xe8\xa9\xb3'
#  b'\xe7\xb4\xb0\xe6\xa4\x9c\xe7\xb4\xa2</a>\n          </div>\n        </div'
#  b'>\n      </div>\n    </div>\n  </div>\n</div>\n\n  <div id="results">\n    '
#  b'<div id="result-wrapper">\n      <div class="container">\n          \n     '
#  b'     <p><a class="collapse-facet-toggle collapsed" data-bs-toggle="collapse"'
#  b' href="#collapse-facet">\xe7\xb5\x9e\xe3\x82\x8a\xe8\xbe\xbc\xe3\x81\xbf'
#  b'\xe6\x9d\xa1\xe4\xbb\xb6</a></p>\n          <div id="collapse-facet" class='
#  b'"panel-collapse collapse">\n            <div id="facet-wrapper">\n        '
#  b'      <div class="facet">\n              <div class="sidebar">\n<div class'
#  b'="facet-title hidden-xs"><i class="fa fa-filter"></i> \xe7\xb5'
#  b'\x9e\xe3\x82\x8a\xe8\xbe\xbc\xe3\x81\xbf</div>\n\n\n<div class="panel-def'
#  b'ault" id="facet_im">\n  <h3>\xe7\xa0\x94\xe7\xa9\xb6\xe6\x9c\x9f'
#  b'\xe9\x96\x93</h3>\n  <div class="panel-body award-year">\n    <div id="char'
#  b't_im"></div>\n    <div id="slider-wrap_im">\n      <div id="slider_im"></d'
#  b'iv>\n      <div class="form-inline">\n        <div class="form-group"><inp'
#  b'ut type="text" id="startYear_im" class="form-control" maxlength="4"></div> -'
#  b' <div class="form-group"><input type="text" id="endYear_im" class="form-cont'
#  b'rol" maxlength="4"></div>\n        <div class="form-group">\n          <in'
#  b'put type="button" class="btn btn-sm btn-default update year_search" id="year'
#  b'_search_im" value="&#xf021;" />\n          <input type="button" class="bt'
#  b'n btn-sm btn-default clear year_clear" id="year_clear_im" value='
#  b'"\xe3\x82\xaf\xe3\x83\xaa\xe3\x82\xa2" />\n        </div>\n      </div>\n '
#  b'   </div>\n  </div>\n</div>\n\n\n\n<div class="panel-default" id="facet_py'
#  b'">\n  <h3>\xe6\x88\x90\xe6\x9e\x9c\xe7\x89\xa9\xe3\x81\xae\xe5\x87\xba'
#  b'\xe7\x89\x88\xe5\xb9\xb4</h3>\n  <div class="panel-body award-year">\n    <d'
#  b'iv id="chart_py"></div>\n    <div id="slider-wrap_py">\n      <div id="sli'
#  b'der_py"></div>\n      <div class="form-inline">\n        <div class="form-'
#  b'group"><input type="text" id="startYear_py" class="form-control" maxlength="'
#  b'4"></div> - <div class="form-group"><input type="text" id="endYear_py" class'
#  b'="form-control" maxlength="4"></div>\n        <div class="form-group">\n  '
#  b'        <input type="button" class="btn btn-sm btn-default update year_searc'
#  b'h" id="year_search_py" value="&#xf021;" />\n          <input type="button'
#  b'" class="btn btn-sm btn-default clear year_clear" id="year_clear_py" value="'
#  b'\xe3\x82\xaf\xe3\x83\xaa\xe3\x82\xa2" />\n        </div>\n      </div>\n  '
#  b'  </div>\n  </div>\n</div>\n\n\n\n <div class="panel panel-default" id="fa'
#  b'cet_in"></div><!-- panel panel-default -->\n <script nonce="UmqelrVo1EH9W'
#  b'pt8lOoHoA==" type="text/javascript">\n  get_facet_data(\'in\');\n </scri'
#  b'pt>\n\n\n\n <div class="panel panel-default" id="facet_dp"></div><!-- panel '
#  b'panel-default -->\n <script nonce="UmqelrVo1EH9Wpt8lOoHoA==" type="text/j'
#  b'avascript">\n  get_facet_data(\'dp\');\n </script>\n\n\n\n <div class="panel'
#  b' panel-default" id="facet_jb"></div><!-- panel panel-default -->\n <scrip'
#  b't nonce="UmqelrVo1EH9Wpt8lOoHoA==" type="text/javascript">\n  get_facet_d'
#  b'ata(\'jb\');\n </script>\n\n\n\n <div class="panel panel-default" id="facet'
#  b'_kw"></div><!-- panel panel-default -->\n <script nonce="UmqelrVo1EH9Wpt8'
#  b'lOoHoA==" type="text/javascript">\n  get_facet_data(\'kw\');\n </script>'
#  b'\n\n\n\n <div class="panel panel-default" id="facet_pj"></div><!-- panel pan'
#  b'el-default -->\n <script nonce="UmqelrVo1EH9Wpt8lOoHoA==" type="text/java'
#  b'script">\n  get_facet_data(\'pj\');\n </script>\n\n\n\n <div class="panel pa'
#  b'nel-default" id="facet_pr"></div><!-- panel panel-default -->\n <script n'
#  b'once="UmqelrVo1EH9Wpt8lOoHoA==" type="text/javascript">\n  get_facet_data'
#  b'(\'pr\');\n </script>\n\n\n<script type="text/javascript" src="/static/js/'
#  b'd3.min.js?1691548633"></script>\n<script nonce="UmqelrVo1EH9Wpt8lOoHoA=="'
#  b' type="text/javascript">\n\nvar margin_im = {top: 10, right: 5, bottom: 0,'
#  b' left: 5},\n    width_im = 255 - margin_im.left - margin_im.right,\n    he'
#  b'ight_im = 80 - margin_im.top - margin_im.bottom;\n\nvar bisectYear_im = d3'
#  b'.bisector(function(d) { return d.year; }).left;\n\nvar x_im = d3.scale.lin'
#  b'ear()\n    .range([0, width_im]);\n\nvar y_im = d3.scale.linear()\n    .rang'
#  b'e([height_im, 0]);\n\nvar xAxis_im = d3.svg.axis()\n    .scale(x_im)\n    .o'
#  b'rient("bottom");\n\nvar yAxis_im = d3.svg.axis()\n    .scale(y_im)\n    .ori'
#  b'ent("left");\n\nvar line_im = d3.svg.line()\n    .x(function(d) { return x_'
#  b'im(d.year); })\n    .y(function(d) { return y_im(d.value); });\n\nvar area_'
#  b'im = d3.svg.area()\n    .x(function(d) { return x_im(d.year); })\n    .y0('
#  b'height_im)\n    .y1(function(d) { return y_im(d.value); });\n\nvar tooltip_'
#  b'im = d3.select("#chart_im").append("div")\n    .attr("class", "tooltip")\n'
#  b'    .style("opacity", 1e-6);\n\nvar svg_im = d3.select("#chart_im").append'
#  b'("svg")\n    .attr("width", width_im + margin_im.left + margin_im.right)\n'
#  b'    .attr("height", height_im + margin_im.top + margin_im.bottom)\n    .a'
#  b'ppend("g")\n    .attr("transform", "translate(" + margin_im.left + "," + '
#  b'margin_im.top + ")");\n\nvar cur_url_im = location.pathname;\nif (cur_url_i'
#  b'm.indexOf("/search") > -1) {\n    cur_url_im = cur_url_im.replace(/\\/sear'
#  b'ch/, "/year/im");\n    if (cur_url_im.slice(-1) != "/") {\n\t    cur_url_im'
#  b' += "/";\n\t}\n    cur_url_im += location.search;\n}\nif (cur_url_im.inde'
#  b'xOf("/") < 0) {\n    cur_url_im = "/" + cur_url_im;\n}\n\nd3.json(cur_url_im'
#  b', function(error, data) {\n\tif (data == "-1") {\n\t\t$("#facet_im").addC'
#  b'lass("hide");\n\t\treturn false;\n\t}\n    data.forEach(function(d) {\n    '
#  b'  d.year = d.year;\n      d.value = +d.value;\n    });\n\n    data.sort(func'
#  b'tion(a, b) {\n      return a.year - b.year;\n    });\n\n    x_im.domain([dat'
#  b'a[0].year, data[data.length - 1].year]);\n    y_im.domain([0, d3.max(data'
#  b', function(d) { return d.value; })]);\n\n\n    var clip = svg_im.append("de'
#  b'fs").append("svg:clipPath")\n        .attr("id", "clip")\n        .append('
#  b'"svg:rect")\n        .attr("id", "clip-rect")\n        .attr("x", "0")\n   '
#  b'     .attr("y", "0")\n        .attr("width", width_im)\n        .attr("hei'
#  b'ght", height_im);\n\n\n    svg_im.append("path")\n        .datum(data)\n '
#  b'       .attr("class", "line")\n        .attr("clip-path", "url(#clip)")\n '
#  b'       .attr("d", line_im);\n\n    svg_im.append("path")\n        .datum(da'
#  b'ta)\n        .attr("class", "area")\n        .attr("clip-path", "url(#clip'
#  b')")\n        .attr("d", area_im);\n\n    var focus_im = svg_im.append("g")\n'
#  b'        .attr("class", "focus")\n        .style("display", "none");\n\n    '
#  b'focus_im.append("circle")\n        .attr("r", 4.5);\n\n    svg_im.append("r'
#  b'ect")\n        .attr("class", "overlay")\n        .attr("width", width_im)'
#  b'\n        .attr("height", height_im)\n        .on("mouseover", function() '
#  b'{\n          focus_im.style("display", null);\n          tooltip_im.transi'
#  b'tion()\n          .duration(500)\n          .style("opacity", 1);\n        '
#  b'})\n        .on("mouseout", function() {\n          focus_im.style("displa'
#  b'y", "none");\n          tooltip_im.transition()\n          .duration(500)\n'
#  b'          .style("opacity", 1e-6);\n        })\n        .on("mousemove", m'
#  b'ousemove_im);\n\n    function mousemove_im() {\n      var x0 = x_im.invert('
#  b'd3.mouse(this)[0]),\n          i = bisectYear_im(data, x0, 1);\n\n      var'
#  b' d0, d1, d_im;\n      d0 = data[i - 1];\n      if (data.length > i) {\n    '
#  b'    d1 = data[i];\n        d_im = x0 - d0.year > d1.year - x0 ? d1 : d0;\n'
#  b'      } else {\n      \td_im = d0;\n      }\n      focus_im.attr("transform"'
#  b', "translate(" + x_im(d_im.year) + "," + y_im(d_im.value) + ")");\n\n     '
#  b' tooltip_im.text(d_im.year + "(" + d_im.value + ")")\n      .style("left"'
#  b', x_im(d_im.year) + "px")\n      .style("top", y_im(d_im.value) - 25 + "p'
#  b'x");\n    }\n});\n\nvar margin_py = {top: 10, right: 5, bottom: 0, left: 5},'
#  b'\n    width_py = 255 - margin_py.left - margin_py.right,\n    height_py = '
#  b'80 - margin_py.top - margin_py.bottom;\n\nvar bisectYear_py = d3.bisector('
#  b'function(d) { return d.year; }).left;\n\nvar x_py = d3.scale.linear()\n    '
#  b'.range([0, width_py]);\n\nvar y_py = d3.scale.linear()\n    .range([height_'
#  b'py, 0]);\n\nvar xAxis_py = d3.svg.axis()\n    .scale(x_py)\n    .orient("bot'
#  b'tom");\n\nvar yAxis_py = d3.svg.axis()\n    .scale(y_py)\n    .orient("left"'
#  b');\n\nvar line_py = d3.svg.line()\n    .x(function(d) { return x_py(d.year)'
#  b'; })\n    .y(function(d) { return y_py(d.value); });\n\nvar area_py = d3.sv'
#  b'g.area()\n    .x(function(d) { return x_py(d.year); })\n    .y0(height_py)'
#  b'\n    .y1(function(d) { return y_py(d.value); });\n\nvar tooltip_py = d3.se'
#  b'lect("#chart_py").append("div")\n    .attr("class", "tooltip")\n    .style'
#  b'("opacity", 1e-6);\n\nvar svg_py = d3.select("#chart_py").append("svg")\n  '
#  b'  .attr("width", width_py + margin_py.left + margin_py.right)\n    .attr('
#  b'"height", height_py + margin_py.top + margin_py.bottom)\n    .append("g")'
#  b'\n    .attr("transform", "translate(" + margin_py.left + "," + margin_py.'
#  b'top + ")");\n\nvar cur_url_py = location.pathname;\nif (cur_url_py.indexOf('
#  b'"/search") > -1) {\n    cur_url_py = cur_url_py.replace(/\\/search/, "/yea'
#  b'r/py");\n    if (cur_url_py.slice(-1) != "/") {\n\t    cur_url_py += "/'
#  b'";\n\t}\n    cur_url_py += location.search;\n}\nif (cur_url_py.indexOf("/'
#  b'") < 0) {\n    cur_url_py = "/" + cur_url_py;\n}\n\nd3.json(cur_url_py, func'
#  b'tion(error, data) {\n\tif (data == "-1") {\n\t\t$("#facet_py").addClass("'
#  b'hide");\n\t\treturn false;\n\t}\n    data.forEach(function(d) {\n      d.ye'
#  b'ar = d.year;\n      d.value = +d.value;\n    });\n\n    data.sort(function(a'
#  b', b) {\n      return a.year - b.year;\n    });\n\n    x_py.domain([data[0].y'
#  b'ear, data[data.length - 1].year]);\n    y_py.domain([0, d3.max(data, func'
#  b'tion(d) { return d.value; })]);\n\n\n    var clip = svg_py.append("defs").a'
#  b'ppend("svg:clipPath")\n        .attr("id", "clip")\n        .append("svg:r'
#  b'ect")\n        .attr("id", "clip-rect")\n        .attr("x", "0")\n        .'
#  b'attr("y", "0")\n        .attr("width", width_py)\n        .attr("height", '
#  b'height_py);\n\n\n    svg_py.append("path")\n        .datum(data)\n       '
#  b' .attr("class", "line")\n        .attr("clip-path", "url(#clip)")\n       '
#  b' .attr("d", line_py);\n\n    svg_py.append("path")\n        .datum(data)\n  '
#  b'      .attr("class", "area")\n        .attr("clip-path", "url(#clip)")\n  '
#  b'      .attr("d", area_py);\n\n    var focus_py = svg_py.append("g")\n      '
#  b'  .attr("class", "focus")\n        .style("display", "none");\n\n    focus_'
#  b'py.append("circle")\n        .attr("r", 4.5);\n\n    svg_py.append("rect")\n'
#  b'        .attr("class", "overlay")\n        .attr("width", width_py)\n     '
#  b'   .attr("height", height_py)\n        .on("mouseover", function() {\n    '
#  b'      focus_py.style("display", null);\n          tooltip_py.transition()'
#  b'\n          .duration(500)\n          .style("opacity", 1);\n        })\n   '
#  b'     .on("mouseout", function() {\n          focus_py.style("display", "n'
#  b'one");\n          tooltip_py.transition()\n          .duration(500)\n      '
#  b'    .style("opacity", 1e-6);\n        })\n        .on("mousemove", mousemo'
#  b've_py);\n\n    function mousemove_py() {\n      var x0 = x_py.invert(d3.mou'
#  b'se(this)[0]),\n          i = bisectYear_py(data, x0, 1);\n\n      var d0, d'
#  b'1, d_py;\n      d0 = data[i - 1];\n      if (data.length > i) {\n        d1'
#  b' = data[i];\n        d_py = x0 - d0.year > d1.year - x0 ? d1 : d0;\n      '
#  b'} else {\n      \td_py = d0;\n      }\n      focus_py.attr("transform", "tra'
#  b'nslate(" + x_py(d_py.year) + "," + y_py(d_py.value) + ")");\n\n      toolt'
#  b'ip_py.text(d_py.year + "(" + d_py.value + ")")\n      .style("left", x_py'
#  b'(d_py.year) + "px")\n      .style("top", y_py(d_py.value) - 25 + "px");\n '
#  b'   }\n});\n\n// slider\n$(function() {\n\n  $.getJSON(cur_url_im,function('
#  b'data){\n\n    var startYear = Number(data[0].year),\n        endYear = Numb'
#  b'er(data[data.length-1].year);\n\n    $("#startYear_im").val(startYear);\n  '
#  b'  $("#endYear_im").val(endYear);\n\n    $( "#slider_im" ).slider({\n      r'
#  b'ange: true,\n      min: startYear,\n      max: endYear,\n      values: [sta'
#  b'rtYear,endYear],\n      slide: function( event, ui ) {\n\n        var maxv '
#  b'= d3.min([ui.values[1], data.length]);\n        var minv = d3.max([ui.val'
#  b'ues[0], 0]);\n\n        x_im.domain([ui.values[0], ui.values[1]]);\n\n      '
#  b'  svg_im.transition().duration(750)\n        .select(".area").attr("d", a'
#  b'rea_im);\n\n        svg_im.transition().duration(750)\n        .select(".fo'
#  b'cus").attr("d", line_im(data));\n\n        svg_im.transition().duration(75'
#  b'0)\n        .select(".line").attr("d", line_im(data));\n\n        // facet '
#  b'search\n        search_im(ui.values[0],ui.values[1]);\n\n      }\n    })'
#  b';\n  });\n\n  $.getJSON(cur_url_py,function(data){\n\n    var startYear ='
#  b' Number(data[0].year),\n        endYear = Number(data[data.length-1].year'
#  b');\n\n    $("#startYear_py").val(startYear);\n    $("#endYear_py").val(endY'
#  b'ear);\n\n    $( "#slider_py" ).slider({\n      range: true,\n      min: star'
#  b'tYear,\n      max: endYear,\n      values: [startYear,endYear],\n      slid'
#  b'e: function( event, ui ) {\n\n        var maxv = d3.min([ui.values[1], dat'
#  b'a.length]);\n        var minv = d3.max([ui.values[0], 0]);\n\n        x_py.'
#  b'domain([ui.values[0], ui.values[1]]);\n\n        svg_py.transition().durat'
#  b'ion(750)\n        .select(".area").attr("d", area_py);\n\n        svg_py.tr'
#  b'ansition().duration(750)\n        .select(".focus").attr("d", line_py(dat'
#  b'a));\n\n        svg_py.transition().duration(750)\n        .select(".line")'
#  b'.attr("d", line_py(data));\n\n        // facet search\n        search_py(ui'
#  b'.values[0],ui.values[1]);\n\n      }\n    });\n  });\n\n});\n\nfunction sear'
#  b'ch_im(start,end){\n  $("#startYear_im").val(start);\n  $("#endYear_im").va'
#  b'l(end);\n}\n\nfunction search_py(start,end){\n  $("#startYear_py").val(start'
#  b');\n  $("#endYear_py").val(end);\n}\n\n</script>\n</div><!-- .sidebar -->'
#  b'\n              </div><!-- .facet -->\n            </div><!-- #facet-wrapp'
#  b'er -->\n          </div>\n          \n          <div id="result-list">\n    '
#  b'        <div class="listings">\n              <div class="block-info clea'
#  b'rfix">\n                <p class="search-term-selected">\xe6\xa4\x9c\xe7\xb4'
#  b'\xa2\xe7\xb5\x90\xe6\x9e\x9c:&nbsp;1,002\xe4\xbb\xb6 / \xe3\x83\x87'
#  b'\xe3\x82\xa3\xe3\x83\xbc\xe3\x83\x97\xe3\x83\xa9\xe3\x83\xbc\xe3'
#  b'\x83\x8b\xe3\x83\xb3\xe3\x82\xb0</p>\n                <div class="pagenum'
#  b'ber">\n                  \n                  <div class="paging paging-top'
#  b'">\n                     <ul class="paginglist">\n                    \n   '
#  b'                   \n                        \n                          <'
#  b'li class="pagingitem"><span class="btn pagingbtn currentpage">1</span></'
#  b'li>\n                        \n                      \n                    '
#  b'\n                      \n                        \n                       '
#  b'   <li class="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_t'
#  b'opnum_21"><span class="short_normal">2</span></a></li>\n                 '
#  b'       \n                      \n                    \n                    '
#  b'  \n                        \n                          <li class="pagingi'
#  b'tem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_topnum_41"><span class'
#  b'="short_normal">3</span></a></li>\n                        \n             '
#  b'         \n                    \n                      \n                  '
#  b'      \n                          <li class="pagingitem hidden-xs"><a cla'
#  b'ss="btn pagingbtn" id="pagingbtn_topnum_61"><span class="short_normal">4</sp'
#  b'an></a></li>\n                        \n                      \n           '
#  b'         \n                      \n                        \n              '
#  b'            <li class="pagingitem hidden-xs"><a class="btn pagingbtn" id="pa'
#  b'gingbtn_topnum_81"><span class="short_normal">5</span></a></li>\n        '
#  b'                \n                      \n                    \n           '
#  b'           \n                        \n                          <li class'
#  b'="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_topnum_101"><'
#  b'span class="short_normal">6</span></a></li>\n                        \n   '
#  b'                   \n                    \n                      \n        '
#  b'                \n                          <li class="pagingitem hidden-'
#  b'xs"><a class="btn pagingbtn" id="pagingbtn_topnum_121"><span class="short_no'
#  b'rmal">7</span></a></li>\n                        \n                      \n'
#  b'                    \n                      \n                        \n   '
#  b'                       <li class="pagingitem hidden-xs"><a class="btn paging'
#  b'btn" id="pagingbtn_topnum_141"><span class="short_normal">8</span></a></'
#  b'li>\n                        \n                      \n                    '
#  b'\n                      \n                        \n                       '
#  b'   <li class="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_t'
#  b'opnum_161"><span class="short_normal">9</span></a></li>\n                '
#  b'        \n                      \n                    \n                   '
#  b'   \n                        \n                          <li class="paging'
#  b'item hidden-xs"><a class="btn pagingbtn" id="pagingbtn_topnum_181"><span cla'
#  b'ss="short_normal">10</span></a></li>\n                        \n          '
#  b'            \n                    \n                      \n               '
#  b'         <li class="pagingitem"><a class="btn pagingbtn" id="pagingbtn_topal'
#  b'_21""><span aria-hidden="true">\n                        \n               '
#  b'         &rsaquo;</span><span class="sr-only">Next\n                     '
#  b'   \n                        </span></a></li>\n                      \n    '
#  b'                \n                      \n                        <li clas'
#  b's="pagingitem"><a class="btn pagingbtn" id="pagingbtn_topal_981""><span aria'
#  b'-hidden="true">\n                        \n                        &raquo;'
#  b'</span><span class="sr-only">End\n                        \n              '
#  b'          </span></a></li>\n                      \n                    \n '
#  b'                   </ul>\n                  </div><!-- .paging paging-top'
#  b' -->\n                  \n                </div><!-- .pagenumber -->\n\n    '
#  b'            <div class="pull-left pagenumber">\n                  <input '
#  b'type="checkbox" id="chk_group" class="checkAll">\n                  \n    '
#  b'                <select class="form-control choice_type" name="ct" id="c'
#  b't">\n                    \n                      <option value="all" selec'
#  b'ted="selected">\xe3\x81\x99\xe3\x81\xb9\xe3\x81\xa6\xe9\x81\xb8\xe6'
#  b'\x8a\x9e</option>\n                    \n                      <option value'
#  b'="page">\xe3\x83\x9a\xe3\x83\xbc\xe3\x82\xb8\xe5\x86\x85\xe9\x81\xb8\xe6'
#  b'\x8a\x9e</option>\n                    \n                    </select>\n '
#  b'                 \n                  \n                  <select class="fo'
#  b'rm-control output_type" name="ot" id="ot">\n                    \n        '
#  b'            <option value="json">JSON\xe3\x81\xa7\xe5\x87\xba\xe5\x8a\x9b</'
#  b'option>\n                    \n                    <option value="csv"'
#  b'>\xe3\x83\x86\xe3\x82\xad\xe3\x82\xb9\xe3\x83\x88(CSV)\xe3\x81'
#  b'\xa7\xe5\x87\xba\xe5\x8a\x9b</option>\n                    \n              '
#  b'    </select>\n                  \n                  <input type="button" '
#  b'class="btn file_btn" id="file_btn" value="\xe5\xae\x9f\xe8\xa1\x8c" />\n   '
#  b'               <input type="hidden" id="is_over" value="0" />\n          '
#  b'        <input type="hidden" id="max_file_msg" value="" />\n             '
#  b'   </div><!-- .pull-left .pagenumber -->\n\n                <div class="pu'
#  b'll-left pageinfo">\n                  \n                  <strong>'
#  b'\xe8\xa1\xa8\xe7\xa4\xba\xe4\xbb\xb6\xe6\x95\xb0:&nbsp;</strong>\n       '
#  b'             <select class="form-control" name="rw" id="rw">\n           '
#  b'           \n                      <option value="20" selected="selected"'
#  b'>20</option>\n                      \n                      <option value='
#  b'"50">50</option>\n                      \n                      <option va'
#  b'lue="100">100</option>\n                      \n                      <opt'
#  b'ion value="200">200</option>\n                      \n                    '
#  b'  <option value="500">500</option>\n                      \n              '
#  b'      </select>\n                  \n                </div>\n              '
#  b'  <div class="pull-right">\n                  \n                  <select '
#  b'class="form-control" name="od" id="od">\n                    \n           '
#  b'             <option value="1">\xe9\x81\xa9\xe5\x90\x88\xe5\xba\xa6</option'
#  b'>\n                    \n                        <option value="2"'
#  b'>\xe3\x82\xab\xe3\x83\x8a: \xe6\x98\x87\xe9\xa0\x86</option>\n           '
#  b'         \n                        <option value="3">\xe3\x82\xab\xe3'
#  b'\x83\x8a: \xe9\x99\x8d\xe9\xa0\x86</option>\n                    \n       '
#  b'                 <option value="4">\xe3\x82\xa2\xe3\x83\xab\xe3\x83\x95'
#  b'\xe3\x82\xa1\xe3\x83\x99\xe3\x83\x83\xe3\x83\x88: \xe6\x98\x87\xe9\xa0\x86'
#  b'</option>\n                    \n                        <option value="5"'
#  b'>\xe3\x82\xa2\xe3\x83\xab\xe3\x83\x95\xe3\x82\xa1\xe3\x83\x99'
#  b'\xe3\x83\x83\xe3\x83\x88: \xe9\x99\x8d\xe9\xa0\x86</option>\n            '
#  b'        \n                        <option value="6">\xe7\xa0\x94\xe7\xa9'
#  b'\xb6\xe8\xaa\xb2\xe9\xa1\x8c\xe6\x95\xb0: \xe6\x98\x87\xe9\xa0\x86</opti'
#  b'on>\n                    \n                        <option value="7" selec'
#  b'ted="selected">\xe7\xa0\x94\xe7\xa9\xb6\xe8\xaa\xb2\xe9\xa1\x8c\xe6'
#  b'\x95\xb0: \xe9\x99\x8d\xe9\xa0\x86</option>\n                    \n       '
#  b'           </select>\n                  \n                </div>\n         '
#  b'     </div><!-- block-info clearfix -->\n              \n              <di'
#  b'v class="listContainer">\n                <ul>\n                  \n       '
#  b'           \n                  <li>\n                    <div class="listi'
#  b'tem xfolkentry">\n                      <h3 class="item_mainTitle">\n     '
#  b'                   <div class="title">\n                        <input ty'
#  b'pe="checkbox" class="chk_group" name="chk[]" id="chk_70213486" value="702134'
#  b'86" />\n                        <span class="row-number"> 1. </span><i cl'
#  b'ass="fa fa-user"></i> <a class="link-page" href="/nrid/1000070213486/">\xe6'
#  b'\xa2\x85\xe6\xbe\xa4 \xe6\x98\x8e\xe5\xbc\x98<span class="subTitle">&nbsp'
#  b';&nbsp;UMEZAWA Akihiro&nbsp;&nbsp;(70213486)</span></a>\n                '
#  b'          </div>\n                      </h3>\n\n                      <tab'
#  b'le class="summary-table">\n                      \n                      <'
#  b'tr>\n                       <th>\xe6\x89\x80\xe5\xb1\x9e (\xe7'
#  b'\x8f\xbe\xe5\x9c\xa8)</th>\n                       <td>\n                '
#  b'       \n                       \xe5\x9b\xbd\xe7\xab\x8b\xe7\xa0\x94'
#  b'\xe7\xa9\xb6\xe9\x96\x8b\xe7\x99\xba\xe6\xb3\x95\xe4\xba\xba\xe5'
#  b'\x9b\xbd\xe7\xab\x8b\xe6\x88\x90\xe8\x82\xb2\xe5\x8c\xbb\xe7\x99'
#  b'\x82\xe7\xa0\x94\xe7\xa9\xb6\xe3\x82\xbb\xe3\x83\xb3\xe3\x82\xbf'
#  b'\xe3\x83\xbc,&nbsp;\xe7\xa0\x94\xe7\xa9\xb6\xe6\x89\x80,&nbsp;\xe7\xa0'
#  b'\x94\xe7\xa9\xb6\xe6\x89\x80\xe9\x95\xb7\n                       <br>\n     '
#  b'                  \xe5\x9b\xbd\xe7\xab\x8b\xe7\xa0\x94\xe7\xa9\xb6\xe9\x96'
#  b'\x8b\xe7\x99\xba\xe6\xb3\x95\xe4\xba\xba\xe5\x9b\xbd\xe7\xab\x8b'
#  b'\xe6\x88\x90\xe8\x82\xb2\xe5\x8c\xbb\xe7\x99\x82\xe7\xa0\x94\xe7'
#  b'\xa9\xb6\xe3\x82\xbb\xe3\x83\xb3\xe3\x82\xbf\xe3\x83\xbc,&nbsp;\xe7\x97\x85'
#  b'\xe7\x90\x86\xe8\xa8\xba\xe6\x96\xad\xe9\x83\xa8,&nbsp;\xe5\x8c\xbb\xe5\x93'
#  b'\xa1\n                       <br>\n                       \xe5\x9b\xbd'
#  b'\xe7\xab\x8b\xe7\xa0\x94\xe7\xa9\xb6\xe9\x96\x8b\xe7\x99\xba\xe6'
#  b'\xb3\x95\xe4\xba\xba\xe5\x9b\xbd\xe7\xab\x8b\xe6\x88\x90\xe8\x82'
#  b'\xb2\xe5\x8c\xbb\xe7\x99\x82\xe7\xa0\x94\xe7\xa9\xb6\xe3\x82\xbb'
#  b'\xe3\x83\xb3\xe3\x82\xbf\xe3\x83\xbc,&nbsp;\xe7\xb4\xb0\xe8\x83\x9e\xe5\x8c'
#  b'\xbb\xe7\x99\x82\xe7\xa0\x94\xe7\xa9\xb6\xe9\x83\xa8,&nbsp;\xe9\x83\xa8\xe9'
#  b' class="chk_group" name="chk[]" id="chk_50143920" value="50143920" />\n  '
#  b'                      <span class="row-number"> 2. </span><i class="fa fa-us'
#  b'er"></i> <a class="link-page" href="/nrid/1000050143920/">\xe7\x9c'
#  b'\x9f\xe7\x94\xb0 \xe5\xbc\x98\xe7\xbe\x8e<span class="subTitle">&nbsp;&nbs'
#  b'p;Sanada Hiromi&nbsp;&nbsp;(50143920)</span></a>\n                       '
#  b'   </div>\n                      </h3>\n\n                      <table clas'
#  b's="summary-table">\n                      \n                      <tr>\n   '
#  b'                    <th>\xe6\x89\x80\xe5\xb1\x9e (\xe7\x8f\xbe\xe5\x9c\xa8)<'
#  b'/th>\n                       <td>\n                       \n               '
#  b'        \xe7\x9f\xb3\xe5\xb7\x9d\xe7\x9c\x8c\xe7\xab\x8b\xe7\x9c\x8b\xe8'
#  b'\xad\xb7\xe5\xa4\xa7\xe5\xad\xa6,&nbsp;\xe7\x9c\x8b\xe8\xad\xb7\xe5\xad\xa6'
#  b'\xe9\x83\xa8,&nbsp;\xe6\x95\x99\xe6\x8e\x88\n                       \n   '
#  b'                    </td>\n                      </tr>\n                  '
#  b'    \n                      \n                        <tr>\n               '
#  b'           <th>\xe5\xaf\xa9\xe6\x9f\xbb\xe5\x8c\xba\xe5\x88\x86/'
#  b'\xe7\xa0\x94\xe7\xa9\xb6\xe5\x88\x86\xe9\x87\x8e</th>\n                  '
#  b'        <td>\n                          <a href="/search/?qd=%5B%E7%A0%94'
#  b'%E7%A9%B6%E5%88%86%E9%87%8E%3A%E7%B4%B0%E7%9B%AE%5D%E7%94%9F%E7%89%A9%E7%B3%'
#  b'BB/%E5%8C%BB%E6%AD%AF%E8%96%AC%E5%AD%A6/%E7%9C%8B%E8%AD%B7%E5%AD%A6/%E5%9F%B'
#  b'A%E7%A4%8E%E7%9C%8B%E8%AD%B7%E5%AD%A6" class="link-page underline">\xe5'
#  b'\x9f\xba\xe7\xa4\x8e\xe7\x9c\x8b\xe8\xad\xb7\xe5\xad\xa6</a>&nbsp;/\n      '
#  b'                    \n                          <a href="/search/?qd=%5B%'
#  b'E5%AF%A9%E6%9F%BB%E5%8C%BA%E5%88%86%3A%E5%AF%A9%E6%9F%BB%E5%8C%BA%E5%88%86%5'
#  b'D%E5%B0%8F%E5%8C%BA%E5%88%8658060%3A%E8%87%A8%E5%BA%8A%E7%9C%8B%E8%AD%B7%E5%'
#  b'AD%A6%E9%96%A2%E9%80%A3" class="link-page underline">\xe5\xb0\x8f'
#  b'\xe5\x8c\xba\xe5\x88\x8658060:\xe8\x87\xa8\xe5\xba\x8a\xe7\x9c'
#  b'\x8b\xe8\xad\xb7\xe5\xad\xa6\xe9\x96\xa2\xe9\x80\xa3</a>&nbsp;/\n           '
#  b'               \n                          <a href="/search/?qd=%5B%E5%AF'
#  b'%A9%E6%9F%BB%E5%8C%BA%E5%88%86%3A%E5%AF%A9%E6%9F%BB%E5%8C%BA%E5%88%86%5D%E4%'
#  b'B8%AD%E5%8C%BA%E5%88%8658%3A%E7%A4%BE%E4%BC%9A%E5%8C%BB%E5%AD%A6%E3%80%81%E7'
#  b'%9C%8B%E8%AD%B7%E5%AD%A6%E3%81%8A%E3%82%88%E3%81%B3%E3%81%9D%E3%81%AE%E9%96%'
#  b'A2%E9%80%A3%E5%88%86%E9%87%8E" class="link-page underline">\xe4'
#  b'\x9c\x8b\xe8\xad\xb7\xe5\xad\xa6</a>&nbsp;/&nbsp;<a href="/search/?qf=%E7%9C'
#  b'%8B%E8%AD%B7%E5%B7%A5%E5%AD%A6" class="link-page underline">\xe7\x9c\x8b\xe8'
#  b'\xad\xb7\xe5\xb7\xa5\xe5\xad\xa6</a>&nbsp;/&nbsp;<a href="/search/?qf=%E6%8C'
#  b'%AF%E5%8B%95" class="link-page underline">\xe6\x8c\xaf\xe5\x8b\x95</a>&nbs'
#  b'p;/&nbsp;<a href="/search/?qf=%E5%89%B5%E5%82%B7%E6%B2%BB%E7%99%92" class="l'
#  b'ink-page underline">\xe5\x89\xb5\xe5\x82\xb7\xe6\xb2\xbb\xe7\x99\x92</a>&nbs'
#  b'p;/&nbsp;<a href="/search/?qf=pressure%20ulcer" class="link-page underline">'
#  b'pressure ulcer</a></td>\n                        </tr>\n                  '
#  b'      \n                        \n                        <tr>\n           '
#  b'               <th>\xe7\xa0\x94\xe7\xa9\xb6\xe8\xaa\xb2\xe9\xa1\x8c\xe6'
#  b'\x95\xb0</th>\n                          <td>104</td>\n                     '
#  b'   </tr>\n                        \n                        \n             '
#  b'           <tr>\n                          <th>\xe7\xa0\x94\xe7\xa9\xb6'
#  b'\xe6\x88\x90\xe6\x9e\x9c\xe6\x95\xb0</th>\n                          <td>575'
#  b'</td>\n                        </tr>\n                        \n           '
#  b'           </table>\n                    </div><!-- .listitem xfolkentry '
#  b'-->\n                  </li>\n                  \n                  \n      '
#  b'            <li>\n                    <div class="listitem xfolkentry">\n '
#  b'                     <h3 class="item_mainTitle">\n                       '
#  b' <div class="title">\n                        <input type="checkbox" clas'
#  b's="chk_group" name="chk[]" id="chk_60160694" value="60160694" />\n       '
#  b'                 <span class="row-number"> 3. </span><i class="fa fa-user"><'
#  b'/i> <a class="link-page" href="/nrid/1000060160694/">\xe5\xb2\xa1'
#  b'\xe9\x87\x8e \xe6\xa0\x84\xe4\xb9\x8b<span class="subTitle">&nbsp;&nbsp;Oka'
#  b'no Hideyuki&nbsp;&nbsp;(60160694)</span></a>\n                          <'
#  b'/div>\n                      </h3>\n\n                      <table class="s'
#  b'ummary-table">\n                      \n                      <tr>\n       '
#  b'                <th>\xe6\x89\x80\xe5\xb1\x9e (\xe7\x8f\xbe\xe5\x9c\xa8)</th>'
#  b'\n                       <td>\n                       \n                   '
#  b'    \xe6\x85\xb6\xe6\x87\x89\xe7\xbe\xa9\xe5\xa1\xbe\xe5\xa4\xa7\xe5'
#  b'\xad\xa6,&nbsp;\xe5\xa4\xa7\xe5\xad\xa6\xe5\x85\xb1\xe9\x80\x9a,&nbsp;'
#  b'\xe6\x95\x99\xe6\x8e\x88\n                       <br>\n                     '
#  b'  \xe5\x9b\xbd\xe7\xab\x8b\xe7\xa0\x94\xe7\xa9\xb6\xe9\x96\x8b\xe7\x99\xba'
#  b'\xe6\xb3\x95\xe4\xba\xba\xe7\x90\x86\xe5\x8c\x96\xe5\xad\xa6\xe7'
#  b'>\xe6\x9c\xa8\xe7\xb0\xa1</a>&nbsp;/&nbsp;<a href="/search/?qf=%E5%9C%B0%E'
#  b'5%9B%B3" class="link-page underline">\xe5\x9c\xb0\xe5\x9b\xb3</a>&nbsp;/&n'
#  b'bsp;<a href="/search/?qf=%E8%8D%98%E5%9C%92%E7%B5%B5%E5%9B%B3" class="link-p'
#  b'age underline">\xe8\x8d\x98\xe5\x9c\x92\xe7\xb5\xb5\xe5\x9b\xb3</a>&nbsp;/&n'
#  b'bsp;<a href="/search/?qf=%E5%8F%A4%E6%96%87%E6%9B%B8" class="link-page under'
#  b'line">\xe5\x8f\xa4\xe6\x96\x87\xe6\x9b\xb8</a>&nbsp;/&nbsp;<a href="/search'
#  b'/?qf=%E8%8D%98%E5%9C%92" class="link-page underline">\xe8\x8d\x98'
#  b'\xe5\x9c\x92</a></td>\n                        </tr>\n                     '
#  b'   \n                        \n                        <tr>\n              '
#  b'            <th>\xe7\xa0\x94\xe7\xa9\xb6\xe8\xaa\xb2\xe9\xa1\x8c'
#  b'\xe6\x95\xb0</th>\n                          <td>44</td>\n                 '
#  b'       </tr>\n                        \n                        \n         '
#  b'               <tr>\n                          <th>\xe7\xa0\x94\xe7\xa9\xb6'
#  b'\xe6\x88\x90\xe6\x9e\x9c\xe6\x95\xb0</th>\n                          <td>305'
#  b'</td>\n                        </tr>\n                        \n           '
#  b'           </table>\n                    </div><!-- .listitem xfolkentry '
#  b'-->\n                  </li>\n                  \n                </ul>\n   '
#  b'           </div><!-- .listContainer -->\n\n              \n              <'
#  b'div class="paging paging-top">\n                 <ul class="paginglist">\n'
#  b'                \n                  \n                  \n                 '
#  b' <li class="pagingitem hidden-xs"><span class="btn pagingbtn currentpage">1<'
#  b'/span></li>\n                  \n                  \n                \n     '
#  b'             \n                  \n                  <li class="pagingitem'
#  b' hidden-xs"><a class="btn pagingbtn" id="pagingbtn_bottomnum_21"><span class'
#  b'="short_normal">2</span></a></li>\n                  \n                  \n'
#  b'                \n                  \n                  \n                 '
#  b' <li class="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_bot'
#  b'tomnum_41"><span class="short_normal">3</span></a></li>\n                '
#  b'  \n                  \n                \n                  \n              '
#  b'    \n                  <li class="pagingitem hidden-xs"><a class="btn pa'
#  b'gingbtn" id="pagingbtn_bottomnum_61"><span class="short_normal">4</span></a>'
#  b'</li>\n                  \n                  \n                \n           '
#  b'       \n                  \n                  <li class="pagingitem hidde'
#  b'n-xs"><a class="btn pagingbtn" id="pagingbtn_bottomnum_81"><span class="shor'
#  b't_normal">5</span></a></li>\n                  \n                  \n      '
#  b'          \n                  \n                  \n                  <li c'
#  b'lass="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_bottomnum'
#  b'_101"><span class="short_normal">6</span></a></li>\n                  \n  '
#  b'                \n                \n                  \n                  \n'
#  b'                  <li class="pagingitem hidden-xs"><a class="btn pagingbtn" '
#  b'id="pagingbtn_bottomnum_121"><span class="short_normal">7</span></a></li'
#  b'>\n                  \n                  \n                \n               '
#  b'   \n                  \n                  <li class="pagingitem hidden-xs'
#  b'"><a class="btn pagingbtn" id="pagingbtn_bottomnum_141"><span class="short_n'
#  b'ormal">8</span></a></li>\n                  \n                  \n         '
#  b'       \n                  \n                  \n                  <li clas'
#  b's="pagingitem hidden-xs"><a class="btn pagingbtn" id="pagingbtn_bottomnum_16'
#  b'1"><span class="short_normal">9</span></a></li>\n                  \n     '
#  b'             \n                \n                  \n                  \n   '
#  b'               <li class="pagingitem hidden-xs"><a class="btn pagingbtn" id='
#  b'"pagingbtn_bottomnum_181"><span class="short_normal">10</span></a></li>\n'
#  b'                  \n                  \n                \n                 '
#  b' \n                  <li class="pagingitem hidden-xs">\n                  '
#  b'  <a class="btn pagingbtn" id="pagingbtn_bottomal_21"><span aria-hidden="tru'
#  b'e">\n                    \n                    &rsaquo;</span><span class='
#  b'"sr-only">Next\n                    \n                    </span></a>\n    '
#  b'              </li>\n                  \n                \n                '
#  b'  \n                  <li class="pagingitem hidden-xs">\n                 '
#  b'   <a class="btn pagingbtn" id="pagingbtn_bottomal_981"><span aria-hidden="t'
#  b'rue">\n                    \n                    &raquo;</span><span class'
#  b'="sr-only">End\n                    \n                    </span></a>\n    '
#  b'              </li>\n                  \n                \n                '
#  b'</ul>\n              </div><!-- .paging paging-top -->\n              \n   '
#  b'         </div><!-- .listings -->\n          </div><!-- #result-list -->\n'
#  b'      </div><!-- .container -->\n    </div><!-- #result-wrapper -->\n  </d'
#  b'iv><!-- #results -->\n\n  \n\n</div><!-- .body-wrap -->\n<input type="hid'
#  b'den" name="st" value="1" />\n<input type="hidden" name="rw" value="20" />'
#  b'\n\n\n </form>\n</div><!-- #content -->\n\n  \n<div class="footer">\n  <div '
#  b'class="footer-wrap">\n      <div class="row">\n          <div class="col-s'
#  b'm-8 col-xs-12">\n              <p class="footer-links">\n               \n '
#  b'                 <a href="https://support.nii.ac.jp/kaken/" class="win_open '
#  b' active">\xe3\x82\xb5\xe3\x83\xbc\xe3\x83\x93\xe3\x82\xb9\xe6\xa6\x82'
#  b'\xe8\xa6\x81</a>\n               \n                  <a href="https://suppo'
#  b'rt.nii.ac.jp/kaken/researcher_quicksearch" class="win_open ">\xe6\xa4\x9c'
#  b'\xe7\xb4\xa2\xe3\x83\x9e\xe3\x83\x8b\xe3\x83\xa5\xe3\x82\xa2\xe3\x83\xab</'
#  b'a>\n               \n                  <a href="https://support.nii.ac.jp/'
#  b'kaken/faq/general" class="win_open ">\xe3\x82\x88\xe3\x81\x8f\xe3'
#  b'\x81\x82\xe3\x82\x8b\xe8\xb3\xaa\xe5\x95\x8f</a>\n               \n        '
#  b'          <a href="https://support.nii.ac.jp/news/kaken" class="win_open'
#  b' ">\xe3\x81\x8a\xe7\x9f\xa5\xe3\x82\x89\xe3\x81\x9b</a>\n               \n'
#  b'                  <a href="https://support.nii.ac.jp/kaken/about/terms" clas'
#  b's="win_open ">\xe5\x88\xa9\xe7\x94\xa8\xe8\xa6\x8f\xe7\xa8\x8b</a>\n     '
#  b'          \n                  <a href="https://support.nii.ac.jp/kaken/ka'
#  b'kenhi" class="win_open ">\xe7\xa7\x91\xe7\xa0\x94\xe8\xb2\xbb\xe3\x81'
#  b'\xab\xe3\x82\x88\xe3\x82\x8b\xe7\xa0\x94\xe7\xa9\xb6\xe3\x81\xae'
#  b'\xe5\xb8\xb0\xe5\xb1\x9e</a>\n               \n              </p>\n      '
#  b'    </div>\n          <div class="col-sm-4 col-xs-12">\n             <a cl'
#  b'ass="pull-right" href="https://www.nii.ac.jp/" target="_blank"><strong>Power'
#  b'ed by NII</strong></a>\n             <a class="pull-right kakenhi-footer-'
#  b'logo" href="https://www.jsps.go.jp/" target="_blank"><img src="/static/image'
#  b's/kaken_footer_logo_ja.png" alt="kakenhi" width="100" height="43" class="kak'
#  b'enhi logo" /></a>\n          </div>\n      </div>\n  </div>\n</div>\n\n<!-'
#  b'- Bootstrap core JavaScript\n============================================'
#  b'====== -->\n<!-- Placed at the end of the document so the pages load fast'
#  b'er -->\n<script type="text/javascript" src="/static/bootstrap/js/bootstra'
#  b'p.min.js?1697515897"></script>\n<script type="text/javascript" src="/stat'
#  b'ic/js/jquery.flot.js?1691548633"></script>\n<script type="text/javascript'
#  b'" src="/static/js/dropzone.js?1691548633"></script>\n\n<script nonce="Umqe'
#  b'lrVo1EH9Wpt8lOoHoA==" type="text/javascript">\n//<![CDATA[\n$(function() {'
#  b'\n    $(".checkAll").on("change", function() {\n        $("." + this.id).p'
#  b'rop("checked", this.checked);\n        if ($(".chk_group:checked").length'
#  b' == 0) {\n        \t$("#file_btn").addClass("invisible");\n        } else {'
#  b'\n        \t$("#file_btn").removeClass("invisible");\n        }\n    });'
#  b'\n\n    $(".chk_group").on("change", function() {\n\t\tif ($(".chk_group:'
#  b'checked").length == 0) {\n        \t$("#file_btn").addClass("invisible");\n'
#  b'        } else {\n        \t$("#file_btn").removeClass("invisible");\n     '
#  b'   }\n    });\n\n    if ($("select[name=ct]").val() == \'all\') {\n\t\t$(".c'
#  b'hk_group").prop(\'checked\', false);\n\t\t$(".checkAll").prop(\'checked\', '
#  b'false);\n\t\t$(".chk_group").prop("disabled", true);\n\t\t$(".checkAll").p'
#  b'rop("disabled", true);\n\t\t$("#file_btn").removeClass("invisible");\n  '
#  b'  }\n\n    $("#ct").on("change", function() {\n    \tif ($("select[name=ct]"'
#  b').val() == \'all\') {\n    \t\t$(".chk_group").prop(\'checked\', false);\n  '
#  b'  \t\t$(".checkAll").prop(\'checked\', false);\n    \t\t$(".chk_group").pro'
#  b'p("disabled", true);\n    \t\t$(".checkAll").prop("disabled", true);\n  '
#  b'  \t\t$("#file_btn").removeClass("invisible");\n\t    } else {\n\t        '
#  b'$(".chk_group").prop("disabled", false);\n\t        $(".checkAll").prop("d'
#  b'isabled", false);\n\t        if ($(".chk_group:checked").length == 0) {\n\t '
#  b'       \t$("#file_btn").addClass("invisible");\n\t        }\n\t    }\n    '
#  b'});\n});\n//]]>\n</script>\n\n</body>\n</html>')

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

def make_request(url, method='GET', data=None, headers=None):
    if headers is None:
        headers = {}

    if method.upper() == 'GET':
        response = requests.get(url, headers=headers)
    elif method.upper() == 'POST':
        response = requests.post(url, data=data, headers=headers)
    else:
        raise ValueError("Unsupported HTTP method: {}".format(method))

    return response

def build_url(base_url, **params):
    query_string = '&'.join(f"{key}={value}" for key, value in params.items())
    return f"{base_url}?{query_string}" if query_string else base_url

def fetch_data(base_url, **params):
    url = build_url(base_url, **params)
    response = make_request(url)

    if response.status_code == 200:
        return response
    else:
        response.raise_for_status()  # Raise an error for bad responses

def parse_html_response(html_content):
    """HTMLレスポンスをパースしてBeautifulSoupオブジェクトに変換する"""
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup

def get_search_results(soup):
    """検索結果を抽出する"""
    results = []

    # 研究者リストの各アイテムを取得
    researchers = soup.select('.listitem.xfolkentry')

    for researcher in researchers:
        # 基本情報の取得
        name_elem = researcher.select_one('.item_mainTitle a')
        if not name_elem:
            continue

        name = name_elem.text.strip()
        # ID部分を取得 (例: (70213486))
        researcher_id = None
        id_match = None
        if '(' in name and ')' in name:
            id_match = name.split('(')[-1].split(')')[0]
            if id_match.isdigit():
                researcher_id = id_match

        # プロフィールURL
        profile_url = name_elem.get('href', '')

        # 所属情報の取得
        affiliation = []
        affiliation_elem = researcher.select_one('tr:has(th:contains("所属")) td')
        if affiliation_elem:
            for line in affiliation_elem.stripped_strings:
                if line.strip():
                    affiliation.append(line.strip())

        # キーワードの取得
        keywords = []
        keywords_elem = researcher.select_one('tr:has(th:contains("キーワード")) td')
        if keywords_elem:
            keywords = [a.text.strip() for a in keywords_elem.select('a')]

        # 研究課題数と研究成果数
        research_projects = 0
        research_projects_elem = researcher.select_one('tr:has(th:contains("研究課題数")) td')
        if research_projects_elem:
            try:
                research_projects = int(research_projects_elem.text.strip().replace(',', ''))
            except:
                pass

        research_results = 0
        research_results_elem = researcher.select_one('tr:has(th:contains("研究成果数")) td')
        if research_results_elem:
            try:
                research_results = int(research_results_elem.text.strip().replace(',', ''))
            except:
                pass

        # 結果を辞書として格納
        researcher_info = {
            'name': name.split('(')[0].strip() if '(' in name else name,
            'researcher_id': researcher_id,
            'profile_url': profile_url,
            'affiliation': affiliation,
            'keywords': keywords,
            'research_projects': research_projects,
            'research_results': research_results
        }

        results.append(researcher_info)

    return results

# メインロジックを実行
base_url = "https://nrid.nii.ac.jp/opensearch/"
params = {
    'rw': 500,
    'qf': '深層学習 OR 人工知能 OR 機械学習',
    'qd': '[審査区分:審査区分]大区分J OR [審査区分:審査希望区分(新学術領域研究)]複合領域',
    'appid': 'gu782hFEjCChFcYxyeb9',
    'od': '1',
}

data = fetch_data(base_url, **params)
soup = parse_html_response(data.content)

# 検索結果の総数を取得
total_results_elem = soup.select_one('.search-term-selected')
total_results = "不明"
if total_results_elem:
    text = total_results_elem.text
    import re
    match = re.search(r'(\d+,?\d*)件', text)
    if match:
        total_results = match.group(1)

print(f"検索結果の総数: {total_results}")

# 検索結果の抽出
results = get_search_results(soup)
print(f"取得した研究者数: {len(results)}")

# 結果の表示（最初の3件だけ表示）
for i, researcher in enumerate(results):
    print(f"\n--- 研究者 {i+1} ---")
    print(f"氏名: {researcher['name']}")
    print(f"研究者ID: {researcher['researcher_id']}")
    print(f"所属: {', '.join(researcher['affiliation'][:1])}")  # 最初の所属だけ表示
    print(f"キーワード: {', '.join(researcher['keywords'][:5])}")  # 最初の5キーワードだけ表示
    print(f"研究課題数: {researcher['research_projects']}")
    print(f"研究成果数: {researcher['research_results']}")
    print(f"プロフィールURL: {researcher['profile_url']}")
# Out:
# 検索結果の総数: 640
# 取得した研究者数: 500
#
# --- 研究者 1 ---
# 氏名: 森岡 博史  MORIOKA Hiroshi
# 研究者ID: 20739552
# 所属: 滋賀大学, データサイエンス学系, 准教授
# キーワード: 機械学習, 深層学習, 非線形解析, 因果探索, 計算神経科学
# 研究課題数: 6
# 研究成果数: 23
# プロフィールURL: /nrid/1000020739552/
#
# --- 研究者 2 ---
# 氏名: 山口 光太  ヤマグチ コウタ
# 研究者ID: 10742596
# 所属: 東北大学, 情報科学研究科, 助教
# キーワード: コンピュータビジョン, 画像認識, 深層学習, 機械学習, 人工知能
# 研究課題数: 2
# 研究成果数: 0
# プロフィールURL: /nrid/1000010742596/
#
# --- 研究者 3 ---
# 氏名: 中島 悠太  Nakashima Yuta
# 研究者ID: 70633551
# 所属: 大阪大学, 産業科学研究所, 教授
# キーワード: 深層学習, 人工知能, 重要領域推定, 映像要約, 仏像
# 研究課題数: 13
# 研究成果数: 86
# プロフィールURL: /nrid/1000070633551/
#
# --- 研究者 4 ---
# 氏名: 中山 浩太郎  Nakayama Kotaro
# 研究者ID: 00512097
# 所属: 東京大学, 大学院工学系研究科(工学部), 学術支援専門職員
# キーワード: 人工知能, 情報システム, 情報検索, スケーラビリティ, Deep Learning
# 研究課題数: 4
# 研究成果数: 102
# プロフィールURL: /nrid/1000000512097/
#
# --- 研究者 5 ---
# 氏名: 塚田 武志  Tsukada Takeshi
# 研究者ID: 50758951
# 所属: 千葉大学, 大学院理学研究院, 教授
# キーワード: プログラム検証, 機械学習, 線形論理, π計算, ゲーム意味論
# 研究課題数: 6
# 研究成果数: 24
# プロフィールURL: /nrid/1000050758951/
#
# --- 研究者 6 ---
# 氏名: 関山 太朗  Sekiyama Taro
# 研究者ID: 80828476
# 所属: 国立情報学研究所, アーキテクチャ科学研究系, 准教授
# キーワード: プログラム検証, プログラミング言語, 機械学習, 型システム, 人工知能
# 研究課題数: 8
# 研究成果数: 38
# プロフィールURL: /nrid/1000080828476/
#
# --- 研究者 7 ---
# 氏名: 宮澤 芳光  MIYAZAWA Yoshimitsu
# 研究者ID: 70726166
# 所属: 独立行政法人大学入試センター, 研究開発部, 准教授
# キーワード: 項目反応理論, eテスティング, 適応型テスト, 自然言語処理, CBT
# 研究課題数: 15
# 研究成果数: 108
# プロフィールURL: /nrid/1000070726166/
#
# --- 研究者 8 ---
# 氏名: 小川 貴弘  Ogawa Takahiro
# 研究者ID: 20524028
# 所属: 北海道大学, 情報科学研究院, 教授
# キーワード: 人工知能, 深層学習, 情報検索, 画質評価, 画像検索
# 研究課題数: 12
# 研究成果数: 1098
# プロフィールURL: /nrid/1000020524028/
#
# --- 研究者 9 ---
# 氏名: 鈴木 大慈  Suzuki Taiji
# 研究者ID: 60551372
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: 機械学習, 深層学習, 統計的学習理論, 統計数学, 高次元データ
# 研究課題数: 11
# 研究成果数: 412
# プロフィールURL: /nrid/1000060551372/
#
# --- 研究者 10 ---
# 氏名: 近添 淳一  Chikazoe Junichi
# 研究者ID: 40456108
# 所属: 広島大学, 脳・こころ・感性科学研究センター, 教授
# キーワード: 機能的MRI, 神経科学, 脳機能画像, 価値, 脳機能計測
# 研究課題数: 9
# 研究成果数: 22
# プロフィールURL: /nrid/1000040456108/
#
# --- 研究者 11 ---
# 氏名: 宇都 雅輝  Uto Masaki
# 研究者ID: 10732571
# 所属: 電気通信大学, 大学院情報理工学研究科, 准教授
# キーワード: 項目反応理論, eテスティング, テスト理論, パフォーマンス評価, 自然言語処理
# 研究課題数: 16
# 研究成果数: 366
# プロフィールURL: /nrid/1000010732571/
#
# --- 研究者 12 ---
# 氏名: 酒井 智弥  SAKAI Tomoya
# 研究者ID: 30345003
# 所属: 長崎大学, 総合生産科学研究科(情報データ科学系), 准教授
# キーワード: パターン認識, 機械学習, 半教師付き分類, リモートセンシング, マルチスペクトル画像
# 研究課題数: 16
# 研究成果数: 161
# プロフィールURL: /nrid/1000030345003/
#
# --- 研究者 13 ---
# 氏名: 山下 祐一  Yamashita Yuichi
# 研究者ID: 40584131
# 所属: 国立研究開発法人国立精神・神経医療研究センター, 神経研究所 疾病研究第七部, 室長
# キーワード: 精神疾患, ニューラルネットワーク, 計算論的精神医学, 神経科学, 深層学習
# 研究課題数: 14
# 研究成果数: 190
# プロフィールURL: /nrid/1000040584131/
#
# --- 研究者 14 ---
# 氏名: 長原 一  Nagahara Hajime
# 研究者ID: 80362648
# 所属: 大阪大学, D3センター, 教授
# キーワード: コンピュテーショナルフォトグラフィ, 深層学習, 人工知能, ディープラーニング, AI
# 研究課題数: 27
# 研究成果数: 332
# プロフィールURL: /nrid/1000080362648/
#
# --- 研究者 15 ---
# 氏名: 柳井 啓司  Yanai Keiji
# 研究者ID: 20301179
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: 深層学習, Web画像マイニング, 画像認識, 物体認識, 一般物体認識
# 研究課題数: 21
# 研究成果数: 524
# プロフィールURL: /nrid/1000020301179/
#
# --- 研究者 16 ---
# 氏名: 松葉 浩也  Matsuba Hiroya
# 研究者ID: 30444095
# 所属: 株式会社日立製作所(研究開発グループ), 計測・デジタルテクノロジーイノベーションセンタ, 主任研究員
# キーワード: 機械学習, リモートスワップ, PCクラスタ, 分散ページ, 大規模メモリ
# 研究課題数: 3
# 研究成果数: 25
# プロフィールURL: /nrid/1000030444095/
#
# --- 研究者 17 ---
# 氏名: 末永 幸平  Suenaga Kohei
# 研究者ID: 70633692
# 所属: 京都大学, 情報学研究科, 准教授
# キーワード: プログラム検証, ハイブリッドシステム, 形式手法, プログラミング言語, 形式検証
# 研究課題数: 11
# 研究成果数: 69
# プロフィールURL: /nrid/1000070633692/
#
# --- 研究者 18 ---
# 氏名: 宮尾 祐介  Miyao Yusuke
# 研究者ID: 00343096
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: 自然言語処理, 機械学習, 人工知能, 深層学習, 情報検索
# 研究課題数: 19
# 研究成果数: 161
# プロフィールURL: /nrid/1000000343096/
#
# --- 研究者 19 ---
# 氏名: 谷口 忠大  Taniguchi Tadahiro
# 研究者ID: 80512251
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 記号創発, 機械学習, ソフトコンピューティング, 言語獲得, 人工知能
# 研究課題数: 16
# 研究成果数: 285
# プロフィールURL: /nrid/1000080512251/
#
# --- 研究者 20 ---
# 氏名: 佐藤 亮介  Sato Ryosuke
# 研究者ID: 10804677
# 所属: 東京農工大学, 学内共同利用施設等, 准教授
# キーワード: プログラム検証, 高階モデル検査, 高階不動点論理, 型システム, 関数型言語
# 研究課題数: 6
# 研究成果数: 52
# プロフィールURL: /nrid/1000010804677/
#
# --- 研究者 21 ---
# 氏名: 原田 達也  Harada Tatsuya
# 研究者ID: 60345113
# 所属: 東京大学, 先端科学技術研究センター, 教授
# キーワード: 画像認識, 人工知能, 機械学習, 感覚行動システム, コンピュータビジョン
# 研究課題数: 12
# 研究成果数: 184
# プロフィールURL: /nrid/1000060345113/
#
# --- 研究者 22 ---
# 氏名: 河原 吉伸  Kawahara Yoshinobu
# 研究者ID: 00514796
# 所属: 大阪大学, 大学院情報科学研究科, 教授
# キーワード: 機械学習, データマイニング, 組合せ最適化, 統計的推定, 超高次元データ
# 研究課題数: 22
# 研究成果数: 226
# プロフィールURL: /nrid/1000000514796/
#
# --- 研究者 23 ---
# 氏名: 猪口 明博  INOKUCHI Akihiro
# 研究者ID: 70452456
# 所属: 関西学院大学, 工学部, 教授
# キーワード: データマイニング, 機械学習, 人工知能, データベース, 知識発見
# 研究課題数: 15
# 研究成果数: 128
# プロフィールURL: /nrid/1000070452456/
#
# --- 研究者 24 ---
# 氏名: 柳澤 琢史  Yanagisawa Takufumi
# 研究者ID: 90533802
# 所属: 大阪大学, 大学院医学系研究科, 教授
# キーワード: 脳磁図, 皮質脳波, Brain-machine interface, ブレイン・デコーディング, 電動義手
# 研究課題数: 17
# 研究成果数: 483
# プロフィールURL: /nrid/1000090533802/
#
# --- 研究者 25 ---
# 氏名: 田中 剛平  Tanaka Gohei
# 研究者ID: 90444075
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 教授
# キーワード: 機械学習, 数理モデル, ニューラルネットワーク, 画像処理, 人工知能
# 研究課題数: 7
# 研究成果数: 119
# プロフィールURL: /nrid/1000090444075/
#
# --- 研究者 26 ---
# 氏名: 内部 英治  UCHIBE Eiji
# 研究者ID: 20426571
# 所属: 株式会社国際電気通信基礎技術研究所, 脳情報通信総合研究所, 主幹研究員
# キーワード: 強化学習, 逆強化学習, モデルフリー, モデルベース, 線形可解マルコフ決定過程
# 研究課題数: 7
# 研究成果数: 83
# プロフィールURL: /nrid/1000020426571/
#
# --- 研究者 27 ---
# 氏名: 荒牧 英治  ARAMAKI EIJI
# 研究者ID: 70401073
# 所属: 奈良先端科学技術大学院大学, 先端科学技術研究科, 教授
# キーワード: 自然言語処理, 機械学習, 医療情報学, 医療情報, 情報システム
# 研究課題数: 23
# 研究成果数: 210
# プロフィールURL: /nrid/1000070401073/
#
# --- 研究者 28 ---
# 氏名: 松尾 豊  Matsuo Yutaka
# 研究者ID: 30358014
# 所属: 東京大学, 大学院工学系研究科(工学部), 教授
# キーワード: 人工知能, Webマイニング, 人口知能, テキストマイニング, 社会ネットワーク
# 研究課題数: 10
# 研究成果数: 63
# プロフィールURL: /nrid/1000030358014/
#
# --- 研究者 29 ---
# 氏名: 佐藤 一誠  Satou Issei
# 研究者ID: 90610155
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: 機械学習, プライバシー保護, 深層学習, データマイニング, アルゴリズム
# 研究課題数: 10
# 研究成果数: 58
# プロフィールURL: /nrid/1000090610155/
#
# --- 研究者 30 ---
# 氏名: 西本 伸志  Nishimoto Shinji
# 研究者ID: 00713455
# 所属: 大阪大学, 大学院生命機能研究科, 教授
# キーワード: fMRI, 神経科学, 大脳皮質, 視覚, 予測モデル
# 研究課題数: 14
# 研究成果数: 267
# プロフィールURL: /nrid/1000000713455/
#
# --- 研究者 31 ---
# 氏名: 高道 慎之介  Shinnosuke Takamichi
# 研究者ID: 90784330
# 所属: 慶應義塾大学, 理工学部(矢上), 准教授
# キーワード: 音声情報処理, 音声翻訳, 音声合成, 機械学習, 深層学習
# 研究課題数: 13
# 研究成果数: 121
# プロフィールURL: /nrid/1000090784330/
#
# --- 研究者 32 ---
# 氏名: ＰＲＥＮＤＩＮＧＥＲ ＨＥＬＭＵ  Prendinger Helmut
# 研究者ID: 40390596
# 所属: 国立情報学研究所, コンテンツ科学研究系, 教授
# キーワード: 人工知能, ユーザインタフェース, エージェント, 感性情報学, モデル化
# 研究課題数: 4
# 研究成果数: 45
# プロフィールURL: /nrid/1000040390596/
#
# --- 研究者 33 ---
# 氏名: 久保 孝富  Kubo Takatomi
# 研究者ID: 20631550
# 所属: 奈良先端科学技術大学院大学, 先端科学技術研究科, 准教授
# キーワード: ノンパラメトリックベイズ法, 時系列分節化, 機械学習, 深層学習, 表面筋電位信号
# 研究課題数: 7
# 研究成果数: 29
# プロフィールURL: /nrid/1000020631550/
#
# --- 研究者 34 ---
# 氏名: 森本 淳  MORIMOTO Jun
# 研究者ID: 10505986
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 強化学習, 機械学習, ロボティクス, 意思決定, 計算神経科学
# 研究課題数: 8
# 研究成果数: 110
# プロフィールURL: /nrid/1000010505986/
#
# --- 研究者 35 ---
# 氏名: 岡 夏樹  OKA Natsuki
# 研究者ID: 20362585
# 所属: 宮崎産業経営大学, 経営学部, 教授
# キーワード: 認知科学, 人工知能, エージェント, 言語獲得, 機械学習
# 研究課題数: 16
# 研究成果数: 218
# プロフィールURL: /nrid/1000020362585/
#
# --- 研究者 36 ---
# 氏名: 柳井 広之  ヤナイ ヒロユキ
# 研究者ID: 90379735
# 所属: 岡山大学, 医療開発領域, 教授
# キーワード: 乳癌, コンピュテーショナルフォトグラフィ, 機会学習, 医療画像処理, 機械学習
# 研究課題数: 3
# 研究成果数: 0
# プロフィールURL: /nrid/1000090379735/
#
# --- 研究者 37 ---
# 氏名: 小林 一樹  Kobayashi Kazuki
# 研究者ID: 00434895
# 所属: 信州大学, 学術研究院工学系, 教授
# キーワード: エージェント, 認知科学, 人工知能, 深層学習, ユーザインターフェース
# 研究課題数: 13
# 研究成果数: 196
# プロフィールURL: /nrid/1000000434895/
#
# --- 研究者 38 ---
# 氏名: 大石 直也  Oishi Naoya
# 研究者ID: 40526878
# 所属: 京都大学, 医学研究科, 准教授
# キーワード: MRI, 深層学習, 脳, 数値解析, 逆問題
# 研究課題数: 30
# 研究成果数: 185
# プロフィールURL: /nrid/1000040526878/
#
# --- 研究者 39 ---
# 氏名: 佐々木 智也  Sasaki Tomoya
# 研究者ID: 20979596
# 所属: 東京理科大学, 先進工学部機能デザイン工学科, 助教
# キーワード: バーチャルリアリティ, 呼吸機能, 空間認知機能, 嚥下機能, 介入効果
# 研究課題数: 4
# 研究成果数: 3
# プロフィールURL: /nrid/1000020979596/
#
# --- 研究者 40 ---
# 氏名: 細谷 晴夫  Hosoya Haruo
# 研究者ID: 50335296
# 所属: 株式会社国際電気通信基礎技術研究所, 脳情報通信総合研究所, 主任研究員
# キーワード: 深層生成学習, 機械学習, XML, ツリーオートマトン, 型検査
# 研究課題数: 9
# 研究成果数: 65
# プロフィールURL: /nrid/1000050335296/
#
# --- 研究者 41 ---
# 氏名: 竹内 純一  Takeuchi Jun'ichi
# 研究者ID: 80432871
# 所属: 九州大学, システム情報科学研究院, 教授
# キーワード: 圧縮センシング, 深層学習, 確率的コンプレキシティ, 超解像, スパース重ね合わせ符号
# 研究課題数: 10
# 研究成果数: 106
# プロフィールURL: /nrid/1000080432871/
#
# --- 研究者 42 ---
# 氏名: 村田 昇  MURATA Noboru
# 研究者ID: 60242038
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 機械学習, 情報幾何学, 汎化誤差, 独立成分分析, 情報幾何
# 研究課題数: 22
# 研究成果数: 93
# プロフィールURL: /nrid/1000060242038/
#
# --- 研究者 43 ---
# 氏名: 小林 一郎  Kobayashi Ichiro
# 研究者ID: 60281440
# 所属: お茶の水女子大学, 基幹研究院, 教授
# キーワード: 脳内情報解読, fMRI, 自然言語処理, 時系列データ, テキスト生成
# 研究課題数: 22
# 研究成果数: 250
# プロフィールURL: /nrid/1000060281440/
#
# --- 研究者 44 ---
# 氏名: 永田 賢二  Nagata Kenji
# 研究者ID: 10556062
# 所属: 国立研究開発法人物質・材料研究機構, マテリアル基盤研究センター, 主任研究員
# キーワード: 機械学習, スペクトル分解, マルコフ連鎖モンテカルロ法, ベイズ推論, 交換モンテカルロ法
# 研究課題数: 9
# 研究成果数: 178
# プロフィールURL: /nrid/1000010556062/
#
# --- 研究者 45 ---
# 氏名: 渡辺 太郎  Watanabe Taro
# 研究者ID: 90395038
# 所属: 奈良先端科学技術大学院大学, 先端科学技術研究科, 教授
# キーワード: 自然言語処理, 知識グラフ, 統計的機械翻訳, 機械学習, 識別学習
# 研究課題数: 4
# 研究成果数: 12
# プロフィールURL: /nrid/1000090395038/
#
# --- 研究者 46 ---
# 氏名: 船水 章大  Funamizu Akihiro
# 研究者ID: 20724397
# 所属: 東京大学, 定量生命科学研究所, 講師
# キーワード: マウス, 強化学習, 光遺伝学, 二光子顕微鏡, 神経科学
# 研究課題数: 14
# 研究成果数: 68
# プロフィールURL: /nrid/1000020724397/
#
# --- 研究者 47 ---
# 氏名: 岩橋 直人  IWAHASHI Naoto
# 研究者ID: 90394999
# 所属: 岡山県立大学, 情報工学部, 教授
# キーワード: 生活支援ロボット, 言語獲得, 機械学習, 認知科学, 知能ロボティクス
# 研究課題数: 7
# 研究成果数: 87
# プロフィールURL: /nrid/1000090394999/
#
# --- 研究者 48 ---
# 氏名: 杉原 玄一  Sugihara Genichi
# 研究者ID: 70402261
# 所属: 東京科学大学, 大学院医歯学総合研究科, 准教授
# キーワード: MRI, 統合失調症, 脳画像, 深層学習, 神経画像
# 研究課題数: 28
# 研究成果数: 147
# プロフィールURL: /nrid/1000070402261/
#
# --- 研究者 49 ---
# 氏名: 須藤 克仁  Sudoh Katsuhito
# 研究者ID: 00396152
# 所属: 奈良女子大学, 生活環境科学系, 教授
# キーワード: 自然言語処理, 音声翻訳, 機械翻訳, 深層学習, 統計的機械翻訳
# 研究課題数: 7
# 研究成果数: 91
# プロフィールURL: /nrid/1000000396152/
#
# --- 研究者 50 ---
# 氏名: 林 隆介  HAYASHI Ryusuke
# 研究者ID: 80444470
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: 神経科学, 視覚情報処理, 顔認識, 深層学習, 物体認識
# 研究課題数: 11
# 研究成果数: 111
# プロフィールURL: /nrid/1000080444470/
#
# --- 研究者 51 ---
# 氏名: 長尾 大道  NAGAO Hiromichi
# 研究者ID: 80435833
# 所属: 東京大学, 地震研究所, 准教授
# キーワード: データ同化, 地震, ベイズ統計学, 疎性モデリング, マルコフ連鎖モンテカルロ法
# 研究課題数: 17
# 研究成果数: 349
# プロフィールURL: /nrid/1000080435833/
#
# --- 研究者 52 ---
# 氏名: 寺田 和憲  TERADA Kazunori
# 研究者ID: 30345798
# 所属: 岐阜大学, 工学部, 教授
# キーワード: ヒューマンエージェントインタラクション, 認知科学, 深層学習, ロボット, 心の理論
# 研究課題数: 18
# 研究成果数: 173
# プロフィールURL: /nrid/1000030345798/
#
# --- 研究者 53 ---
# 氏名: 田宮 元  Tamiya Gen
# 研究者ID: 10317745
# 所属: 東北大学, 医学系研究科, 教授
# キーワード: ゲノム, HLA, マイクロサテライトマーカー, 連鎖不平衡, 遺伝子
# 研究課題数: 28
# 研究成果数: 173
# プロフィールURL: /nrid/1000010317745/
#
# --- 研究者 54 ---
# 氏名: 大森 敏明  OMORI TOSHIAKI
# 研究者ID: 10391898
# 所属: 神戸大学, 工学研究科, 准教授
# キーワード: 機械学習, 理論神経科学, データ駆動科学, ベイズ推論, 統計的機械学習
# 研究課題数: 14
# 研究成果数: 562
# プロフィールURL: /nrid/1000010391898/
#
# --- 研究者 55 ---
# 氏名: 下川辺 隆史  Shimokawabe Takashi
# 研究者ID: 40636049
# 所属: 東京大学, 情報基盤センター, 准教授
# キーワード: GPU, 高性能計算, 適合細分化格子法, 高生産フレームワーク, 機械学習
# 研究課題数: 12
# 研究成果数: 220
# プロフィールURL: /nrid/1000040636049/
#
# --- 研究者 56 ---
# 氏名: 日野 英逸  Hino Hideitsu
# 研究者ID: 10580079
# 所属: 統計数理研究所, 先端データサイエンス研究系, 教授
# キーワード: 機械学習, 情報幾何, 差分プライバシー, 可視化, 多変量解析
# 研究課題数: 24
# 研究成果数: 187
# プロフィールURL: /nrid/1000010580079/
#
# --- 研究者 57 ---
# 氏名: 八杉 公基  Yasugi Masaki
# 研究者ID: 50722790
# 所属: 福井県立大学, 海洋生物資源学部, 准教授
# キーワード: 魚類, 行動, 認知, メダカ, 動物行動
# 研究課題数: 7
# 研究成果数: 198
# プロフィールURL: /nrid/1000050722790/
#
# --- 研究者 58 ---
# 氏名: 川上 英良  Kawakami Eiryo
# 研究者ID: 30725338
# 所属: 千葉大学, 大学院医学研究院, 教授
# キーワード: 人工知能, AI, 機械学習, 人工股関節全置換術, マイクロRNA
# 研究課題数: 21
# 研究成果数: 46
# プロフィールURL: /nrid/1000030725338/
#
# --- 研究者 59 ---
# 氏名: 大関 真之  Ohzeki Masayuki
# 研究者ID: 80447549
# 所属: 東北大学, 情報科学研究科, 教授
# キーワード: 量子アニーリング, 最適化問題, 機械学習, 統計力学, 非平衡統計力学
# 研究課題数: 12
# 研究成果数: 540
# プロフィールURL: /nrid/1000080447549/
#
# --- 研究者 60 ---
# 氏名: 福水 健次  fukumizu kenji
# 研究者ID: 60311362
# 所属: 統計数理研究所, 先端データサイエンス研究系, 教授
# キーワード: 機械学習, カーネル法, アルゴリズム, 時系列解析, スパースモデリング
# 研究課題数: 15
# 研究成果数: 228
# プロフィールURL: /nrid/1000060311362/
#
# --- 研究者 61 ---
# 氏名: 張 耀中  Zhang Yaozhong
# 研究者ID: 60817138
# 所属: 東京大学, 医科学研究所, 准教授
# キーワード: がん, システム生物学, 統計的モデリング, バイオインフォマティクス, 人工知能
# 研究課題数: 2
# 研究成果数: 21
# プロフィールURL: /nrid/1000060817138/
#
# --- 研究者 62 ---
# 氏名: 吉仲 亮  Ryo Yoshinaka
# 研究者ID: 80466424
# 所属: 東北大学, 情報科学研究科, 准教授
# キーワード: 文法推論, 分布学習, 計算論的学習, 計算論的学習理論, データ構造
# 研究課題数: 16
# 研究成果数: 159
# プロフィールURL: /nrid/1000080466424/
#
# --- 研究者 63 ---
# 氏名: 岡谷 貴之  OKATANI TAKAYUKI
# 研究者ID: 00312637
# 所属: 東北大学, 情報科学研究科, 教授
# キーワード: コンピュータビジョン, 画像認識, 能動視覚, ロボット視覚, ステレオ
# 研究課題数: 20
# 研究成果数: 360
# プロフィールURL: /nrid/1000000312637/
#
# --- 研究者 64 ---
# 氏名: 小林 透  KOBAYASHI Toru
# 研究者ID: 90637399
# 所属: 駒澤大学, グローバル・メディア・スタディーズ学部, 教授
# キーワード: IoT, AI, ドローン, 関節リウマチ, 人工知能（AI）
# 研究課題数: 12
# 研究成果数: 155
# プロフィールURL: /nrid/1000090637399/
#
# --- 研究者 65 ---
# 氏名: 藤井 慶輔  Fujii Keisuke
# 研究者ID: 70747401
# 所属: 名古屋大学, 情報学研究科, 准教授
# キーワード: 機械学習, スポーツ科学, 集団運動, スポーツ, 身体運動
# 研究課題数: 11
# 研究成果数: 128
# プロフィールURL: /nrid/1000070747401/
#
# --- 研究者 66 ---
# 氏名: 舟橋 啓  FUNAHASHI Akira
# 研究者ID: 70324548
# 所属: 慶應義塾大学, 理工学部(矢上), 教授
# キーワード: 生体生命情報学, 画像解析, 機械学習, システムバイオロジー, 深層学習
# 研究課題数: 23
# 研究成果数: 154
# プロフィールURL: /nrid/1000070324548/
#
# --- 研究者 67 ---
# 氏名: 室岡 雅樹  Murooka Masaki
# 研究者ID: 70825017
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: ヒューマノイド, マニピュレーション, 最適化, 動作計画, ロボット
# 研究課題数: 5
# 研究成果数: 6
# プロフィールURL: /nrid/1000070825017/
#
# --- 研究者 68 ---
# 氏名: 玉田 嘉紀  Tamada Yoshinori
# 研究者ID: 80435495
# 所属: 弘前大学, 医学研究科, 教授
# キーワード: 機械学習, がん, システム生物学, バイオインフォマティクス, 統計的モデリング
# 研究課題数: 7
# 研究成果数: 21
# プロフィールURL: /nrid/1000080435495/
#
# --- 研究者 69 ---
# 氏名: 中井 智也  Nakai Tomoya
# 研究者ID: 60781250
# 所属: 株式会社アラヤ(研究開発部), 研究開発部, チーフリサーチャー
# キーワード: 言語, MRI, fMRI, 機械学習, ニューラルネット
# 研究課題数: 6
# 研究成果数: 48
# プロフィールURL: /nrid/1000060781250/
#
# --- 研究者 70 ---
# 氏名: 山田 誠二  YAMADA Seiji
# 研究者ID: 50220380
# 所属: 国立情報学研究所, コンテンツ科学研究系, 教授
# キーワード: 人工知能, 機械学習, エージェント, 認知科学, ヒューマンインタフェース
# 研究課題数: 29
# 研究成果数: 192
# プロフィールURL: /nrid/1000050220380/
#
# --- 研究者 71 ---
# 氏名: 香取 勇一  KATORI Yuichi
# 研究者ID: 20557607
# 所属: 公立はこだて未来大学, システム情報科学部, 教授
# キーワード: リザバー計算, レザバー計算, ニューラルネットワーク, 脳型人工知能, 計算論的神経科学
# 研究課題数: 11
# 研究成果数: 165
# プロフィールURL: /nrid/1000020557607/
#
# --- 研究者 72 ---
# 氏名: 玉木 徹  Tamaki Toru
# 研究者ID: 10333494
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 教授
# キーワード: コンピュータビジョン, 画像認識, 計算機システム, 集積回路, ハード・ソフト協調設計
# 研究課題数: 15
# 研究成果数: 423
# プロフィールURL: /nrid/1000010333494/
#
# --- 研究者 73 ---
# 氏名: 宮脇 陽一  MIYAWAKI Yoichi
# 研究者ID: 80373372
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: 脳・神経, 機械学習, 認知科学, 脳機能計測, 視覚
# 研究課題数: 13
# 研究成果数: 111
# プロフィールURL: /nrid/1000080373372/
#
# --- 研究者 74 ---
# 氏名: 池田 思朗  ikeda shiro
# 研究者ID: 30336101
# 所属: 統計数理研究所, 先端データサイエンス研究系, 教授
# キーワード: 確率伝搬法, 情報幾何学, 情報幾何, 統計物理学, グラフ
# 研究課題数: 14
# 研究成果数: 154
# プロフィールURL: /nrid/1000030336101/
#
# --- 研究者 75 ---
# 氏名: 三村 和史  MIMURA Kazushi
# 研究者ID: 40353297
# 所属: 広島市立大学, 情報科学研究科, 教授
# キーワード: 経路積分法, 情報統計力学, 情報理論, 圧縮センシング, 統計力学
# 研究課題数: 12
# 研究成果数: 154
# プロフィールURL: /nrid/1000040353297/
#
# --- 研究者 76 ---
# 氏名: 中原 裕之  Nakahara Hiroyuki
# 研究者ID: 10312282
# 所属: 国立研究開発法人理化学研究所, 脳神経科学研究センター, チームディレクター
# キーワード: 強化学習, 神経科学, 人工知能, 数理工学, 情報工学
# 研究課題数: 19
# 研究成果数: 142
# プロフィールURL: /nrid/1000010312282/
#
# --- 研究者 77 ---
# 氏名: 福永 津嵩  FUKUNAGA Tsukasa
# 研究者ID: 80791433
# 所属: 慶應義塾大学, 理工学部(矢上), 准教授
# キーワード: アルゴリズム, lncRNA, 遺伝子機能推定, 確率モデル, 機能未知遺伝子
# 研究課題数: 6
# 研究成果数: 23
# プロフィールURL: /nrid/1000080791433/
#
# --- 研究者 78 ---
# 氏名: 池上 高志  Ikegami Takashi
# 研究者ID: 10211715
# 所属: 東京大学, 大学院総合文化研究科, 教授
# キーワード: 人工生命, 進化, 力学系, ゲーム, 移送エントロピー
# 研究課題数: 33
# 研究成果数: 307
# プロフィールURL: /nrid/1000010211715/
#
# --- 研究者 79 ---
# 氏名: 内田 誠一  UCHIDA Seiichi
# 研究者ID: 70315125
# 所属: 九州大学, システム情報科学研究院, 教授
# キーワード: 文字認識, パターン認識, 機械学習, 動的計画法, 深層学習
# 研究課題数: 32
# 研究成果数: 672
# プロフィールURL: /nrid/1000070315125/
#
# --- 研究者 80 ---
# 氏名: 申 吉浩  Shin Yoshihiro
# 研究者ID: 60523587
# 所属: 学習院大学, 付置研究所, 教授
# キーワード: 機械学習, データマイニング, アルゴリズム, クラスタリング, 簡潔データ構造
# 研究課題数: 12
# 研究成果数: 134
# プロフィールURL: /nrid/1000060523587/
#
# --- 研究者 81 ---
# 氏名: 小渕 智之  Obuchi Tomoyuki
# 研究者ID: 40588448
# 所属: 京都大学, 情報学研究科, 准教授
# キーワード: 機械学習, レプリカ法, 情報統計力学, スパースモデリング, ニューラルネットワーク
# 研究課題数: 8
# 研究成果数: 130
# プロフィールURL: /nrid/1000040588448/
#
# --- 研究者 82 ---
# 氏名: 前田 英作  Maeda Eisaku
# 研究者ID: 90396143
# 所属: 東京電機大学, システムデザイン工学部, 教授
# キーワード: 機械学習, 学習科学, 認知科学, 知能ロボティクス, 教育工学
# 研究課題数: 5
# 研究成果数: 97
# プロフィールURL: /nrid/1000090396143/
#
# --- 研究者 83 ---
# 氏名: 小林 泰介  Kobayashi Taisuke
# 研究者ID: 10796452
# 所属: 国立情報学研究所, 情報学プリンシプル研究系, 助教
# キーワード: 強化学習, 2自由度制御, ネットワーク制御, 適応学習, 切り替え系
# 研究課題数: 7
# 研究成果数: 47
# プロフィールURL: /nrid/1000010796452/
#
# --- 研究者 84 ---
# 氏名: 鮎澤 光  Ayusawa Ko
# 研究者ID: 60649086
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 上級主任研究員
# キーワード: 運動最適化, 動力学計算, システム同定, 運動解析, 運動計画
# 研究課題数: 7
# 研究成果数: 38
# プロフィールURL: /nrid/1000060649086/
#
# --- 研究者 85 ---
# 氏名: 林部 充宏  Hayashibe Mitsuhiro
# 研究者ID: 40338934
# 所属: 東北大学, 工学研究科, 教授
# キーワード: 運動シナジー, 深層学習, 運動学習, 手術ロボット, 知能ロボティクス
# 研究課題数: 10
# 研究成果数: 158
# プロフィールURL: /nrid/1000040338934/
#
# --- 研究者 86 ---
# 氏名: 山川 宏  Yamakawa Hiroshi
# 研究者ID: 00417495
# 所属: 玉川大学, 脳科学研究所, 研究員
# キーワード: 全脳アーキテクチャ, 脳参照アーキテクチャ, 脳情報フロー, 脳型人工知能, 並列計算
# 研究課題数: 2
# 研究成果数: 26
# プロフィールURL: /nrid/1000000417495/
#
# --- 研究者 87 ---
# 氏名: 間木 重行  Magi Shigeyuki
# 研究者ID: 90708546
# 所属: 東邦大学, 医学部, 助教
# キーワード: 乳がん, 薬剤耐性, 一細胞解析, がん, 数理モデル
# 研究課題数: 4
# 研究成果数: 37
# プロフィールURL: /nrid/1000090708546/
#
# --- 研究者 88 ---
# 氏名: 道喜 将太郎  Doki Shotaro
# 研究者ID: 60808781
# 所属: 筑波大学, 医学医療系, 助教
# キーワード: メンタルヘルス, fNIRS, SOC, 職域, 勤労者
# 研究課題数: 7
# 研究成果数: 38
# プロフィールURL: /nrid/1000060808781/
#
# --- 研究者 89 ---
# 氏名: 烏山 昌幸  Karasuyama Masayuki
# 研究者ID: 40628640
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 准教授
# キーワード: 機械学習, グラフ, バイオインフォマティクス, 半教師付き学習, 凸最適化
# 研究課題数: 9
# 研究成果数: 81
# プロフィールURL: /nrid/1000040628640/
#
# --- 研究者 90 ---
# 氏名: 末谷 大道  Suetani Hiromichi
# 研究者ID: 40507167
# 所属: 大分大学, 理工学部, 教授
# キーワード: 多様体学習, カオス, 脳波, ニューラルネットワーク, 時系列解析
# 研究課題数: 18
# 研究成果数: 127
# プロフィールURL: /nrid/1000040507167/
#
# --- 研究者 91 ---
# 氏名: 小野 峻佑  Ono Shunsuke
# 研究者ID: 60752269
# 所属: 東京科学大学, 情報理工学院, 准教授
# キーワード: 信号処理, 凸最適化, グラフ信号処理, 機械学習, 計測データ解析
# 研究課題数: 15
# 研究成果数: 138
# プロフィールURL: /nrid/1000060752269/
#
# --- 研究者 92 ---
# 氏名: 鈴木 真介  SUZUKI SHINSUKE
# 研究者ID: 90525578
# 所属: 一橋大学, 大学院ソーシャル・データサイエンス研究科, 教授
# キーワード: fMRI, 計算論的精神医学, 神経経済学, 脳情報デコーディング, 精神疾患
# 研究課題数: 6
# 研究成果数: 51
# プロフィールURL: /nrid/1000090525578/
#
# --- 研究者 93 ---
# 氏名: 大関 洋平  Oseki Yohei
# 研究者ID: 10821994
# 所属: 東京大学, 大学院総合文化研究科, 准教授
# キーワード: 自然言語処理, 認知科学, 言語学, 形態論, 理論言語学
# 研究課題数: 16
# 研究成果数: 70
# プロフィールURL: /nrid/1000010821994/
#
# --- 研究者 94 ---
# 氏名: 岡田 将吾  Okada Shogo
# 研究者ID: 00512261
# 所属: 北陸先端科学技術大学院大学, 先端科学技術研究科, 教授
# キーワード: 機械学習, データマイニング, マルチモーダルインタラクション, マルチモーダルインタフェース, 社会的信号処理
# 研究課題数: 13
# 研究成果数: 204
# プロフィールURL: /nrid/1000000512261/
#
# --- 研究者 95 ---
# 氏名: 高橋 恒一  Takahashi Koichi
# 研究者ID: 20514508
# 所属: 国立研究開発法人理化学研究所, 生命機能科学研究センター, チームディレクター
# キーワード: 並列計算, 並列化, シミュレーション, 細胞生物学, 細胞
# 研究課題数: 4
# 研究成果数: 12
# プロフィールURL: /nrid/1000020514508/
#
# --- 研究者 96 ---
# 氏名: 西出 俊  Nishide Shun
# 研究者ID: 30613400
# 所属: 京都橘大学, 工学部, 准教授
# キーワード: 神経回路モデル, 知能ロボティクス, 認知発達ロボティクス, アフォーダンス, 神経力学モデル
# 研究課題数: 6
# 研究成果数: 133
# プロフィールURL: /nrid/1000030613400/
#
# --- 研究者 97 ---
# 氏名: 池田 和司  Ikeda Kazushi
# 研究者ID: 10262552
# 所属: 奈良先端科学技術大学院大学, 先端科学技術研究科, 教授
# キーワード: 機械学習, 学習理論, 情報幾何学, コインシデンス・ディテクタ, ニューラルネットワーク
# 研究課題数: 19
# 研究成果数: 130
# プロフィールURL: /nrid/1000010262552/
#
# --- 研究者 98 ---
# 氏名: 平山 淳一郎  Hirayama Jun-ichiro
# 研究者ID: 80512269
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: 機械学習, 生体信号処理, 脳機能イメージング, ブレイン・マシンインターフェイス, 脳波
# 研究課題数: 9
# 研究成果数: 58
# プロフィールURL: /nrid/1000080512269/
#
# --- 研究者 99 ---
# 氏名: 大渕 竜太郎  OHBUCHI Ryutarou
# 研究者ID: 80313782
# 所属: 山梨大学, 大学院総合研究部, 教授
# キーワード: 機械学習, マルチメディア検索, 3次元グラフィックス, 3次元形状検索, 形状モデリング
# 研究課題数: 12
# 研究成果数: 154
# プロフィールURL: /nrid/1000080313782/
#
# --- 研究者 100 ---
# 氏名: 竹内 一郎  TAKEUCHI Ichiro
# 研究者ID: 40335146
# 所属: 名古屋大学, 工学研究科, 教授
# キーワード: 機械学習, データマイニング, 統計科学, 分位点回帰分析, カーネル法
# 研究課題数: 17
# 研究成果数: 258
# プロフィールURL: /nrid/1000040335146/
#
# --- 研究者 101 ---
# 氏名: 石井 雅樹  Ishii Masaki
# 研究者ID: 10390907
# 所属: 秋田県立大学, システム科学技術学部, 教授
# キーワード: 表情認識, 顔画像処理, 機械学習, 認知科学, 感性情報学
# 研究課題数: 6
# 研究成果数: 47
# プロフィールURL: /nrid/1000010390907/
#
# --- 研究者 102 ---
# 氏名: 三村 喬生  Mimura Koki
# 研究者ID: 60747377
# 所属: 国立研究開発法人国立精神・神経医療研究センター, 神経研究所 疾病研究第三部, 室長
# キーワード: 社会性, 霊長類, 化学遺伝学, 自閉症, モーション解析
# 研究課題数: 5
# 研究成果数: 40
# プロフィールURL: /nrid/1000060747377/
#
# --- 研究者 103 ---
# 氏名: 長谷山 美紀  Haseyama Miki
# 研究者ID: 00218463
# 所属: 北海道大学, 情報科学研究院, 教授
# キーワード: 遺伝的アルゴリズム, 画像解析, IFS, 画像検索, 領域分割
# 研究課題数: 20
# 研究成果数: 1121
# プロフィールURL: /nrid/1000000218463/
#
# --- 研究者 104 ---
# 氏名: 川島 英之  Kawashima Hideyuki
# 研究者ID: 90407148
# 所属: 慶應義塾大学, 環境情報学部(藤沢), 教授
# キーワード: データベース, 情報統合, 機械学習, ストリーム処理, トランザクション
# 研究課題数: 20
# 研究成果数: 207
# プロフィールURL: /nrid/1000090407148/
#
# --- 研究者 105 ---
# 氏名: 庄野 逸  Shouno Hayaru
# 研究者ID: 50263231
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: 神経回路モデル, ベイズ推定, びまん性肺疾患, ディープラーニング, MDCT
# 研究課題数: 19
# 研究成果数: 204
# プロフィールURL: /nrid/1000050263231/
#
# --- 研究者 106 ---
# 氏名: 瀧川 一学  Takigawa Ichigaku
# 研究者ID: 10374597
# 所属: 東京大学, 大学院新領域創成科学研究科, 教授
# キーワード: 機械学習, アルゴリズム, グラフ, 離散構造, 最適化
# 研究課題数: 20
# 研究成果数: 326
# プロフィールURL: /nrid/1000010374597/
#
# --- 研究者 107 ---
# 氏名: 小松 三佐子  KOMATSU M
# 研究者ID: 00525545
# 所属: 東京科学大学, 総合研究院, 特任准教授
# キーワード: ECoG, マーモセット, 皮質脳波, 神経科学, 非ヒト霊長類
# 研究課題数: 6
# 研究成果数: 56
# プロフィールURL: /nrid/1000000525545/
#
# --- 研究者 108 ---
# 氏名: 藤吉 弘亘  FUJIYOSHI Hironobu
# 研究者ID: 20333172
# 所属: 中部大学, 理工学部, 教授
# キーワード: 創造性, 工学教育, 創造性評価, 動作認識, LEGO Mindstorms
# 研究課題数: 6
# 研究成果数: 76
# プロフィールURL: /nrid/1000020333172/
#
# --- 研究者 109 ---
# 氏名: 銅谷 賢治  DOYA Kenji
# 研究者ID: 80188846
# 所属: 沖縄科学技術大学院大学, 神経計算ユニット, 教授
# キーワード: 脳科学, 強化学習, 人工知能, 研究提携, 統合的脳研究
# 研究課題数: 13
# 研究成果数: 397
# プロフィールURL: /nrid/1000080188846/
#
# --- 研究者 110 ---
# 氏名: 梶岡 慎輔  KAJIOKA Shinsuke
# 研究者ID: 40609517
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 助教
# キーワード: 地理情報システム, BLEビーコン, 屋内位置推定, 機械学習, 軌跡マイニング
# 研究課題数: 3
# 研究成果数: 7
# プロフィールURL: /nrid/1000040609517/
#
# --- 研究者 111 ---
# 氏名: 太田 禎生  Ota Sadao
# 研究者ID: 70731214
# 所属: 東京大学, 先端科学技術研究センター, 教授
# キーワード: マイクロ・ナノデバイス, ネットワーク化計測, バーコーディング, 機械学習, サイトメトリー
# 研究課題数: 9
# 研究成果数: 6
# プロフィールURL: /nrid/1000070731214/
#
# --- 研究者 112 ---
# 氏名: 鮫島 正樹  SAMEJIMA Masaki
# 研究者ID: 80564690
# 所属: 大阪大学, 情報科学研究科, 助教
# キーワード: クラウドコンピューティング, 機械学習, ＩＴリスク, リスクコミュニケーション, 合意形成
# 研究課題数: 6
# 研究成果数: 43
# プロフィールURL: /nrid/1000080564690/
#
# --- 研究者 113 ---
# 氏名: 長岡 浩司  Nagaoka Hiroshi
# 研究者ID: 80192235
# 所属: 電気通信大学, その他部局等, 名誉教授
# キーワード: 情報幾何学, 情報理論, 情報幾何, 量子情報理論, 情報スペクトル
# 研究課題数: 13
# 研究成果数: 86
# プロフィールURL: /nrid/1000080192235/
#
# --- 研究者 114 ---
# 氏名: 赤穗 昭太郎  Akaho Shotaro
# 研究者ID: 40356340
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 上級主任研究員
# キーワード: 機械学習, 情報幾何, 情報幾何学, 推薦システム, カーネル法
# 研究課題数: 18
# 研究成果数: 196
# プロフィールURL: /nrid/1000040356340/
#
# --- 研究者 115 ---
# 氏名: 坂本 比呂志  Sakamoto Hiroshi
# 研究者ID: 50315123
# 所属: 九州工業大学, 大学院情報工学研究院, 教授
# キーワード: データ圧縮, 機械学習, 半構造データ, パターン発見, データマイニング
# 研究課題数: 32
# 研究成果数: 213
# プロフィールURL: /nrid/1000050315123/
#
# --- 研究者 116 ---
# 氏名: 松香 敏彦  Matsuka Toshihiko
# 研究者ID: 30466693
# 所属: 千葉大学, 大学院人文科学研究院, 教授
# キーワード: 認知科学, 認知モデル, 人工知能, 意思決定, カテゴリー
# 研究課題数: 10
# 研究成果数: 199
# プロフィールURL: /nrid/1000030466693/
#
# --- 研究者 117 ---
# 氏名: 野口 博史  Noguchi Hiroshi
# 研究者ID: 50431797
# 所属: 大阪公立大学, 大学院工学研究科 , 教授
# キーワード: 看護理工学, 看護工学, 褥瘡, 糖尿病足潰瘍, サーモグラフィ
# 研究課題数: 28
# 研究成果数: 175
# プロフィールURL: /nrid/1000050431797/
#
# --- 研究者 118 ---
# 氏名: 伊藤 篤  Ito Atsushi
# 研究者ID: 80500074
# 所属: 中央大学, 経済学部, 教授
# キーワード: 世界遺産, 言語景観, 翻訳, 観光, インバウンド
# 研究課題数: 8
# 研究成果数: 285
# プロフィールURL: /nrid/1000080500074/
#
# --- 研究者 119 ---
# 氏名: 岡部 誠  Okabe Makoto
# 研究者ID: 40557211
# 所属: 静岡大学, 工学部, 准教授
# キーワード: テクスチャ合成, コンピュータグラフィクス, 画像処理, マルチメディア技術, 音処理
# 研究課題数: 4
# 研究成果数: 66
# プロフィールURL: /nrid/1000040557211/
#
# --- 研究者 120 ---
# 氏名: 中村 泰  Nakamura Yutaka
# 研究者ID: 70403334
# 所属: 国立研究開発法人理化学研究所, 情報統合本部, チームディレクター
# キーワード: アンドロイド, 知能ロボティクス, 認知科学, ロボット, 強化学習
# 研究課題数: 15
# 研究成果数: 109
# プロフィールURL: /nrid/1000070403334/
#
# --- 研究者 121 ---
# 氏名: 神谷 之康  KAMITANI Yukiyasu
# 研究者ID: 50418513
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 認知科学, ブレイン・デコーディング, 視覚, 機能再建, 機能局在
# 研究課題数: 12
# 研究成果数: 162
# プロフィールURL: /nrid/1000050418513/
#
# --- 研究者 122 ---
# 氏名: 難波 大輔  Nanba Daisuke
# 研究者ID: 10380255
# 所属: 鳥取大学, 医学部, 教授
# キーワード: 表皮角化幹細胞, 表皮角化細胞, 幹細胞, 糖尿病, HB-EGF
# 研究課題数: 18
# 研究成果数: 116
# プロフィールURL: /nrid/1000010380255/
#
# --- 研究者 123 ---
# 氏名: 永井 岳大  Nagai Takehiro
# 研究者ID: 40549036
# 所属: 東京科学大学, 工学院, 准教授
# キーワード: 心理物理学, 色覚, 質感, 質感知覚, 脳波
# 研究課題数: 17
# 研究成果数: 103
# プロフィールURL: /nrid/1000040549036/
#
# --- 研究者 124 ---
# 氏名: 中島 昭彦  NAKAJIMA Akihiko
# 研究者ID: 90612119
# 所属: 東京大学, 大学院総合文化研究科, 助教
# キーワード: 細胞運動, 走化性, 粘菌, マイクロ流路, 適応
# 研究課題数: 6
# 研究成果数: 56
# プロフィールURL: /nrid/1000090612119/
#
# --- 研究者 125 ---
# 氏名: 萩原 良信  Hagiwara Yoshinobu
# 研究者ID: 20609416
# 所属: 創価大学, 理工学部, 准教授
# キーワード: 記号創発, 機械学習, 転移学習, 記号創発ロボティクス, 生活支援ロボット
# 研究課題数: 9
# 研究成果数: 161
# プロフィールURL: /nrid/1000020609416/
#
# --- 研究者 126 ---
# 氏名: 城口 克之  Shiroguchi Katsuyuki
# 研究者ID: 00454059
# 所属: 国立研究開発法人理化学研究所, 生命機能科学研究センター, チームディレクター
# キーワード: シークエンシング, １細胞解析, イメージング, 機械学習, バイオイメージング
# 研究課題数: 15
# 研究成果数: 81
# プロフィールURL: /nrid/1000000454059/
#
# --- 研究者 127 ---
# 氏名: 品川 政太朗  Shinagawa Seitaro
# 研究者ID: 70897454
# 所属: 奈良先端科学技術大学院大学, 先端科学技術研究科, 客員助教
# キーワード: 音声翻訳, 構造化された表現, 対話システム, 自然言語処理, Vision and Language
# 研究課題数: 2
# 研究成果数: 7
# プロフィールURL: /nrid/1000070897454/
#
# --- 研究者 128 ---
# 氏名: 南部 功夫  NAMBU Isao
# 研究者ID: 40553235
# 所属: 長岡技術科学大学, 工学研究科, 准教授
# キーワード: 脳波, BCI, 機械学習, 脳, fNIRS
# 研究課題数: 16
# 研究成果数: 135
# プロフィールURL: /nrid/1000040553235/
#
# --- 研究者 129 ---
# 氏名: 吉浦 康寿  Yoshiura Yasutoshi
# 研究者ID: 90372052
# 所属: 福井県立大学, 海洋生物資源学部, 教授
# キーワード: トラフグ, ゲノム編集, メダカ, 代理親魚技術, バイオセンサ
# 研究課題数: 11
# 研究成果数: 70
# プロフィールURL: /nrid/1000090372052/
#
# --- 研究者 130 ---
# 氏名: 五十田 博  ISODA HIROSHI
# 研究者ID: 40242664
# 所属: 京都大学, 生存圏研究所, 教授
# キーワード: 木質構造, 接合部, 建築構造・材料, モデル化, モニタリング
# 研究課題数: 14
# 研究成果数: 68
# プロフィールURL: /nrid/1000040242664/
#
# --- 研究者 131 ---
# 氏名: 児嶋 長次郎  Kojima Chojiro
# 研究者ID: 50333563
# 所属: 横浜国立大学, 大学院工学研究院, 教授
# キーワード: NMR, 立体構造, 構造生物学, 蛋白質, 分子認識
# 研究課題数: 34
# 研究成果数: 308
# プロフィールURL: /nrid/1000050333563/
#
# --- 研究者 132 ---
# 氏名: 河原 達也  Kawahara Tatsuya
# 研究者ID: 00234104
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 音声認識, 音声対話, 音声情報処理, HMM, 話し言葉
# 研究課題数: 54
# 研究成果数: 681
# プロフィールURL: /nrid/1000000234104/
#
# --- 研究者 133 ---
# 氏名: 石井 信  Ishii Shin
# 研究者ID: 90294280
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 強化学習, ベイズ推定, 意思決定, 計算論的神経科学, システム同定
# 研究課題数: 24
# 研究成果数: 335
# プロフィールURL: /nrid/1000090294280/
#
# --- 研究者 134 ---
# 氏名: 田口 亮  taguchi ryo
# 研究者ID: 70508415
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 准教授
# キーワード: 言語獲得, シンボルグラウンディング, ロボット, 音声情報処理, 機械学習
# 研究課題数: 7
# 研究成果数: 54
# プロフィールURL: /nrid/1000070508415/
#
# --- 研究者 135 ---
# 氏名: 吉永 司  Yoshinaga Tsukasa
# 研究者ID: 50824190
# 所属: 大阪大学, 大学院基礎工学研究科, 助教
# キーワード: 構音, 構音障害, 空力音, 声帯, 数値流体解析
# 研究課題数: 7
# 研究成果数: 64
# プロフィールURL: /nrid/1000050824190/
#
# --- 研究者 136 ---
# 氏名: 武石 啓成  Takeishi Yoshinari
# 研究者ID: 00963779
# 所属: 九州大学, システム情報科学研究院, 助教
# キーワード: スパース重ね合わせ符号, 符号理論, 通信路符号化, アダマール行列, 圧縮センシング
# 研究課題数: 3
# 研究成果数: 2
# プロフィールURL: /nrid/1000000963779/
#
# --- 研究者 137 ---
# 氏名: 宮武 勇登  Miyatake Yuto
# 研究者ID: 60757384
# 所属: 大阪大学, D3センター, 准教授
# キーワード: 数値解析, 微分方程式, 偏微分方程式, 数値線形代数, 深層学習
# 研究課題数: 8
# 研究成果数: 115
# プロフィールURL: /nrid/1000060757384/
#
# --- 研究者 138 ---
# 氏名: 沖米田 司  Okiyoneda Tsukasa
# 研究者ID: 90398248
# 所属: 関西学院大学, 生命環境学部, 教授
# キーワード: ユビキチンリガーゼ, CFTR, ユビキチン, タンパク質品質管理, 嚢胞性線維症
# 研究課題数: 10
# 研究成果数: 85
# プロフィールURL: /nrid/1000090398248/
#
# --- 研究者 139 ---
# 氏名: 吉留 崇  Yoshidome Takashi
# 研究者ID: 90456830
# 所属: 東北大学, 工学研究科, 准教授
# キーワード: 水和, 深層学習, タンパク質, F1-ATPase, 溶液理論
# 研究課題数: 7
# 研究成果数: 57
# プロフィールURL: /nrid/1000090456830/
#
# --- 研究者 140 ---
# 氏名: 谷藤 学  TANIFUJI Manabu
# 研究者ID: 60197530
# 所属: 国立研究開発法人理化学研究所, 脳神経科学研究センター, チームリーダー
# キーワード: カラム, 下側頭葉視覚連合野, 物体認識, 電位感受性色素, 顔認知
# 研究課題数: 12
# 研究成果数: 141
# プロフィールURL: /nrid/1000060197530/
#
# --- 研究者 141 ---
# 氏名: 本田 秀仁  Honda Hidehito
# 研究者ID: 60452017
# 所属: 追手門学院大学, 心理学部, 教授
# キーワード: 意思決定, インタラクション, コミュニケーション, 機械学習, 認知科学
# 研究課題数: 10
# 研究成果数: 149
# プロフィールURL: /nrid/1000060452017/
#
# --- 研究者 142 ---
# 氏名: 川嵜 圭祐  Kawasaki Keisuke
# 研究者ID: 60511178
# 所属: 新潟大学, 医歯学系, 准教授
# キーワード: 皮質脳波, 心の理論, マカクザル, 前頭葉, 視覚
# 研究課題数: 19
# 研究成果数: 131
# プロフィールURL: /nrid/1000060511178/
#
# --- 研究者 143 ---
# 氏名: 猿渡 洋  Saruwatari Hiroshi
# 研究者ID: 30324974
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: 音源分離, ブラインド音源分離, 音声合成, 音声情報処理, 音声認識
# 研究課題数: 20
# 研究成果数: 586
# プロフィールURL: /nrid/1000030324974/
#
# --- 研究者 144 ---
# 氏名: 桑谷 立  Kuwatani Tatsu
# 研究者ID: 60646785
# 所属: 国立研究開発法人海洋研究開発機構, 海域地震火山部門(火山・地球内部研究センター), センター長代理
# キーワード: スパースモデリング, データ駆動, 機械学習, ベイズ推論, 津波堆積物
# 研究課題数: 17
# 研究成果数: 221
# プロフィールURL: /nrid/1000060646785/
#
# --- 研究者 145 ---
# 氏名: 杉山 淳司  Sugiyama Junji
# 研究者ID: 40183842
# 所属: 京都大学, 農学研究科, 名誉教授
# キーワード: セルロース, セルロース合成酵素, 酢酸菌, 樹種同定, 樹種識別
# 研究課題数: 43
# 研究成果数: 274
# プロフィールURL: /nrid/1000040183842/
#
# --- 研究者 146 ---
# 氏名: 田中 健一郎  Tanaka Kenichiro
# 研究者ID: 70610640
# 所属: 東京科学大学, 情報理工学院, 教授
# キーワード: 深層学習, 数値積分, 関数近似, 行列関数, 二重指数関数型数値積分公式
# 研究課題数: 7
# 研究成果数: 78
# プロフィールURL: /nrid/1000070610640/
#
# --- 研究者 147 ---
# 氏名: 宮 冬樹  Miya Fuyuki
# 研究者ID: 50415311
# 所属: 慶應義塾大学, 医学部(信濃町), 准教授
# キーワード: ゲノム, 遺伝子, 脳神経疾患, エクソーム解析, 癌
# 研究課題数: 13
# 研究成果数: 129
# プロフィールURL: /nrid/1000050415311/
#
# --- 研究者 148 ---
# 氏名: 地村 弘二  Jimura Koji
# 研究者ID: 80431766
# 所属: 群馬大学, 情報学部, 教授
# キーワード: 前頭前野, 機能的MRI, 意思決定, 認知制御, 自己制御
# 研究課題数: 16
# 研究成果数: 56
# プロフィールURL: /nrid/1000080431766/
#
# --- 研究者 149 ---
# 氏名: 青嶋 誠  Aoshima Makoto
# 研究者ID: 90246679
# 所属: 筑波大学, 数理物質系, 教授
# キーワード: 逐次解析, 判別分析, 多変量解析, 漸近有効性, クラスタリング
# 研究課題数: 40
# 研究成果数: 502
# プロフィールURL: /nrid/1000090246679/
#
# --- 研究者 150 ---
# 氏名: 鄭 銀強  ZHENG YINQIANG
# 研究者ID: 30756896
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: コンピュータビジョン, コンピュテーショナルフォトグラフィ, Spectral Imaging, イメージング, コンピュテーショナルイメージング
# 研究課題数: 10
# 研究成果数: 45
# プロフィールURL: /nrid/1000030756896/
#
# --- 研究者 151 ---
# 氏名: 土居 裕和  DOI Hirokazu
# 研究者ID: 40437827
# 所属: 長岡技術科学大学, 工学研究科, 教授
# キーワード: ホルモン, 遺伝子多型, 発達障害, 脳機能, ASD
# 研究課題数: 24
# 研究成果数: 112
# プロフィールURL: /nrid/1000040437827/
#
# --- 研究者 152 ---
# 氏名: 西崎 博光  NISHIZAKI Hiromitsu
# 研究者ID: 40362082
# 所属: 山梨大学, 大学院総合研究部, 教授
# キーワード: 音声認識, 講義音声, 接客訓練, フィラー, 講演音声
# 研究課題数: 24
# 研究成果数: 277
# プロフィールURL: /nrid/1000040362082/
#
# --- 研究者 153 ---
# 氏名: 木賀 大介  Kiga Daisuke
# 研究者ID: 30376587
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 合成生物学, 遺伝暗号, 人工遺伝子回路, タンパク質, tRNA
# 研究課題数: 23
# 研究成果数: 242
# プロフィールURL: /nrid/1000030376587/
#
# --- 研究者 154 ---
# 氏名: 吉田 和子  YOSHIDA Wako
# 研究者ID: 30379599
# 所属: 株式会社国際電気通信基礎技術研究所, 脳情報通信総合研究所, 客員研究員
# キーワード: 前頭前野, 意思決定, 強化学習, 計算論的神経科学, 計算モデル
# 研究課題数: 7
# 研究成果数: 15
# プロフィールURL: /nrid/1000030379599/
#
# --- 研究者 155 ---
# 氏名: 金広 文男  Kanehiro Fumio
# 研究者ID: 70356806
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 連携研究ラボ長
# キーワード: 機械学習, 知能ロボティックス, 最適化, モーションプランニング, 多自由度ロボット
# 研究課題数: 6
# 研究成果数: 49
# プロフィールURL: /nrid/1000070356806/
#
# --- 研究者 156 ---
# 氏名: 太田 真理  Ohta Shinri
# 研究者ID: 20750045
# 所属: 九州大学, 人文科学研究院, 准教授
# キーワード: 言語, fMRI, 左下前頭回, 理論言語学, 経頭蓋電気刺激法
# 研究課題数: 8
# 研究成果数: 188
# プロフィールURL: /nrid/1000020750045/
#
# --- 研究者 157 ---
# 氏名: 高前田 伸也  YAMAZAKI SHINYA
# 研究者ID: 60738897
# 所属: 東京大学, 大学院情報理工学系研究科, 准教授
# キーワード: FPGA, 高位合成, Python, コンパイラ, 深層学習
# 研究課題数: 5
# 研究成果数: 101
# プロフィールURL: /nrid/1000060738897/
#
# --- 研究者 158 ---
# 氏名: 植田 一博  Ueda Kazuhiro
# 研究者ID: 60262101
# 所属: 東京大学, 大学院総合文化研究科, 教授
# キーワード: 認知科学, コミュニケーション, 機械学習, 人工知能, 社会系心理学
# 研究課題数: 35
# 研究成果数: 344
# プロフィールURL: /nrid/1000060262101/
#
# --- 研究者 159 ---
# 氏名: 浅井 義之  Asai Yoshiyuki
# 研究者ID: 00415639
# 所属: 山口大学, 大学院医学系研究科, 教授
# キーワード: フィジオーム, 数理モデル, データサイエンス, 人工知能, システム生理学
# 研究課題数: 20
# 研究成果数: 147
# プロフィールURL: /nrid/1000000415639/
#
# --- 研究者 160 ---
# 氏名: 鈴木 麗璽  SUZUKI Reiji
# 研究者ID: 20362296
# 所属: 名古屋大学, 情報学研究科, 教授
# キーワード: 人工生命, ロボット聴覚, 進化, ボールドウィン効果, 進化と学習
# 研究課題数: 19
# 研究成果数: 520
# プロフィールURL: /nrid/1000020362296/
#
# --- 研究者 161 ---
# 氏名: 大谷 幸利  OTANI Yukitoshi
# 研究者ID: 10233165
# 所属: 宇都宮大学, 工学部, 教授
# キーワード: 3次元形状計測, 複屈折, 超精密計測, ナノ形状, 位相シフト法
# 研究課題数: 13
# 研究成果数: 162
# プロフィールURL: /nrid/1000010233165/
#
# --- 研究者 162 ---
# 氏名: 松本 敦  Matsumoto Atsushi
# 研究者ID: 20588462
# 所属: 関西福祉科学大学, 心理科学部, 講師
# キーワード: 脳波, 外国語能力, 一般線形モデル, 機械学習, 自由意思
# 研究課題数: 7
# 研究成果数: 11
# プロフィールURL: /nrid/1000020588462/
#
# --- 研究者 163 ---
# 氏名: 岡嶋 克典  OKAJIMA Katsunori
# 研究者ID: 60377108
# 所属: 横浜国立大学, 大学院環境情報研究院, 教授
# キーワード: 感性情報学, 色彩工学, 認知科学, 心理物理学, 視覚情報処理
# 研究課題数: 19
# 研究成果数: 396
# プロフィールURL: /nrid/1000060377108/
#
# --- 研究者 164 ---
# 氏名: 村尾 和哉  Murao Kazuya
# 研究者ID: 50609295
# 所属: 立命館大学, 情報理工学部, 教授
# キーワード: センサ情報処理, ウェアラブルコンピュータ, ユビキタスコンピューティング, スマートホーム, インタフェース
# 研究課題数: 8
# 研究成果数: 120
# プロフィールURL: /nrid/1000050609295/
#
# --- 研究者 165 ---
# 氏名: 飯塚 博幸  Iizuka Hiroyuki
# 研究者ID: 30396832
# 所属: 北海道大学, 人間知・脳・AI研究教育センター, 准教授
# キーワード: 深層学習, ニューラルネットワーク, LSTM, 相互作用, インタラクション
# 研究課題数: 10
# 研究成果数: 85
# プロフィールURL: /nrid/1000030396832/
#
# --- 研究者 166 ---
# 氏名: 岡田 真人  Okada Masato
# 研究者ID: 90233345
# 所属: 東京大学, 大学院新領域創成科学研究科, 教授
# キーワード: スパースモデリング, ベイズ推論, データ駆動科学, 統計力学, 機械学習
# 研究課題数: 26
# 研究成果数: 576
# プロフィールURL: /nrid/1000090233345/
#
# --- 研究者 167 ---
# 氏名: 前川 卓也  Maekawa Takuya
# 研究者ID: 50447025
# 所属: 大阪大学, 高等共創研究院, 教授
# キーワード: ユビキタスコンピューティング, 行動認識, 生態学, 神経科学, センサデータ処理
# 研究課題数: 13
# 研究成果数: 204
# プロフィールURL: /nrid/1000050447025/
#
# --- 研究者 168 ---
# 氏名: 山本 昇志  YAMAMOTO Shoji
# 研究者ID: 70469576
# 所属: 東京都立産業技術高等専門学校, ものづくり工学科, 教授
# キーワード: 質感, 画像処理, コンピュータグラフィックス, 感性工学, コンピュータグラフィック
# 研究課題数: 8
# 研究成果数: 119
# プロフィールURL: /nrid/1000070469576/
#
# --- 研究者 169 ---
# 氏名: 山藤 浩明  SANTO Hiroaki
# 研究者ID: 40830906
# 所属: 大阪大学, 大学院情報科学研究科, 助教
# キーワード: コンピュータビジョン, 3次元復元, ３次元復元, 機械学習, デジタルアーカイブ
# 研究課題数: 4
# 研究成果数: 11
# プロフィールURL: /nrid/1000040830906/
#
# --- 研究者 170 ---
# 氏名: 大本 義正  Ohmoto Yoshimasa
# 研究者ID: 90511775
# 所属: 静岡大学, 情報学部, 教授
# キーワード: エージェント, 会話エージェント, ヒューマンエージェントインタラクション, 認知科学, 会話情報学
# 研究課題数: 11
# 研究成果数: 139
# プロフィールURL: /nrid/1000090511775/
#
# --- 研究者 171 ---
# 氏名: 安戸 僚汰  Yasudo Ryota
# 研究者ID: 00846941
# 所属: 京都大学, 情報学研究科, 助教
# キーワード: 相互結合網, 機械学習, メモリキューブネットワーク, トポロジ, ルーティング
# 研究課題数: 5
# 研究成果数: 16
# プロフィールURL: /nrid/1000000846941/
#
# --- 研究者 172 ---
# 氏名: 諸岡 健一  Morooka Kennichi
# 研究者ID: 80323806
# 所属: 熊本大学, 大学院先端科学研究部(工), 教授
# キーワード: 実時間有限要素解析, 脳図譜, 形状変形, 有限要素解析, 脳神経外科学
# 研究課題数: 24
# 研究成果数: 209
# プロフィールURL: /nrid/1000080323806/
#
# --- 研究者 173 ---
# 氏名: 陶山 史朗  Suyama Shiro
# 研究者ID: 70457331
# 所属: 宇都宮大学, オプティクス教育研究センター, 特任教授
# キーワード: 3D表示, アーク3D表示, バーチャルリアリティ, DFD表示, ヒューマンインタフェース
# 研究課題数: 12
# 研究成果数: 988
# プロフィールURL: /nrid/1000070457331/
#
# --- 研究者 174 ---
# 氏名: 大須 理英子  OSU Rieko
# 研究者ID: 60374112
# 所属: 早稲田大学, 人間科学学術院, 教授
# キーワード: リハビリテーション, 脳波, 脳卒中, 非侵襲脳刺激, うつ
# 研究課題数: 17
# 研究成果数: 96
# プロフィールURL: /nrid/1000060374112/
#
# --- 研究者 175 ---
# 氏名: 森澤 光晴  Morisawa Mitsuharu
# 研究者ID: 00392671
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 副連携研究ラボ長
# キーワード: 機械学習, 人型ロボット, ロボットビジョン, 柔軟物ハンドリング, モデル駆動型画像処理
# 研究課題数: 5
# 研究成果数: 3
# プロフィールURL: /nrid/1000000392671/
#
# --- 研究者 176 ---
# 氏名: 新井田 厚司  Niida Atsushi
# 研究者ID: 00772493
# 所属: 東京大学, 医科学研究所, 講師
# キーワード: シミュレーション, がん, 大腸がん, 食道癌, 進化
# 研究課題数: 12
# 研究成果数: 50
# プロフィールURL: /nrid/1000000772493/
#
# --- 研究者 177 ---
# 氏名: 片平 健太郎  KATAHIRA KENTARO
# 研究者ID: 60569218
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: 意思決定, 計算論モデル, 生理, 強化学習, 統計モデル
# 研究課題数: 24
# 研究成果数: 95
# プロフィールURL: /nrid/1000060569218/
#
# --- 研究者 178 ---
# 氏名: 山口 裕  Yamaguti Yutaka
# 研究者ID: 80507236
# 所属: 福岡工業大学, 情報工学部, 准教授
# キーワード: 海馬, 機能分化, カオス的遍歴, 学習と記憶, カオス
# 研究課題数: 9
# 研究成果数: 93
# プロフィールURL: /nrid/1000080507236/
#
# --- 研究者 179 ---
# 氏名: 浅井 哲也  Asai Tetsuya
# 研究者ID: 00312380
# 所属: 北海道大学, 情報科学研究院, 教授
# キーワード: 単電子, ニューラルネットワーク, 集積回路, 反応拡散系, 自己組織化
# 研究課題数: 26
# 研究成果数: 436
# プロフィールURL: /nrid/1000000312380/
#
# --- 研究者 180 ---
# 氏名: 藤本 晃司  Fujimoto Koji
# 研究者ID: 10580110
# 所属: 京都大学, 医学研究科, 特定准教授
# キーワード: MRI, 圧縮センシング, 深層学習, 自然言語処理, 画像再構成
# 研究課題数: 16
# 研究成果数: 110
# プロフィールURL: /nrid/1000010580110/
#
# --- 研究者 181 ---
# 氏名: 鈴木 健嗣  Suzuki Kenji
# 研究者ID: 30350474
# 所属: 筑波大学, システム情報系, 教授
# キーワード: 人支援技術, 生体電位信号, 装着型ロボット, 嚥下障害, 嚥下音
# 研究課題数: 20
# 研究成果数: 165
# プロフィールURL: /nrid/1000030350474/
#
# --- 研究者 182 ---
# 氏名: 藤原 広臨  Fujiwara Hironobu
# 研究者ID: 10599608
# 所属: 京都大学, 医学研究科, 准教授
# キーワード: MRI, 脳・神経, モチベーション, 神経心理学, 環境
# 研究課題数: 10
# 研究成果数: 16
# プロフィールURL: /nrid/1000010599608/
#
# --- 研究者 183 ---
# 氏名: 佐々木 耕太  Sasaki Kota
# 研究者ID: 40467501
# 所属: 松江工業高等専門学校, 情報工学科, 准教授
# キーワード: 受容野, 一次視覚野, 質感, 大脳, 方位選択性
# 研究課題数: 7
# 研究成果数: 106
# プロフィールURL: /nrid/1000040467501/
#
# --- 研究者 184 ---
# 氏名: 宮野 悟  Miyano Satoru
# 研究者ID: 50128104
# 所属: 東京科学大学, 総合研究院, 特任教授
# キーワード: システム生物学, バイオインフォマティクス, 遺伝子ネットワーク, がん, 機械学習
# 研究課題数: 54
# 研究成果数: 584
# プロフィールURL: /nrid/1000050128104/
#
# --- 研究者 185 ---
# 氏名: 八代 尚  YASHIRO Hisashi
# 研究者ID: 80451508
# 所属: 国立研究開発法人国立環境研究所, 地球システム領域, 主任研究員
# キーワード: 物質循環, 環境計測, 温室効果気体, 同位体比, 高性能計算
# 研究課題数: 4
# 研究成果数: 67
# プロフィールURL: /nrid/1000080451508/
#
# --- 研究者 186 ---
# 氏名: 坂本 真樹  Sakamoto Maki
# 研究者ID: 80302826
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: オノマトペ, 認知科学, 感性情報学, 質感, 比喩
# 研究課題数: 20
# 研究成果数: 297
# プロフィールURL: /nrid/1000080302826/
#
# --- 研究者 187 ---
# 氏名: 香川 景一郎  KAGAWA Keiichiro
# 研究者ID: 30335484
# 所属: 静岡大学, 電子工学研究所, 教授
# キーワード: CMOSイメージセンサ, イメージセンサ, コンピュテーショナルフォトグラフィ, ビジョンチップ, バイオイメージング
# 研究課題数: 30
# 研究成果数: 610
# プロフィールURL: /nrid/1000030335484/
#
# --- 研究者 188 ---
# 氏名: 白石 友一  shiraisi yuichi
# 研究者ID: 70516880
# 所属: 国立研究開発法人国立がん研究センター, 研究所, 分野長
# キーワード: がん, バイオインフォマティクス, スプライシング, ゲノム, がんゲノム
# 研究課題数: 16
# 研究成果数: 137
# プロフィールURL: /nrid/1000070516880/
#
# --- 研究者 189 ---
# 氏名: 澤田 秀之  SAWADA Hideyuki
# 研究者ID: 00308206
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 聴覚フィードバック, 音声, 発話ロボット, 支援技術, ソフトロボット
# 研究課題数: 13
# 研究成果数: 271
# プロフィールURL: /nrid/1000000308206/
#
# --- 研究者 190 ---
# 氏名: 久保田 有一  kubota yuichi
# 研究者ID: 40372982
# 所属: 東京女子医科大学, 医学部, 教授
# キーワード: てんかん, 海馬, PSA, 神経前駆細胞, Doublecortin
# 研究課題数: 4
# 研究成果数: 0
# プロフィールURL: /nrid/1000040372982/
#
# --- 研究者 191 ---
# 氏名: 吉田 英一  Yoshida Eiichi
# 研究者ID: 30358329
# 所属: 東京理科大学, 先進工学部機能デザイン工学科, 教授
# キーワード: ヒューマノイド, 最適化, ロボット, 知能ロボティックス, 機械学習
# 研究課題数: 17
# 研究成果数: 67
# プロフィールURL: /nrid/1000030358329/
#
# --- 研究者 192 ---
# 氏名: 三浦 佳二  MIURA KEIJI
# 研究者ID: 60520096
# 所属: 関西学院大学, 生命環境学部, 教授
# キーワード: 神経科学, 応用数学, 深層学習, information geometry, nonstationarity
# 研究課題数: 9
# 研究成果数: 174
# プロフィールURL: /nrid/1000060520096/
#
# --- 研究者 193 ---
# 氏名: 藤澤 克樹  Fujisawa Katsuki
# 研究者ID: 40303854
# 所属: 東京科学大学, 総合研究院, 教授
# キーワード: 半正定値計画問題, 並列計算, 半正定値計画, 数理最適化, 最適化
# 研究課題数: 28
# 研究成果数: 278
# プロフィールURL: /nrid/1000040303854/
#
# --- 研究者 194 ---
# 氏名: 横田 秀夫  YOKOTA Hideo
# 研究者ID: 00261206
# 所属: 国立研究開発法人理化学研究所, 光量子工学研究センター, チームディレクター
# キーワード: 画像処理, 生物・生体工学, バイオイメージング, ナノ粒子, バイオメカニクス
# 研究課題数: 34
# 研究成果数: 317
# プロフィールURL: /nrid/1000000261206/
#
# --- 研究者 195 ---
# 氏名: 中臺 一博  Nakadai Kazuhiro
# 研究者ID: 70436715
# 所属: 東京科学大学, 工学院, 教授
# キーワード: ロボット聴覚, 音環境理解, 聖徳太子ロボット, 音源定位, 音声認識
# 研究課題数: 13
# 研究成果数: 626
# プロフィールURL: /nrid/1000070436715/
#
# --- 研究者 196 ---
# 氏名: 川村 一志  Kawamura Kazushi
# 研究者ID: 70803229
# 所属: 早稲田大学, 理工学術院, 専任講師
# キーワード: 組合せ最適化, イジングモデル, アニーリングマシン, 生成ＡＩ, ボルツマンマシン
# 研究課題数: 2
# 研究成果数: 18
# プロフィールURL: /nrid/1000070803229/
#
# --- 研究者 197 ---
# 氏名: 伊藤 貴之  ITOH Takayuki
# 研究者ID: 80401595
# 所属: お茶の水女子大学, 基幹研究院, 教授
# キーワード: 可視化, 情報可視化, シミュレーション, テキストマイニング, 構造活性相関
# 研究課題数: 14
# 研究成果数: 170
# プロフィールURL: /nrid/1000080401595/
#
# --- 研究者 198 ---
# 氏名: 木村 幸太郎  Kimura Kotaro
# 研究者ID: 20370116
# 所属: 名古屋市立大学, 大学院理学研究科, 教授
# キーワード: 行動, 神経科学, 線虫C.elegans, 学習, 分子生物学
# 研究課題数: 19
# 研究成果数: 158
# プロフィールURL: /nrid/1000020370116/
#
# --- 研究者 199 ---
# 氏名: 今西 規  Imanishi Tadashi
# 研究者ID: 80270461
# 所属: 東海大学, 医学部, 教授
# キーワード: データベース, 分子進化, 分子系統樹, ゲノム, DNA
# 研究課題数: 27
# 研究成果数: 53
# プロフィールURL: /nrid/1000080270461/
#
# --- 研究者 200 ---
# 氏名: 開 一夫  Hiraki Kazuo
# 研究者ID: 30323455
# 所属: 東京大学, 大学院総合文化研究科, 教授
# キーワード: 認知科学, 発達科学, アンドロイド, 発達, 乳児
# 研究課題数: 26
# 研究成果数: 533
# プロフィールURL: /nrid/1000030323455/
#
# --- 研究者 201 ---
# 氏名: 茅野 光範  Kayano Mitsunori
# 研究者ID: 20590095
# 所属: 帯広畜産大学, 畜産学部, 准教授
# キーワード: ヤブカ, 犬糸状虫, システム生物学, バイオインフォマティクス, プロテオーム
# 研究課題数: 11
# 研究成果数: 26
# プロフィールURL: /nrid/1000020590095/
#
# --- 研究者 202 ---
# 氏名: 松井 秀俊  Matsui Hidetoshi
# 研究者ID: 90633305
# 所属: 滋賀大学, データサイエンス学系, 教授
# キーワード: 関数データ解析, 統計数学, 高次元データ, モデル選択, スパース推定
# 研究課題数: 10
# 研究成果数: 170
# プロフィールURL: /nrid/1000090633305/
#
# --- 研究者 203 ---
# 氏名: 山下 智志  yamashita satoshi
# 研究者ID: 50244108
# 所属: 統計数理研究所, 学際統計数理研究系, 教授
# キーワード: 信用リスク, LGD, 回収率, 担保, 機械学習
# 研究課題数: 13
# 研究成果数: 220
# プロフィールURL: /nrid/1000050244108/
#
# --- 研究者 204 ---
# 氏名: 塚本 光昭  Tsukamoto Mitsuaki
# 研究者ID: 00514481
# 所属: 株式会社国際電気通信基礎技術研究所, 脳情報通信総合研究所, 研究技術員
# キーワード: 認知科学, 夢, ブレイン・デコーディング, イメージ, 視覚
# 研究課題数: 3
# 研究成果数: 2
# プロフィールURL: /nrid/1000000514481/
#
# --- 研究者 205 ---
# 氏名: 安藤 洸太  Ando Kota
# 研究者ID: 20855324
# 所属: 北海道大学, 情報科学研究院, 准教授
# キーワード: 深層ニューラルネット, アニーリング計算, ハイパーディメンジョナルコンピューティング, 機械学習, 離散最適化
# 研究課題数: 2
# 研究成果数: 5
# プロフィールURL: /nrid/1000020855324/
#
# --- 研究者 206 ---
# 氏名: 片桐 孝洋  Katagiri Takahiro
# 研究者ID: 40345434
# 所属: 名古屋大学, 情報基盤センター, 教授
# キーワード: 自動チューニング, 高性能計算, 機械学習, 実行時最適化, ハイパフォーマンスコンピューティング
# 研究課題数: 20
# 研究成果数: 369
# プロフィールURL: /nrid/1000040345434/
#
# --- 研究者 207 ---
# 氏名: 荻 多加之  Ogi Takayuki
# 研究者ID: 20391964
# 所属: 福島大学, 地域未来デザインセンター, リサーチ・アドミニストレーター(URA)
# キーワード: 物体認識, 顔認知, 深層学習, 下側頭葉視覚連合野, マシンビジョン
# 研究課題数: 1
# 研究成果数: 2
# プロフィールURL: /nrid/1000020391964/
#
# --- 研究者 208 ---
# 氏名: 植野 真臣  Ueno Maomi
# 研究者ID: 50262316
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: 教育工学, e-ラーニング, eラーニング, e-Learning, eテスティング
# 研究課題数: 39
# 研究成果数: 510
# プロフィールURL: /nrid/1000050262316/
#
# --- 研究者 209 ---
# 氏名: 石尾 隆  Ishio Takashi
# 研究者ID: 60452413
# 所属: 公立はこだて未来大学, システム情報科学部, 教授
# キーワード: ソフトウェア工学, コードクローン, プログラム解析, 再利用, オープンソースソフトウェア
# 研究課題数: 15
# 研究成果数: 231
# プロフィールURL: /nrid/1000060452413/
#
# --- 研究者 210 ---
# 氏名: 張 景耀  ZHANG Jingyao
# 研究者ID: 50546736
# 所属: 京都大学, 工学研究科, 准教授
# キーワード: 張力空間構造, テンセグリティ, 安定性, 対称性, 最適化
# 研究課題数: 15
# 研究成果数: 124
# プロフィールURL: /nrid/1000050546736/
#
# --- 研究者 211 ---
# 氏名: ＫＵＬＡ ＲＡＵＬＡ・ＧＡＩＫＯＶＩＮＡ  KULA RAULA GAIKOVINA
# 研究者ID: 80749094
# 所属: 大阪大学, 高等共創研究院, 教授
# キーワード: ソフトウェアエコシステム, SPDX, オープンソースソフトウェアOSS, ソフトウェアライブラリ, ソフトウェアレポジトリマイニングMSR
# 研究課題数: 5
# 研究成果数: 92
# プロフィールURL: /nrid/1000080749094/
#
# --- 研究者 212 ---
# 氏名: 打矢 隆弘  UCHIYA Takahiro
# 研究者ID: 10375157
# 所属: 名古屋工業大学, 工学(系)研究科(研究院), 教授
# キーワード: マルチエージェントシステム, 防災システム, マルチエージェント, ロボット, エージェント
# 研究課題数: 9
# 研究成果数: 156
# プロフィールURL: /nrid/1000010375157/
#
# --- 研究者 213 ---
# 氏名: 中村 友哉  Nakamura Tomoya
# 研究者ID: 70756709
# 所属: 大阪大学, 大学院基礎工学研究科, 准教授
# キーワード: コンピュテーショナルイメージング, 符号化撮像, 圧縮センシング, レンズレスイメージング, レンズレスカメラ
# 研究課題数: 12
# 研究成果数: 45
# プロフィールURL: /nrid/1000070756709/
#
# --- 研究者 214 ---
# 氏名: 吉村 奈津江  Yoshimura Natsue
# 研究者ID: 00581315
# 所属: 東京科学大学, 情報理工学院, 教授
# キーワード: 脳波, 機械学習, ブレイン・コンピュータ・インタフェース, デコーディング, 機能的MRI
# 研究課題数: 11
# 研究成果数: 73
# プロフィールURL: /nrid/1000000581315/
#
# --- 研究者 215 ---
# 氏名: ＣＨＵ ＴｈｉｅｍＶａｎ  Chu Thiem Van
# 研究者ID: 80838235
# 所属: 東京科学大学, 工学院, 准教授
# キーワード: 疎行列処理, 疎行列疎行列積, データフロー, アーキテクチャ, FPGA
# 研究課題数: 4
# 研究成果数: 20
# プロフィールURL: /nrid/1000080838235/
#
# --- 研究者 216 ---
# 氏名: 冨岡 亮太  TOMIOKA Ryota
# 研究者ID: 70518282
# 所属: 東京大学, 情報理工学(系)研究科, 助教
# キーワード: 機械学習, 最適化, データマイニング, スパース性, 正則化
# 研究課題数: 4
# 研究成果数: 37
# プロフィールURL: /nrid/1000070518282/
#
# --- 研究者 217 ---
# 氏名: 長井 隆行  Nagai Takayuki
# 研究者ID: 40303010
# 所属: 大阪大学, 大学院基礎工学研究科, 教授
# キーワード: 人工知能, コミュニケーション, ロボット, 知能ロボティクス, 知能ロボット
# 研究課題数: 17
# 研究成果数: 297
# プロフィールURL: /nrid/1000040303010/
#
# --- 研究者 218 ---
# 氏名: 亀井 保博  KAMEI Yasuhiro
# 研究者ID: 70372563
# 所属: 基礎生物学研究所, 超階層生物学センター , RMC教授
# キーワード: メダカ, 赤外レーザー, 温度計測, イメージング, 遺伝子発現
# 研究課題数: 22
# 研究成果数: 210
# プロフィールURL: /nrid/1000070372563/
#
# --- 研究者 219 ---
# 氏名: 金澤 周介  Kanazawa Shusuke
# 研究者ID: 60783925
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: センサ, 印刷, MEMS, カンチレバー, マイクロ・ナノデバイス
# 研究課題数: 4
# 研究成果数: 28
# プロフィールURL: /nrid/1000060783925/
#
# --- 研究者 220 ---
# 氏名: 寺前 順之介  Teramae Jun-nosuke
# 研究者ID: 50384722
# 所属: 京都大学, 情報学研究科, 准教授
# キーワード: ネットワーク, 脳, 確率, 大脳皮質, 局所回路
# 研究課題数: 13
# 研究成果数: 187
# プロフィールURL: /nrid/1000050384722/
#
# --- 研究者 221 ---
# 氏名: 古川 茂人  Furukawa Shigeto
# 研究者ID: 90396169
# 所属: 静岡社会健康医学大学院大学, 社会健康医学研究科, 教授
# キーワード: 質感, 情報工学, 認知科学, 神経科学, 感性情報学
# 研究課題数: 3
# 研究成果数: 59
# プロフィールURL: /nrid/1000090396169/
#
# --- 研究者 222 ---
# 氏名: 芦原 貴司  Ashihara Takashi
# 研究者ID: 80396259
# 所属: 滋賀医科大学, 医学部, 教授
# キーワード: 不整脈, 心房細動, コンピュータシミュレーション, カテーテルアブレーション, シミュレーション
# 研究課題数: 37
# 研究成果数: 1087
# プロフィールURL: /nrid/1000080396259/
#
# --- 研究者 223 ---
# 氏名: 中島 研吾  Nakajima Kengo
# 研究者ID: 20376528
# 所属: 東京大学, 情報基盤センター, 教授
# キーワード: 線形方程式, Krylov 空間法, Krylov空間法, 大規模線形方程式, Krylov 空間法(反復法)
# 研究課題数: 5
# 研究成果数: 169
# プロフィールURL: /nrid/1000020376528/
#
# --- 研究者 224 ---
# 氏名: 佐藤 いまり  SATO Imari
# 研究者ID: 50413927
# 所属: 国立情報学研究所, コンテンツ科学研究系, 教授
# キーワード: コンピュータビジョン, 分光解析, コンピュータグラフィックス, 反射解析, 画像解析
# 研究課題数: 11
# 研究成果数: 136
# プロフィールURL: /nrid/1000050413927/
#
# --- 研究者 225 ---
# 氏名: 小長谷 明彦  Konagaya Akihiko
# 研究者ID: 00301200
# 所属: 恵泉女学園大学, 人文学部, 客員教授
# キーワード: 分子ロボティクス, DNAコンピュータ, ナノバイオ, 細胞シミュレーション, RLGS
# 研究課題数: 16
# 研究成果数: 77
# プロフィールURL: /nrid/1000000301200/
#
# --- 研究者 226 ---
# 氏名: 永原 正章  Nagahara Masaaki
# 研究者ID: 90362582
# 所属: 広島大学, 先進理工系科学研究科(工), 教授
# キーワード: 最適制御, スパースモデリング, サンプル値制御理論, ディジタルフィルタ, 圧縮センシング
# 研究課題数: 24
# 研究成果数: 443
# プロフィールURL: /nrid/1000090362582/
#
# --- 研究者 227 ---
# 氏名: 雨森 賢一  Amemori Ken-ichi
# 研究者ID: 70344471
# 所属: 京都大学, 高等研究院, 特定拠点准教授
# キーワード: 意思決定, 大脳基底核, 不安障害, 線条体, 計算論的神経科学
# 研究課題数: 20
# 研究成果数: 230
# プロフィールURL: /nrid/1000070344471/
#
# --- 研究者 228 ---
# 氏名: 内田 豪  Uchida Go
# 研究者ID: 50321732
# 所属: 兵庫県立大学, 情報科学研究科, 客員准教授
# キーワード: 下側頭葉視覚連合野, 脳・神経, 物体認識, 顔認知, 深層学習
# 研究課題数: 2
# 研究成果数: 12
# プロフィールURL: /nrid/1000050321732/
#
# --- 研究者 229 ---
# 氏名: 海野 広志  UNNO HIROSHI
# 研究者ID: 80569575
# 所属: 東北大学, 電気通信研究所, 教授
# キーワード: プログラム検証, 型システム, プログラミング言語, 不動点論理, 高階モデル検査
# 研究課題数: 15
# 研究成果数: 81
# プロフィールURL: /nrid/1000080569575/
#
# --- 研究者 230 ---
# 氏名: 松野 浩嗣  Matsuno Hiroshi
# 研究者ID: 10181744
# 所属: 山口大学, その他部局等, 理事
# キーワード: シミュレーション, ペトリネット, システム生物学, モデル化, 大腸菌
# 研究課題数: 25
# 研究成果数: 116
# プロフィールURL: /nrid/1000010181744/
#
# --- 研究者 231 ---
# 氏名: 戸田 智基  Toda Tomoki
# 研究者ID: 90403328
# 所属: 名古屋大学, 情報基盤センター, 教授
# キーワード: 音声合成, 音声情報処理, 音声変換, 音声分析, 音声認識
# 研究課題数: 24
# 研究成果数: 812
# プロフィールURL: /nrid/1000090403328/
#
# --- 研究者 232 ---
# 氏名: 國枝 武治  Kunieda Takeharu
# 研究者ID: 60609931
# 所属: 愛媛大学, 医学系研究科, 教授
# キーワード: てんかん, 皮質皮質間誘発電位, Glioblastoma, glioblastoma, 機能的結合
# 研究課題数: 15
# 研究成果数: 643
# プロフィールURL: /nrid/1000060609931/
#
# --- 研究者 233 ---
# 氏名: 山本 江  YAMAMOTO KOU
# 研究者ID: 20641880
# 所属: 東京大学, 大学院情報理工学系研究科, 准教授
# キーワード: ヒューマノイド, 手術ロボット, デジタルヒューマン, 二足歩行制御, ヒューマノイドロボット
# 研究課題数: 9
# 研究成果数: 104
# プロフィールURL: /nrid/1000020641880/
#
# --- 研究者 234 ---
# 氏名: 宮崎 美智子  MIYAZAKI Michiko
# 研究者ID: 90526732
# 所属: 大妻女子大学, 社会情報学部, 准教授
# キーワード: 発達, 視線計測, 認知科学, 身体表象, 自己
# 研究課題数: 10
# 研究成果数: 91
# プロフィールURL: /nrid/1000090526732/
#
# --- 研究者 235 ---
# 氏名: 川上 哲志  Kawakami Satoshi
# 研究者ID: 20845523
# 所属: 九州大学, システム情報科学研究院, 准教授
# キーワード: 光コンピューティング, 計算機システムアーキテクチャ, 単一磁束量子回路, 再帰型ニューラルネットワーク, 再帰型光回路
# 研究課題数: 5
# 研究成果数: 45
# プロフィールURL: /nrid/1000020845523/
#
# --- 研究者 236 ---
# 氏名: 角田 達彦  Tsunoda Tatsuhiko
# 研究者ID: 10273468
# 所属: 東京大学, 大学院理学系研究科(理学部), 教授
# キーワード: ゲノム, SNP, マイクロアレイ, 遺伝子発現, 統計数学
# 研究課題数: 23
# 研究成果数: 209
# プロフィールURL: /nrid/1000010273468/
#
# --- 研究者 237 ---
# 氏名: 川鍋 一晃  Kawanabe Motoaki
# 研究者ID: 30272389
# 所属: 株式会社国際電気通信基礎技術研究所, 脳情報通信総合研究所, 研究室長
# キーワード: 機械学習, 独立成分分析, 確率的情報処理, 人間情報学, 転移学習
# 研究課題数: 9
# 研究成果数: 62
# プロフィールURL: /nrid/1000030272389/
#
# --- 研究者 238 ---
# 氏名: 田中 弘美  TANAKA Hiromi
# 研究者ID: 10268154
# 所属: 立命館大学, OIC総合研究機構, 教授
# キーワード: 変形, モデリング, バーチャルリアリティ, 可視化, 距離画像解析
# 研究課題数: 29
# 研究成果数: 643
# プロフィールURL: /nrid/1000010268154/
#
# --- 研究者 239 ---
# 氏名: 中井 隆介  Nakai Ryusuke
# 研究者ID: 10576234
# 所属: 京都大学, 人と社会の未来研究院, 特定准教授
# キーワード: MRI, 画像処理, 顎関節, リハビリテーション, シミュレーション
# 研究課題数: 18
# 研究成果数: 105
# プロフィールURL: /nrid/1000010576234/
#
# --- 研究者 240 ---
# 氏名: Ｖｅｎｔｕｒｅ Ｇｅｎｔｉａｎｅ  VENTURE GENTIANE
# 研究者ID: 30538278
# 所属: 東京大学, 大学院工学系研究科(工学部), 教授
# キーワード: ロボティクス, 超音波モータ, ステント, 機械力学・制御, 運動制御
# 研究課題数: 12
# 研究成果数: 76
# プロフィールURL: /nrid/1000030538278/
#
# --- 研究者 241 ---
# 氏名: 鈴木 泰博  SUZUKI Yasuhiro
# 研究者ID: 50292983
# 所属: 名古屋大学, 情報学研究科, 准教授
# キーワード: 触譜, 触覚, 人工知能, 自然計算, DNAコンピュータ
# 研究課題数: 24
# 研究成果数: 211
# プロフィールURL: /nrid/1000050292983/
#
# --- 研究者 242 ---
# 氏名: 板木 拓也  Itaki Takuya
# 研究者ID: 30509724
# 所属: 国立研究開発法人産業技術総合研究所, 地質調査総合センター, 研究グループ長
# キーワード: 古海洋学, 気候変動, 南極, 微化石, 海洋循環
# 研究課題数: 15
# 研究成果数: 169
# プロフィールURL: /nrid/1000030509724/
#
# --- 研究者 243 ---
# 氏名: 木立 尚孝  kiryu hisanori
# 研究者ID: 80415778
# 所属: 東京大学, 大学院新領域創成科学研究科, 准教授
# キーワード: バイオインフォマティクス, 機械学習, 確率モデル, RNA二次構造, RNA
# 研究課題数: 10
# 研究成果数: 33
# プロフィールURL: /nrid/1000080415778/
#
# --- 研究者 244 ---
# 氏名: 荻田 武史  Ogita Takeshi
# 研究者ID: 00339615
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 数値線形代数, 精度保証, 高精度計算, 精度保証付き数値計算, 情報数理
# 研究課題数: 12
# 研究成果数: 208
# プロフィールURL: /nrid/1000000339615/
#
# --- 研究者 245 ---
# 氏名: 石川 智治  Ishikawa Tomoharu
# 研究者ID: 90343186
# 所属: 宇都宮大学, 工学部, 教授
# キーワード: 触覚, 深い癒し, 「場」の実現, 身体・皮膚感覚, 心理生理学
# 研究課題数: 18
# 研究成果数: 282
# プロフィールURL: /nrid/1000090343186/
#
# --- 研究者 246 ---
# 氏名: 鮫島 和行  SAMEJIMA Kazuyuki
# 研究者ID: 30395131
# 所属: 玉川大学, 脳科学研究所, 教授
# キーワード: 意思決定, 強化学習, 認知科学, 大脳基底核, 線条体
# 研究課題数: 21
# 研究成果数: 124
# プロフィールURL: /nrid/1000030395131/
#
# --- 研究者 247 ---
# 氏名: 杉山 将  Sugiyama Masashi
# 研究者ID: 90334515
# 所属: 国立研究開発法人理化学研究所, 革新知能統合研究センター, センター長
# キーワード: 機械学習, 教師付き学習, 強化学習, 汎化能力, 共変量シフト
# 研究課題数: 15
# 研究成果数: 247
# プロフィールURL: /nrid/1000090334515/
#
# --- 研究者 248 ---
# 氏名: 菅原 健  SUGAWARA Takeshi
# 研究者ID: 60785236
# 所属: 電気通信大学, 大学院情報理工学研究科, 准教授
# キーワード: セキュリティ, ハードウェアセキュリティ, レーザー, 光音響効果, 情報セキュリティ
# 研究課題数: 8
# 研究成果数: 86
# プロフィールURL: /nrid/1000060785236/
#
# --- 研究者 249 ---
# 氏名: 森 洋二郎  MORI Yojiro
# 研究者ID: 10722100
# 所属: 豊田工業大学, 工学(系)研究科(研究院), 教授
# キーワード: フォトニックネットワーク, 光ファイバ通信, 光ネットワーク, 光ファイバ, 光通信
# 研究課題数: 6
# 研究成果数: 123
# プロフィールURL: /nrid/1000010722100/
#
# --- 研究者 250 ---
# 氏名: 堂坂 浩二  Dohsaka Kohji
# 研究者ID: 70396191
# 所属: 秋田県立大学, システム科学技術学部, 教授
# キーワード: 機械学習, マルチモーダル, 対話, コミュニケーション, 環境知能
# 研究課題数: 2
# 研究成果数: 76
# プロフィールURL: /nrid/1000070396191/
#
# --- 研究者 251 ---
# 氏名: 伊藤 聡志  ITO SATOSHI
# 研究者ID: 80261816
# 所属: 宇都宮大学, 工学部, 教授
# キーワード: MRI, 磁気共鳴映像法, 再構成, 圧縮センシング, ホログラフィ
# 研究課題数: 12
# 研究成果数: 325
# プロフィールURL: /nrid/1000080261816/
#
# --- 研究者 252 ---
# 氏名: 田中 和之  Tanaka Kazuyuki
# 研究者ID: 80217017
# 所属: 東北大学, 情報科学研究科, 教授
# キーワード: 確率的情報処理, 情報統計力学, マルコフ確率場, 統計力学, ベイズ統計
# 研究課題数: 19
# 研究成果数: 293
# プロフィールURL: /nrid/1000080217017/
#
# --- 研究者 253 ---
# 氏名: 神永 拓  KAMINAGA Hiroshi
# 研究者ID: 90571571
# 所属: 国立研究開発法人産業技術総合研究所, 情報・人間工学領域, 主任研究員
# キーワード: 力制御, 電気静油圧アクチュエータ, 知能ロボット, 統計推論, 自然言語処理
# 研究課題数: 6
# 研究成果数: 61
# プロフィールURL: /nrid/1000090571571/
#
# --- 研究者 254 ---
# 氏名: 酒井 弘  Sakai Hiromu
# 研究者ID: 50274030
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 心理言語学, 言語学, 国際研究者交流, 実験系心理学, 認知科学
# 研究課題数: 42
# 研究成果数: 206
# プロフィールURL: /nrid/1000050274030/
#
# --- 研究者 255 ---
# 氏名: イン ベイウェン  YING Bei-Wen
# 研究者ID: 90422401
# 所属: 筑波大学, 生命環境系, 准教授
# キーワード: 増殖速度, 大腸菌, 遺伝子発現, 実験進化, 細胞間相互作用
# 研究課題数: 8
# 研究成果数: 129
# プロフィールURL: /nrid/1000090422401/
#
# --- 研究者 256 ---
# 氏名: 荒木 通啓  Araki Michihiro
# 研究者ID: 40396867
# 所属: 立命館大学, 薬学部, 教授
# キーワード: 代謝工学, 合成生物学, バイオインフォマティクス, 機械学習, ケモインフォマティクス
# 研究課題数: 6
# 研究成果数: 78
# プロフィールURL: /nrid/1000040396867/
#
# --- 研究者 257 ---
# 氏名: 島田 裕  SHIMADA Yutaka
# 研究者ID: 50734414
# 所属: 埼玉大学, 理工学研究科, 准教授
# キーワード: テンポラル・ネットワーク, 複雑ネットワーク, 非線形時系列解析, グラフ間距離, テンポラルネットワーク
# 研究課題数: 15
# 研究成果数: 291
# プロフィールURL: /nrid/1000050734414/
#
# --- 研究者 258 ---
# 氏名: 片上 大輔  Katagami Daisuke
# 研究者ID: 90345372
# 所属: 東京工芸大学, 工学部, 教授
# キーワード: コミュニケーション, 人狼, ヒューマンエージェントインタラクション, ヒューマン・エージェント・インタラクション, エージェント
# 研究課題数: 17
# 研究成果数: 149
# プロフィールURL: /nrid/1000090345372/
#
# --- 研究者 259 ---
# 氏名: 瀧山 健  TAKIYAMA Ken
# 研究者ID: 40725933
# 所属: 東京農工大学, 工学(系)研究科(研究院), 准教授
# キーワード: 運動学習, 運動制御, 身体運動学習, 身体運動制御, 機械学習
# 研究課題数: 9
# 研究成果数: 83
# プロフィールURL: /nrid/1000040725933/
#
# --- 研究者 260 ---
# 氏名: 杉浦 孔明  Sugiura Komei
# 研究者ID: 60470473
# 所属: 慶應義塾大学, 理工学部(矢上), 教授
# キーワード: 生活支援ロボット, ヒューマンロボットインタラクション, 機械学習, 知能ロボティクス, 模倣学習
# 研究課題数: 7
# 研究成果数: 120
# プロフィールURL: /nrid/1000060470473/
#
# --- 研究者 261 ---
# 氏名: 中村 匡秀  NAKAMURA MASAHIDE
# 研究者ID: 30324859
# 所属: 神戸大学, 数理・データサイエンスセンター, 教授
# キーワード: 認知症, サービス競合, 競合検出, ホームネットワーク, スマートセンサ情報システム
# 研究課題数: 25
# 研究成果数: 696
# プロフィールURL: /nrid/1000030324859/
#
# --- 研究者 262 ---
# 氏名: 高橋 英之  Takahashi Hideyuki
# 研究者ID: 30535084
# 所属: 追手門学院大学, 理工学部, 准教授
# キーワード: ロボット, 子ども, ジェスチャー, 擬人化, fMRI
# 研究課題数: 15
# 研究成果数: 119
# プロフィールURL: /nrid/1000030535084/
#
# --- 研究者 263 ---
# 氏名: 成本 迅  Narumoto Jin
# 研究者ID: 30347463
# 所属: 京都府立医科大学, 医学(系)研究科(研究院), 教授
# キーワード: 認知症, 強迫性障害, 介護者, 認知行動療法, 非薬物療法
# 研究課題数: 23
# ...
# 研究者ID: 30553284
# 所属: 滋賀大学, データサイエンス学系, 准教授
# キーワード: ネットワーク科学, 自己組織化, コミュニティ検出, 人流, ソフトコンピューティング
# 研究課題数: 11
# 研究成果数: 142
# プロフィールURL: /nrid/1000030553284/
#
# --- 研究者 414 ---
# 氏名: 清水 渉  Shimizu Wataru
# 研究者ID: 50399606
# 所属: 東京医科大学, 医学部, その他
# キーワード: 不整脈, 遺伝性不整脈, 心臓突然死, バイオインフォマティクス, エピジェネティクス
# 研究課題数: 7
# 研究成果数: 60
# プロフィールURL: /nrid/1000050399606/
#
# --- 研究者 415 ---
# 氏名: 茅 元司  Kaya Motoshi
# 研究者ID: 00422098
# 所属: 東京大学, 大学院理学系研究科(理学部), 助教
# キーワード: ミオシン, 生物物理, 筋肉, イメージング, 1分子計測
# 研究課題数: 11
# 研究成果数: 81
# プロフィールURL: /nrid/1000000422098/
#
# --- 研究者 416 ---
# 氏名: 成瀬 康  Naruse Yasushi
# 研究者ID: 00455453
# 所属: 国立研究開発法人情報通信研究機構, 未来ICT研究所脳情報通信融合研究センター, 室長
# キーワード: 脳波, 同期, ウェアラブル脳波計, 共感, 脳磁界
# 研究課題数: 11
# 研究成果数: 121
# プロフィールURL: /nrid/1000000455453/
#
# --- 研究者 417 ---
# 氏名: 植村 誠  Uemura Makoto
# 研究者ID: 50403514
# 所属: 広島大学, 宇宙科学センター, 准教授
# キーワード: 光学赤外線天文学, 光赤外線天文学, 偏光, 天文学, 活動銀河核
# 研究課題数: 12
# 研究成果数: 180
# プロフィールURL: /nrid/1000050403514/
#
# --- 研究者 418 ---
# 氏名: 横井 浩史  Yokoi Hiroshi
# 研究者ID: 90271634
# 所属: 電気通信大学, 大学院情報理工学研究科, 教授
# キーワード: 筋電義手, 感覚フィードバック, 機能的電気刺激, 機械学習, リハビリテーション
# 研究課題数: 35
# 研究成果数: 533
# プロフィールURL: /nrid/1000090271634/
#
# --- 研究者 419 ---
# 氏名: 大武 美保子  Ootake Mihoko
# 研究者ID: 10361544
# 所属: 国立研究開発法人理化学研究所, 革新知能統合研究センター, チームディレクター
# キーワード: ロボット, 高齢者, コミュニケーション, モデリング, 認知機能
# 研究課題数: 16
# 研究成果数: 178
# プロフィールURL: /nrid/1000010361544/
#
# --- 研究者 420 ---
# 氏名: 武藤 香織  Muto Kaori
# 研究者ID: 50345766
# 所属: 東京大学, 医科学研究所, 教授
# キーワード: 生命倫理, ゲノム, 遺伝子, 医学, 研究倫理
# 研究課題数: 16
# 研究成果数: 218
# プロフィールURL: /nrid/1000050345766/
#
# --- 研究者 421 ---
# 氏名: 岡田 康志  Okada Yasushi
# 研究者ID: 50272430
# 所属: 国立研究開発法人理化学研究所, 生命機能科学研究センター, 副センター長
# キーワード: 微小管, 分子モーター, キネシン, 細胞内物質輸送, 細胞内輸送
# 研究課題数: 29
# 研究成果数: 371
# プロフィールURL: /nrid/1000050272430/
#
# --- 研究者 422 ---
# 氏名: 山口 類  YAMAGUCHI RUI
# 研究者ID: 90380675
# 所属: 愛知県がんセンター(研究所), システム解析学分野, 分野長
# キーワード: がん, バイオインフォマティクス, システム生物学, 遺伝子ネットワーク, 統計的モデリング
# 研究課題数: 28
# 研究成果数: 162
# プロフィールURL: /nrid/1000090380675/
#
# --- 研究者 423 ---
# 氏名: 貴島 晴彦  KISHIMA Haruhiko
# 研究者ID: 10332743
# 所属: 大阪大学, 大学院医学系研究科, 教授
# キーワード: てんかん, 脳磁図, 電気刺激, 硬膜下電極, 頭蓋内脳波
# 研究課題数: 33
# 研究成果数: 741
# プロフィールURL: /nrid/1000010332743/
#
# --- 研究者 424 ---
# 氏名: 長谷川 泰久  Hasegawa Yasuhisa
# 研究者ID: 70303675
# 所属: 名古屋大学, 工学研究科, 教授
# キーワード: ロボット, 遠隔操作, リハビリテーション, 身体拡張, 外骨格
# 研究課題数: 21
# 研究成果数: 79
# プロフィールURL: /nrid/1000070303675/
#
# --- 研究者 425 ---
# 氏名: 小池 亮太郎  Koike Ryotaro
# 研究者ID: 20381577
# 所属: 名古屋大学, 情報学研究科, 助教
# キーワード: アクチン, 分子シミュレーション, 構造バイオインフォマティクス, データベース, 構造機能相関
# 研究課題数: 7
# 研究成果数: 32
# プロフィールURL: /nrid/1000020381577/
#
# --- 研究者 426 ---
# 氏名: 濱田 浩幸  HAMADA Hiroyuki
# 研究者ID: 80346840
# 所属: 九州大学, 農学研究院, 助教
# キーワード: 数理解析, 計算機シミュレーション, クオラムセンシング, 慢性血液透析療法, 心筋細胞拍動能
# 研究課題数: 7
# 研究成果数: 111
# プロフィールURL: /nrid/1000080346840/
#
# --- 研究者 427 ---
# 氏名: 岡本 敦  Okamoto Atsushi
# 研究者ID: 40422092
# 所属: 東北大学, 環境科学研究科, 教授
# キーワード: 水熱実験, 沈み込み帯, 水熱反応実験, 石英脈, 蛇紋岩化作用
# 研究課題数: 26
# 研究成果数: 825
# プロフィールURL: /nrid/1000040422092/
#
# --- 研究者 428 ---
# 氏名: 淺間 一  Asama Hajime
# 研究者ID: 50184156
# 所属: 東京大学, 東京カレッジ, 特任教授
# キーワード: リハビリテーション, 筋シナジー, 数理モデル, 起立動作, 自己組織化
# 研究課題数: 18
# 研究成果数: 229
# プロフィールURL: /nrid/1000050184156/
#
# --- 研究者 429 ---
# 氏名: 浅原 正幸  Asahara Masayuki
# 研究者ID: 80379528
# 所属: 大学共同利用機関法人人間文化研究機構国立国語研究所, 研究系, 教授
# キーワード: コーパス, 自然言語処理, 形態素解析, アノテーション, 比喩
# 研究課題数: 22
# 研究成果数: 283
# プロフィールURL: /nrid/1000080379528/
#
# --- 研究者 430 ---
# 氏名: 阪上 雅昭  SAKAGAMI Masa-aki
# 研究者ID: 70202083
# 所属: 京都大学, 人間・環境学研究科, 名誉教授
# キーワード: ブラックホール, ホーキング輻射, 重力多体系, トンネル効果, ゆらぎ
# 研究課題数: 18
# 研究成果数: 84
# プロフィールURL: /nrid/1000070202083/
#
# --- 研究者 431 ---
# 氏名: 渡辺 幸信  Watanabe Yukinobu
# 研究者ID: 30210959
# 所属: 九州大学, 総合理工学研究院, 教授
# キーワード: 陽子, 核データ, 連続状態離散化チャネル結合法, グラウバー模型, 加速器中性子源
# 研究課題数: 16
# 研究成果数: 143
# プロフィールURL: /nrid/1000030210959/
#
# --- 研究者 432 ---
# 氏名: 松井 鉄平  MATSUI TEPPEI
# 研究者ID: 10725948
# 所属: 同志社大学, 脳科学研究科, 教授
# キーワード: カルシウムイメージング, 脳活動イメージング, 大脳皮質, 機能的MRI, 神経科学
# 研究課題数: 10
# 研究成果数: 85
# プロフィールURL: /nrid/1000010725948/
#
# --- 研究者 433 ---
# 氏名: 丹羽 伸介  Niwa Shinsuke
# 研究者ID: 30714985
# 所属: 東北大学, 学際科学フロンティア研究所, 准教授
# キーワード: 軸索輸送, キネシン, シナプス小胞, KIF1A, UNC-104
# 研究課題数: 12
# 研究成果数: 54
# プロフィールURL: /nrid/1000030714985/
#
# --- 研究者 434 ---
# 氏名: 温 文  Wen Wen
# 研究者ID: 50646601
# 所属: 立教大学, 現代心理学部, 准教授
# キーワード: 運動主体感, 脳波, 転移学習, 強化学習, 認知神経科学
# 研究課題数: 7
# 研究成果数: 55
# プロフィールURL: /nrid/1000050646601/
#
# --- 研究者 435 ---
# 氏名: 今井 むつみ  IMAI Mutsumi
# 研究者ID: 60255601
# 所属: 慶應義塾大学, 環境情報学部(藤沢), 教授
# キーワード: 言語発達, 言語獲得, 語彙獲得, 言語学習, 語意学習
# 研究課題数: 29
# 研究成果数: 373
# プロフィールURL: /nrid/1000060255601/
#
# --- 研究者 436 ---
# 氏名: 東島 仁  Higashijima Jin
# 研究者ID: 80579326
# 所属: 千葉大学, 大学院国際学術研究院, 准教授
# キーワード: ELSI, 患者参画, コミュニケーション, 科学コミュニケーション, 研究倫理
# 研究課題数: 11
# 研究成果数: 42
# プロフィールURL: /nrid/1000080579326/
#
# --- 研究者 437 ---
# 氏名: 宮下 敬宏  MIYASHITA Takahiro
# 研究者ID: 50332771
# 所属: 株式会社国際電気通信基礎技術研究所, インタラクション科学研究所, 所長
# キーワード: 認知科学, アンドロイド, 知能ロボティクス, 遠隔操作, 知能ロボット
# 研究課題数: 10
# 研究成果数: 39
# プロフィールURL: /nrid/1000050332771/
#
# --- 研究者 438 ---
# 氏名: 佐藤 茂雄  SATO Shigeo
# 研究者ID: 10282013
# 所属: 東北大学, 電気通信研究所, 教授
# キーワード: ニューラルネットワーク, 培養神経回路, 量子ビット, ジョセフソン接合, 集積回路
# 研究課題数: 27
# 研究成果数: 416
# プロフィールURL: /nrid/1000010282013/
#
# --- 研究者 439 ---
# 氏名: 溝口 理一郎  Mizoguchi Riichiro
# 研究者ID: 20116106
# 所属: 大阪大学, 大学院 医学系研究科, 名誉教授
# キーワード: オントロジー, 知識工学, 知識ベース, 知識モデリング, 対話モデル
# 研究課題数: 59
# 研究成果数: 580
# プロフィールURL: /nrid/1000020116106/
#
# --- 研究者 440 ---
# 氏名: 尾上 弘晃  ONOE Hiroaki
# 研究者ID: 30548681
# 所属: 慶應義塾大学, 理工学部(矢上), 教授
# キーワード: マイクロ・ナノデバイス, 再生医療, マイクロマシン, ハイドロゲル, MEMS
# 研究課題数: 34
# 研究成果数: 293
# プロフィールURL: /nrid/1000030548681/
#
# --- 研究者 441 ---
# 氏名: 小西 克巳  Konishi Katsumi
# 研究者ID: 20339138
# 所属: 法政大学, 情報科学部, 教授
# キーワード: 圧縮センシング, 制御系設計, 行列ランク最小化, システム同定, 信号修復
# 研究課題数: 12
# 研究成果数: 91
# プロフィールURL: /nrid/1000020339138/
#
# --- 研究者 442 ---
# 氏名: 遠藤 俊徳  Endo Toshinori
# 研究者ID: 00323692
# 所属: 北海道大学, 情報科学研究院, 教授
# キーワード: ゲノム, 分子進化, 分子系統樹, 遺伝子機能, 機能進化
# 研究課題数: 7
# 研究成果数: 17
# プロフィールURL: /nrid/1000000323692/
#
# --- 研究者 443 ---
# 氏名: 小松崎 民樹  Komatsuzaki Tamiki
# 研究者ID: 30270549
# 所属: 北海道大学, 電子科学研究所, 教授
# キーワード: 1分子計測, 遷移状態, 情報理論, カオス力学系, 化学反応ダイナミックス
# 研究課題数: 29
# 研究成果数: 1222
# プロフィールURL: /nrid/1000030270549/
#
# --- 研究者 444 ---
# 氏名: 井上 謙一  INOUE Ken-ichi
# 研究者ID: 90455395
# 所属: 京都大学, ヒト行動進化研究センター, 助教
# キーワード: ウイルスベクター, 神経科学, 脳・神経, 霊長類, バイオテクノロジー
# 研究課題数: 28
# 研究成果数: 667
# プロフィールURL: /nrid/1000090455395/
#
# --- 研究者 445 ---
# 氏名: 角 康之  Sumi Yasuyuki
# 研究者ID: 30362578
# 所属: 公立はこだて未来大学, システム情報科学部, 教授
# キーワード: コミュニケーション支援, インタラクション, グループウェア, エージェント, 対話エージェント
# 研究課題数: 19
# 研究成果数: 339
# プロフィールURL: /nrid/1000030362578/
#
# --- 研究者 446 ---
# 氏名: 有田 隆也  ARITA Takaya
# 研究者ID: 40202759
# 所属: 名古屋大学, 情報学研究科, 特任教授
# キーワード: 人工生命, ボールドウィン効果, 遺伝的アルゴリズム, 共進化, 進化ロボティクス
# 研究課題数: 23
# 研究成果数: 337
# プロフィールURL: /nrid/1000040202759/
#
# --- 研究者 447 ---
# 氏名: 大野 和則  Ohno Kazunori
# 研究者ID: 70379486
# 所属: 東北大学, タフ・サイバーフィジカルAI研究センター, 教授
# キーワード: レスキューロボット, SLAM, センサ融合・統合, 犬, アクチュエータ
# 研究課題数: 9
# 研究成果数: 89
# プロフィールURL: /nrid/1000070379486/
#
# --- 研究者 448 ---
# 氏名: 森島 繁生  Morishima Shigeo
# 研究者ID: 10200411
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: 表情合成, メディア変換, 感性情報処理, コンピュータグラフィックス, 感情認識
# 研究課題数: 26
# 研究成果数: 233
# プロフィールURL: /nrid/1000010200411/
#
# --- 研究者 449 ---
# 氏名: 菊池 隆幸  Kikuchi Takayuki
# 研究者ID: 40625084
# 所属: 京都大学, 医学研究科, 講師
# キーワード: 皮質皮質間誘発電位, 言語, てんかん, 皮質脳波, 脳機能ネットワーク
# 研究課題数: 13
# 研究成果数: 412
# プロフィールURL: /nrid/1000040625084/
#
# --- 研究者 450 ---
# 氏名: 大脇 大  OWAKI DAI
# 研究者ID: 40551908
# 所属: 東北大学, 工学研究科, 准教授
# キーワード: 昆虫, 歩行, 脚間協調, 筋電位, Motion Hacking
# 研究課題数: 14
# 研究成果数: 189
# プロフィールURL: /nrid/1000040551908/
#
# --- 研究者 451 ---
# 氏名: 村上 郁也  Murakami Ikuya
# 研究者ID: 60396166
# 所属: 東京大学, 大学院人文社会系研究科(文学部), 教授
# キーワード: 運動視, 実験系心理学, 錯視, fMRI, 静止画が動いて見える錯視
# 研究課題数: 16
# 研究成果数: 183
# プロフィールURL: /nrid/1000060396166/
#
# --- 研究者 452 ---
# 氏名: 道上 達男  Michiue Tatsuo
# 研究者ID: 10282724
# 所属: 東京大学, 大学院総合文化研究科, 教授
# キーワード: ツメガエル, アフリカツメガエル, 細胞張力, 細胞骨格, プラコード
# 研究課題数: 16
# 研究成果数: 149
# プロフィールURL: /nrid/1000010282724/
#
# --- 研究者 453 ---
# 氏名: 杉本 昌弘  Sugimoto Masahiro
# 研究者ID: 30458963
# 所属: 慶應義塾大学, 政策・メディア研究科(藤沢), 教授
# キーワード: メタボローム, 唾液, メタボローム解析, バイオマーカー, 乳癌
# 研究課題数: 83
# 研究成果数: 300
# プロフィールURL: /nrid/1000030458963/
#
# --- 研究者 454 ---
# 氏名: 硯川 潤  Suzurikawa Jun
# 研究者ID: 50571577
# 所属: 国立障害者リハビリテーションセンター(研究所), 研究所 福祉機器開発部, 研究部長
# キーワード: 高齢者, 電動車椅子, 支援機器, ハンドル形電動車椅子, ライフログ
# 研究課題数: 17
# 研究成果数: 73
# プロフィールURL: /nrid/1000050571577/
#
# --- 研究者 455 ---
# 氏名: 吉川 信行  YOSHIKAWA Nobuyuki
# 研究者ID: 70202398
# 所属: 横浜国立大学, 先端科学高等研究院, 教授
# キーワード: 集積回路, 単一磁束量子, SFQ, 超伝導集積回路, 低消費電力
# 研究課題数: 26
# 研究成果数: 1089
# プロフィールURL: /nrid/1000070202398/
#
# --- 研究者 456 ---
# 氏名: 小林 直樹  Kobayashi Naoki
# 研究者ID: 00262155
# 所属: 東京大学, 大学院情報理工学系研究科, 教授
# キーワード: 型システム, 線形論理, デッドロック, プログラム検証, 並列言語
# 研究課題数: 26
# 研究成果数: 193
# プロフィールURL: /nrid/1000000262155/
#
# --- 研究者 457 ---
# 氏名: 梅津 高朗  UMEDU TAKAAKI
# 研究者ID: 10346174
# 所属: 滋賀大学, データサイエンス学系, 准教授
# キーワード: 車車間通信, 無線通信, 無線ネットワーク, 高度交通システム, ユビキタスネットワーク
# 研究課題数: 23
# 研究成果数: 143
# プロフィールURL: /nrid/1000010346174/
#
# --- 研究者 458 ---
# 氏名: 高里 実  TAKASATO Minoru
# 研究者ID: 40788676
# 所属: 国立研究開発法人理化学研究所, 生命機能科学研究センター, チームディレクター
# キーワード: 腎臓オルガノイド, ヒトiPS細胞, オルガノイド, 分化誘導, 1細胞解析
# 研究課題数: 9
# 研究成果数: 176
# プロフィールURL: /nrid/1000040788676/
#
# --- 研究者 459 ---
# 氏名: 重藤 真介  SHIGETO Shinsuke
# 研究者ID: 10756696
# 所属: 関西学院大学, 理学部, 教授
# キーワード: 顕微ラマン分光, 微生物生態, ナノ制限空間, 電場変調赤外分光, 水素結合
# 研究課題数: 8
# 研究成果数: 82
# プロフィールURL: /nrid/1000010756696/
#
# --- 研究者 460 ---
# 氏名: 浦山 ケビン  Urayama Kevin
# 研究者ID: 60726850
# 所属: 聖路加国際大学, 専門職大学院公衆衛生学研究科(公衆衛生大学院), 特命教授
# キーワード: 小児, 白血病, 小児AYA世代がん, 神経・認知機能, QOL
# 研究課題数: 7
# 研究成果数: 8
# プロフィールURL: /nrid/1000060726850/
#
# --- 研究者 461 ---
# 氏名: 高久 康春  Takaku Yasuharu
# 研究者ID: 60378700
# 所属: 東京農業大学, 農学部, 教授
# キーワード: 電子顕微鏡, 高真空, NanoSuit, 生きたまま, NanoSuit法
# 研究課題数: 13
# 研究成果数: 104
# プロフィールURL: /nrid/1000060378700/
#
# --- 研究者 462 ---
# 氏名: 八木 信行  YAGI NOBUYUKI
# 研究者ID: 80533992
# 所属: 東京大学, 大学院農学生命科学研究科(農学部), 教授
# キーワード: 合意形成, 生態系サービス, 国連海洋法条約, 海洋生態系サービス, マーケティング
# 研究課題数: 6
# 研究成果数: 129
# プロフィールURL: /nrid/1000080533992/
#
# --- 研究者 463 ---
# 氏名: 服部 憲明  Hattori Noriaki
# 研究者ID: 70513141
# 所属: 富山大学, 学術研究部医学系, 教授
# キーワード: リハビリテーション, 脳卒中, 機能的MRI, やる気, 片麻痺
# 研究課題数: 9
# 研究成果数: 64
# プロフィールURL: /nrid/1000070513141/
#
# --- 研究者 464 ---
# 氏名: 藤渕 航  Fujibuchi Wataru
# 研究者ID: 60273512
# 所属: 東京大学, 医学部附属病院, 特任研究員
# キーワード: バイオインフォマティクス, GPCR, 嗅覚受容体, 生体生命情報学, 化学物質
# 研究課題数: 10
# 研究成果数: 102
# プロフィールURL: /nrid/1000060273512/
#
# --- 研究者 465 ---
# 氏名: 久保 尋之  Kubo Hiroyuki
# 研究者ID: 90613951
# 所属: 千葉大学, 大学院情報学研究院, 准教授
# キーワード: コンピュータビジョン, コンピュテーショナルフォトグラフィ, コンピュータグラフィックス, コンピュテーショナルイメージング, コンピュータグラフィクス
# 研究課題数: 5
# 研究成果数: 95
# プロフィールURL: /nrid/1000090613951/
#
# --- 研究者 466 ---
# 氏名: 高島 響子  Takashima Kyoko
# 研究者ID: 10735749
# 所属: 国立健康危機管理研究機構, 臨床研究センター, 室長
# キーワード: 研究倫理, ELSI, ゲノム研究, 守秘義務, 医療倫理
# 研究課題数: 7
# 研究成果数: 82
# プロフィールURL: /nrid/1000010735749/
#
# --- 研究者 467 ---
# 氏名: 大村 廉  OMURA Ren
# 研究者ID: 10395163
# 所属: 豊橋技術科学大学, 工学(系)研究科(研究院), 准教授
# キーワード: ヒューマンロボットインタラクション, 振る舞い, 信頼関係, 視線の動き, 心理指標
# 研究課題数: 7
# 研究成果数: 73
# プロフィールURL: /nrid/1000010395163/
#
# --- 研究者 468 ---
# 氏名: 前田 真吾  Maeda Shingo
# 研究者ID: 40424808
# 所属: 東京科学大学, 工学院, 教授
# キーワード: ソフトアクチュエータ, ゲル, ゲルアクチュエータ, ソフトロボット, 自律駆動
# 研究課題数: 23
# 研究成果数: 319
# プロフィールURL: /nrid/1000040424808/
#
# --- 研究者 469 ---
# 氏名: 木村 亮介  Kimura Ryosuke
# 研究者ID: 00453712
# 所属: 琉球大学, 医学(系)研究科(研究院), 教授
# キーワード: ゲノム, 人類学, 形態, 集団遺伝学, 多型
# 研究課題数: 31
# 研究成果数: 300
# プロフィールURL: /nrid/1000000453712/
#
# --- 研究者 470 ---
# 氏名: 小西 行彦  Konishi Yukihiko
# 研究者ID: 60528157
# 所属: 香川大学, 教育学部, 准教授
# キーワード: 早産児, 低出生体重児, 発達, 生体リズム, 感覚特性
# 研究課題数: 13
# 研究成果数: 172
# プロフィールURL: /nrid/1000060528157/
#
# --- 研究者 471 ---
# 氏名: 金野 武司  Konno Takeshi
# 研究者ID: 50537058
# 所属: 金沢工業大学, 情報理工学部, 准教授
# キーワード: 実験記号論, 記号コミュニケーション, 言語進化実験, コミュニケーション, 認知科学
# 研究課題数: 11
# 研究成果数: 287
# プロフィールURL: /nrid/1000050537058/
#
# --- 研究者 472 ---
# 氏名: 山田 友幸  Yamada Tomoyuki
# 研究者ID: 40166723
# 所属: 北海道大学, 文学研究院, 名誉教授
# キーワード: 言語行為, 発話行為, 発語内行為, 動的義務論理, 証明論
# 研究課題数: 19
# 研究成果数: 63
# プロフィールURL: /nrid/1000040166723/
#
# --- 研究者 473 ---
# 氏名: 石井 秀始  Ishii Hideshi
# 研究者ID: 10280736
# 所属: 大阪大学, 大学院医学系研究科, 特任教授(常勤)
# キーワード: 癌, 癌幹細胞, 核酸, 膵がん, 再生医学
# 研究課題数: 52
# 研究成果数: 736
# プロフィールURL: /nrid/1000010280736/
#
# --- 研究者 474 ---
# 氏名: 田中 利幸  Tanaka Toshiyuki
# 研究者ID: 10254153
# 所属: 京都大学, 情報学研究科, 教授
# キーワード: 情報統計力学, 確率的情報処理, 統計力学, ベイズ統計, 情報幾何
# 研究課題数: 15
# 研究成果数: 263
# プロフィールURL: /nrid/1000010254153/
#
# --- 研究者 475 ---
# 氏名: 高田 則雄  Takata Norio
# 研究者ID: 50415212
# 所属: 慶應義塾大学, 医学部(信濃町), 講師
# キーワード: マウス, fMRI, 視床網様核, 大脳皮質, in vivo
# 研究課題数: 17
# 研究成果数: 136
# プロフィールURL: /nrid/1000050415212/
#
# --- 研究者 476 ---
# 氏名: 古川 徹生  Furukawa Tetsuo
# 研究者ID: 50219101
# 所属: 九州工業大学, 大学院生命体工学研究科, 教授
# キーワード: 網膜, シナプス, 水平細胞, 可塑性, NO
# 研究課題数: 22
# 研究成果数: 175
# プロフィールURL: /nrid/1000050219101/
#
# --- 研究者 477 ---
# 氏名: 飯高 哲也  Iidaka Tetsuya
# 研究者ID: 70324366
# 所属: 名古屋大学, 脳とこころの研究センター(保健), 教授
# キーワード: fMRI, 扁桃体, 顔認知, 脳賦活検査, 情動
# 研究課題数: 24
# 研究成果数: 138
# プロフィールURL: /nrid/1000070324366/
#
# --- 研究者 478 ---
# 氏名: 坂上 雅道  SAKAGAMI Masamichi
# 研究者ID: 10225782
# 所属: 玉川大学, 脳科学研究所, 教授
# キーワード: 前頭前野, ニホンザル, 単一ニューロン活動, 推論, 意思決定
# 研究課題数: 32
# 研究成果数: 480
# プロフィールURL: /nrid/1000010225782/
#
# --- 研究者 479 ---
# 氏名: 櫻庭 俊  Sakuraba Shun
# 研究者ID: 90647380
# 所属: 国立研究開発法人量子科学技術研究開発機構, 量子生命科学研究所, 上席研究員
# キーワード: 分子動力学, 分子動力学法, 分子動力学シミュレーション, 力場, 自由エネルギー計算
# 研究課題数: 8
# 研究成果数: 28
# プロフィールURL: /nrid/1000090647380/
#
# --- 研究者 480 ---
# 氏名: 竹井 邦晴  Takei Kuniharu
# 研究者ID: 20630833
# 所属: 北海道大学, 情報科学研究院, 教授
# キーワード: フレキシブルデバイス, フレキシブルセンサ, 印刷技術, 歪みセンサ, ナノ材料
# 研究課題数: 15
# 研究成果数: 259
# プロフィールURL: /nrid/1000020630833/
#
# --- 研究者 481 ---
# 氏名: 堅田 元喜  katata genki
# 研究者ID: 00391251
# 所属: 一般財団法人キヤノングローバル戦略研究所, エネルギー環境グループ, 主任研究員
# キーワード: 物質沈着, 酸性降下物, 植物影響, 地表面モデル, エッジ効果
# 研究課題数: 10
# 研究成果数: 110
# プロフィールURL: /nrid/1000000391251/
#
# --- 研究者 482 ---
# 氏名: 渡辺 一帆  WATANABE KAZUHO
# 研究者ID: 10506744
# 所属: 豊橋技術科学大学, 工学(系)研究科(研究院), 教授
# キーワード: レート歪み関数, 変分ベイズ法, 局所変分近似, 混合モデル, クラスタリング
# 研究課題数: 8
# 研究成果数: 162
# プロフィールURL: /nrid/1000010506744/
#
# --- 研究者 483 ---
# 氏名: 平 諭一郎  taira yuichiro
# 研究者ID: 10582819
# 所属: 東京藝術大学, 学内共同利用施設等, 准教授
# キーワード: 保存, 修復, 芸術, 現代美術, メディア・アート
# 研究課題数: 11
# 研究成果数: 60
# プロフィールURL: /nrid/1000010582819/
#
# --- 研究者 484 ---
# 氏名: 羽石 秀昭  Haneishi Hideaki
# 研究者ID: 20228521
# 所属: 千葉大学, フロンティア医工学センター, 教授
# キーワード: PET, 核医学, 画像再構成, 色再現, 画像診断
# 研究課題数: 33
# 研究成果数: 243
# プロフィールURL: /nrid/1000020228521/
#
# --- 研究者 485 ---
# 氏名: 山崎 正俊  Yamazaki Masatoshi
# 研究者ID: 30627328
# 所属: 東京大学, 先端科学技術研究センター, 特任研究員
# キーワード: 心房細動, 光学マッピング, 不整脈, 心臓電気生理学, 心室細動
# 研究課題数: 17
# 研究成果数: 181
# プロフィールURL: /nrid/1000030627328/
#
# --- 研究者 486 ---
# 氏名: 川畑 秀明  Kawabata Hideaki
# 研究者ID: 70347079
# 所属: 慶應義塾大学, 文学部(三田), 教授
# キーワード: 美, 魅力, 感性, 脳機能, fMRI
# 研究課題数: 18
# 研究成果数: 243
# プロフィールURL: /nrid/1000070347079/
#
# --- 研究者 487 ---
# 氏名: 高野 裕治  TAKANO Yuji
# 研究者ID: 00424317
# 所属: 人間環境大学, 総合心理学部, 教授
# キーワード: 認知介入, 高齢者, 運動介入, 個人差, 生活介入
# 研究課題数: 10
# 研究成果数: 7
# プロフィールURL: /nrid/1000000424317/
#
# --- 研究者 488 ---
# 氏名: 福田 憲二郎  Fukuda Kenjiro
# 研究者ID: 40613766
# 所属: 大阪大学, 大学院工学研究科, 教授
# キーワード: 有機トランジスタ, フレキシブルエレクトロニクス, 集積回路, ソフトアクチュエータ, 印刷プロセス
# 研究課題数: 9
# 研究成果数: 147
# プロフィールURL: /nrid/1000040613766/
#
# --- 研究者 489 ---
# 氏名: 駒井 武  KOMAI Takeshi
# 研究者ID: 30357024
# 所属: 東北大学, 環境科学研究科, 教授
# キーワード: スパースモデリング, 津波堆積物, リスク評価, 土壌, データ駆動
# 研究課題数: 8
# 研究成果数: 85
# プロフィールURL: /nrid/1000030357024/
#
# --- 研究者 490 ---
# 氏名: 山崎 匡  Yamazaki Tadashi
# 研究者ID: 40392162
# 所属: 電気通信大学, 大学院情報理工学研究科, 准教授
# キーワード: 小脳, シミュレーション, モデル, 学習と知識獲得, 運動学習
# 研究課題数: 12
# 研究成果数: 66
# プロフィールURL: /nrid/1000040392162/
#
# --- 研究者 491 ---
# 氏名: 高西 淳夫  TAKANISHI Atsuo
# 研究者ID: 50179462
# 所属: 早稲田大学, 理工学術院, 教授
# キーワード: ロボット, ヒューマノイド, ロボティクス, 知能ロボット, 2足歩行
# 研究課題数: 39
# 研究成果数: 276
# プロフィールURL: /nrid/1000050179462/
#
# --- 研究者 492 ---
# 氏名: 岡本 正宏  OKAMOTO Masahiro
# 研究者ID: 40211122
# 所属: 九州大学, 農学研究院, 教授
# キーワード: タンパク質, チトクロムc_3, 密度汎関数法, オブジェクト指向プログラミング, 確率オートマトン
# 研究課題数: 29
# 研究成果数: 52
# プロフィールURL: /nrid/1000040211122/
#
# --- 研究者 493 ---
# 氏名: 小野 哲雄  Ono Tetsuo
# 研究者ID: 40343389
# 所属: 京都橘大学, 工学部, 教授
# キーワード: ユーザインタフェース, 視覚障害, インタラクション, エージェント, 空間認識
# 研究課題数: 21
# 研究成果数: 134
# プロフィールURL: /nrid/1000040343389/
#
# --- 研究者 494 ---
# 氏名: 駒谷 和範  Komatani Kazunori
# 研究者ID: 40362579
# 所属: 大阪大学, 産業科学研究所, 教授
# キーワード: 音声認識, 音環境理解, 音声対話システム, 視聴覚情報統合, ロボット聴覚
# 研究課題数: 17
# 研究成果数: 412
# プロフィールURL: /nrid/1000040362579/
#
# --- 研究者 495 ---
# 氏名: 相庭 武司  aiba takeshi
# 研究者ID: 40574348
# 所属: 国立研究開発法人国立循環器病研究センター, 病院, 部長
# キーワード: 不整脈, イオンチャネル, 遺伝性不整脈, 心室細動, 突然死
# 研究課題数: 14
# 研究成果数: 110
# プロフィールURL: /nrid/1000040574348/
#
# --- 研究者 496 ---
# 氏名: 藤枝 俊宣  fujie toshinori
# 研究者ID: 70538735
# 所属: 東京科学大学, 生命理工学院, 教授
# キーワード: 高分子ナノ薄膜, ナノシート, 高分子ナノシート, 生体材料, 光線力学療法
# 研究課題数: 21
# 研究成果数: 441
# プロフィールURL: /nrid/1000070538735/
#
# --- 研究者 497 ---
# 氏名: 浅野 泰仁  Asano Yasuhito
# 研究者ID: 20361157
# 所属: 東洋大学, 情報連携学部, 教授
# キーワード: アルゴリズム, Web, グラフ, 情報検索, ネットワーク
# 研究課題数: 25
# 研究成果数: 236
# プロフィールURL: /nrid/1000020361157/
#
# --- 研究者 498 ---
# 氏名: 細野 祥之  Hosono Yasuyuki
# 研究者ID: 60820363
# 所属: 岡山大学, 医歯薬学域, 教授
# キーワード: ゼブラフィッシュ, 化合物スクリーニング, 動物モデル, 癌, 血漿タンパク
# 研究課題数: 21
# 研究成果数: 4
# プロフィールURL: /nrid/1000060820363/
#
# --- 研究者 499 ---
# 氏名: 安 ち  AN QI
# 研究者ID: 70747873
# 所属: 東京大学, 大学院新領域創成科学研究科, 准教授
# キーワード: 筋シナジー, 起立動作, リハビリテーション, 片麻痺患者, 立ち上がり動作
# 研究課題数: 16
# 研究成果数: 141
# プロフィールURL: /nrid/1000070747873/
#
# --- 研究者 500 ---
# 氏名: 舩戸 徹郎  Funato Tetsuro
# 研究者ID: 40512869
# 所属: 電気通信大学, 大学院情報理工学研究科, 准教授
# キーワード: ラット, 姿勢制御, 歩行, 筋シナジー, 小脳
# 研究課題数: 18
# 研究成果数: 332
# プロフィールURL: /nrid/1000040512869/

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="no-cache" http-equiv="Pragma">
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-store" http-equiv="Cache-Control"/>
# <meta content="must-revalidate" http-equiv="Cache-Control"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="NONE" name="ROBOTS"/>
# <meta content="NOINDEX,NOFOLLOW" name="ROBOTS"/>
# <meta content="NOARCHIVE" name="ROBOTS"/>
# <link href="/static/images/favicon_kakenhi.ico" rel="shortcut icon" type="image/vnd.microsoft.ico"/>
# <link href="/static/images/favicon_kakenhi.ico" rel="icon" type="image/vnd.microsoft.ico"/>
# <!-- Bootstrap core CSS -->
# <link href="/static/css/bootstrap-modal.css?1691548633" id="switch_style" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="/static/css/chosentree.css?1697515897" rel="stylesheet"/>
# <link href="/static/css/treeselect.css?1697515897" rel="stylesheet"/>
# <link href="/static/css/cinii.css?1735186047" rel="stylesheet"/>
# <link href="/static/css/dropzone.css?1691548633" rel="stylesheet"/>
# <link href="/static/css/font-awesome.css?1691548633" rel="stylesheet"/>
# <link href="/static/css/jquery-ui.min.css?1691548633" rel="stylesheet"/>
# <link href="/static/css/box-flex.css?1691548633" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#     <script type="text/javascript" src="/static/js/html5shiv.js?1691548633"></script>
#     <script type="text/javascript" src="/static/js/respond.min.js?1691548634"></script>
#     <![endif]-->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#     //<![CDATA[
#     var static_url="/static/";
#     var fault_mode="False";
#     //]]>
#
#     if(navigator.userAgent.match(/(iPad)/)){
#         document.write('<meta name="viewport" content="width=980">');
#     }
#     else{
#         document.write('<meta name="viewport" content="width=device-width">');
#     }
#    </script>
# <script src="/static/js/jquery.min.js?1691548633" type="text/javascript"></script>
# <script src="/static/js/common.js?1691548633" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/static/js/changeDisplayMode.js?1691548633"></script>
#  -->
# <script src="/static/js/jquery-ui.min.js?1691548633" type="text/javascript"></script>
# <script src="/static/js/search.js?1728349713" type="text/javascript"></script>
# <!--[if IE 8.0]>
#       <link href="/static/css/cinii-ie8.css?1691548633" rel="stylesheet" type="text/css" />
#     <![endif]-->
# <title>KAKEN — 研究者をさがす | 審査区分/研究分野: [審査区分:審査区分]大区分J</title>
# </meta></head>
# <body class="kakenhi grants topscreen with_sidenavi ja">
# <div id="content">
# <form action="." autoclass="form-signin" class="form-vertical" id="search" method="post"><input name="csrfmiddlewaretoken" type="hidden" value="IhlvLCuQu2nfhxA2Ahj6soiNNq124hehHZp4ewtkaOTNjGrjoBzdJHViZrB4V8MW"/>
# <input id="lang" name="lang" type="hidden" value="ja"/>
# <input id="url_lang" name="url_lang" type="hidden" value=""/>
# <nav class="navbar navbar-header">
# <div class="navbar-topcontent">
# <!--ブランド名 ロゴ名の表示-->
# <a class="navbar-brand headerlogo" href="/index/"></a>
# <!--トグルボタンの設置-->
# <button aria-controls="nav-content" aria-expanded="false" aria-label="メニュー" class="navbar-toggler button-menu collapsed" data-bs-target="#nav-content" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <button class="navbar-toggler button-search collapsed" data-bs-target="#searchbox" data-bs-toggle="collapse" type="button">
#           検索
#         </button>
# <div class="collapse navbar-collapse headermenu" id="nav-content">
# <ul class="nav navbar-nav menu-service-list btn-group">
#         　<li><a href="/index/">研究課題をさがす</a></li>
# <li class="active"><a href="/index/">研究者をさがす</a></li>
# </ul>
# <ul class="nav navbar-nav menu-kaken-use-list btn-group">
# <li><a href="/" target="_blank">KAKENの使い方</a></li>
# </ul>
# <ul class="nav navbar-nav menu-utility-list btn-group">
# <li class="menu-utility-item">
# <select class="form-control" id="langChange" name="langChange">
# <option selected="selected" value="ja">日本語</option>
# <option value="en">英語</option>
# </select>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="container body-wrap">
# <div class="searchbox lower-page" id="searchbox">
# <div class="kakenhi_search">
# <div class="searchformcontents container-fluid">
# <div class="searchboxheader col-xs-12 col-sm-3">
# <div class="col-xs-12 col-sm-12">
# </div>
# </div>
# <div class="form-tabcontent form-kakenhi col-xs-12 col-sm-9">
# <div class="col-xs-12 col-sm-6">
# <div class="row row-textform">
# <div class="col-xs-9 col-sm-9 col-form">
# <input class="main_srchterm searchforminput input_simple" id="text_kywd_0" name="kw" placeholder="フリーワード" type="text" value=""/>
# </div>
# <div class="col-xs-3 col-sm-3">
# <input class="btn searchbtn" id="search_simple" type="button" value="検索"/>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 fulltext-area">
# <div class="col-sm-11 col-sm-offset-1">
# <a class="link-page underline link_pointer" id="searchAdvanced"><i class="fa fa-chevron-right"></i> 詳細検索</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="results">
# <div id="result-wrapper">
# <div class="container">
# <p><a class="collapse-facet-toggle collapsed" data-bs-toggle="collapse" href="#collapse-facet">絞り込み条件</a></p>
# <div class="panel-collapse collapse" id="collapse-facet">
# <div id="facet-wrapper">
# <div class="facet">
# <div class="sidebar">
# <div class="facet-title hidden-xs"><i class="fa fa-filter"></i> 絞り込み</div>
# <div class="panel-default" id="facet_im">
# <h3>研究期間</h3>
# <div class="panel-body award-year">
# <div id="chart_im"></div>
# <div id="slider-wrap_im">
# <div id="slider_im"></div>
# <div class="form-inline">
# <div class="form-group"><input class="form-control" id="startYear_im" maxlength="4" type="text"/></div> - <div class="form-group"><input class="form-control" id="endYear_im" maxlength="4" type="text"/></div>
# <div class="form-group">
# <input class="btn btn-sm btn-default update year_search" id="year_search_im" type="button" value="">
# <input class="btn btn-sm btn-default clear year_clear" id="year_clear_im" type="button" value="クリア">
# </input></input></div>
# </div>
# </div>
# </div>
# </div>
# <div class="panel-default" id="facet_py">
# <h3>成果物の出版年</h3>
# <div class="panel-body award-year">
# <div id="chart_py"></div>
# <div id="slider-wrap_py">
# <div id="slider_py"></div>
# <div class="form-inline">
# <div class="form-group"><input class="form-control" id="startYear_py" maxlength="4" type="text"/></div> - <div class="form-group"><input class="form-control" id="endYear_py" maxlength="4" type="text"/></div>
# <div class="form-group">
# <input class="btn btn-sm btn-default update year_search" id="year_search_py" type="button" value="">
# <input class="btn btn-sm btn-default clear year_clear" id="year_clear_py" type="button" value="クリア">
# </input></input></div>
# </div>
# </div>
# </div>
# </div>
# <div class="panel panel-default" id="facet_in"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('in');
#  </script>
# <div class="panel panel-default" id="facet_dp"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('dp');
#  </script>
# <div class="panel panel-default" id="facet_jb"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('jb');
#  </script>
# <div class="panel panel-default" id="facet_kw"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('kw');
#  </script>
# <div class="panel panel-default" id="facet_pj"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('pj');
#  </script>
# <div class="panel panel-default" id="facet_pr"></div><!-- panel panel-default -->
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#   get_facet_data('pr');
#  </script>
# <script src="/static/js/d3.min.js?1691548633" type="text/javascript"></script>
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
#
# var margin_im = {top: 10, right: 5, bottom: 0, left: 5},
#     width_im = 255 - margin_im.left - margin_im.right,
#     height_im = 80 - margin_im.top - margin_im.bottom;
#
# var bisectYear_im = d3.bisector(function(d) { return d.year; }).left;
#
# var x_im = d3.scale.linear()
#     .range([0, width_im]);
#
# var y_im = d3.scale.linear()
#     .range([height_im, 0]);
#
# var xAxis_im = d3.svg.axis()
#     .scale(x_im)
#     .orient("bottom");
#
# var yAxis_im = d3.svg.axis()
#     .scale(y_im)
#     .orient("left");
#
# var line_im = d3.svg.line()
#     .x(function(d) { return x_im(d.year); })
#     .y(function(d) { return y_im(d.value); });
#
# var area_im = d3.svg.area()
#     .x(function(d) { return x_im(d.year); })
#     .y0(height_im)
#     .y1(function(d) { return y_im(d.value); });
#
# var tooltip_im = d3.select("#chart_im").append("div")
#     .attr("class", "tooltip")
#     .style("opacity", 1e-6);
#
# var svg_im = d3.select("#chart_im").append("svg")
#     .attr("width", width_im + margin_im.left + margin_im.right)
#     .attr("height", height_im + margin_im.top + margin_im.bottom)
#     .append("g")
#     .attr("transform", "translate(" + margin_im.left + "," + margin_im.top + ")");
#
# var cur_url_im = location.pathname;
# if (cur_url_im.indexOf("/search") > -1) {
#     cur_url_im = cur_url_im.replace(/\/search/, "/year/im");
#     if (cur_url_im.slice(-1) != "/") {
# 	    cur_url_im += "/";
# 	}
#     cur_url_im += location.search;
# }
# if (cur_url_im.indexOf("/") < 0) {
#     cur_url_im = "/" + cur_url_im;
# }
#
# d3.json(cur_url_im, function(error, data) {
# 	if (data == "-1") {
# 		$("#facet_im").addClass("hide");
# 		return false;
# 	}
#     data.forEach(function(d) {
#       d.year = d.year;
#       d.value = +d.value;
#     });
#
#     data.sort(function(a, b) {
#       return a.year - b.year;
#     });
#
#     x_im.domain([data[0].year, data[data.length - 1].year]);
#     y_im.domain([0, d3.max(data, function(d) { return d.value; })]);
#
#
#     var clip = svg_im.append("defs").append("svg:clipPath")
#         .attr("id", "clip")
#         .append("svg:rect")
#         .attr("id", "clip-rect")
#         .attr("x", "0")
#         .attr("y", "0")
#         .attr("width", width_im)
#         .attr("height", height_im);
#
#
#     svg_im.append("path")
#         .datum(data)
#         .attr("class", "line")
#         .attr("clip-path", "url(#clip)")
#         .attr("d", line_im);
#
#     svg_im.append("path")
#         .datum(data)
#         .attr("class", "area")
#         .attr("clip-path", "url(#clip)")
#         .attr("d", area_im);
#
#     var focus_im = svg_im.append("g")
#         .attr("class", "focus")
#         .style("display", "none");
#
#     focus_im.append("circle")
#         .attr("r", 4.5);
#
#     svg_im.append("rect")
#         .attr("class", "overlay")
#         .attr("width", width_im)
#         .attr("height", height_im)
#         .on("mouseover", function() {
#           focus_im.style("display", null);
#           tooltip_im.transition()
#           .duration(500)
#           .style("opacity", 1);
#         })
#         .on("mouseout", function() {
#           focus_im.style("display", "none");
#           tooltip_im.transition()
#           .duration(500)
#           .style("opacity", 1e-6);
#         })
#         .on("mousemove", mousemove_im);
#
#     function mousemove_im() {
#       var x0 = x_im.invert(d3.mouse(this)[0]),
#           i = bisectYear_im(data, x0, 1);
#
#       var d0, d1, d_im;
#       d0 = data[i - 1];
#       if (data.length > i) {
#         d1 = data[i];
#         d_im = x0 - d0.year > d1.year - x0 ? d1 : d0;
#       } else {
#       	d_im = d0;
#       }
#       focus_im.attr("transform", "translate(" + x_im(d_im.year) + "," + y_im(d_im.value) + ")");
#
#       tooltip_im.text(d_im.year + "(" + d_im.value + ")")
#       .style("left", x_im(d_im.year) + "px")
#       .style("top", y_im(d_im.value) - 25 + "px");
#     }
# });
#
# var margin_py = {top: 10, right: 5, bottom: 0, left: 5},
#     width_py = 255 - margin_py.left - margin_py.right,
#     height_py = 80 - margin_py.top - margin_py.bottom;
#
# var bisectYear_py = d3.bisector(function(d) { return d.year; }).left;
#
# var x_py = d3.scale.linear()
#     .range([0, width_py]);
#
# var y_py = d3.scale.linear()
#     .range([height_py, 0]);
#
# var xAxis_py = d3.svg.axis()
#     .scale(x_py)
#     .orient("bottom");
#
# var yAxis_py = d3.svg.axis()
#     .scale(y_py)
#     .orient("left");
#
# var line_py = d3.svg.line()
#     .x(function(d) { return x_py(d.year); })
#     .y(function(d) { return y_py(d.value); });
#
# var area_py = d3.svg.area()
#     .x(function(d) { return x_py(d.year); })
#     .y0(height_py)
#     .y1(function(d) { return y_py(d.value); });
#
# var tooltip_py = d3.select("#chart_py").append("div")
#     .attr("class", "tooltip")
#     .style("opacity", 1e-6);
#
# var svg_py = d3.select("#chart_py").append("svg")
#     .attr("width", width_py + margin_py.left + margin_py.right)
#     .attr("height", height_py + margin_py.top + margin_py.bottom)
#     .append("g")
#     .attr("transform", "translate(" + margin_py.left + "," + margin_py.top + ")");
#
# var cur_url_py = location.pathname;
# if (cur_url_py.indexOf("/search") > -1) {
#     cur_url_py = cur_url_py.replace(/\/search/, "/year/py");
#     if (cur_url_py.slice(-1) != "/") {
# 	    cur_url_py += "/";
# 	}
#     cur_url_py += location.search;
# }
# if (cur_url_py.indexOf("/") < 0) {
#     cur_url_py = "/" + cur_url_py;
# }
#
# d3.json(cur_url_py, function(error, data) {
# 	if (data == "-1") {
# 		$("#facet_py").addClass("hide");
# 		return false;
# 	}
#     data.forEach(function(d) {
#       d.year = d.year;
#       d.value = +d.value;
#     });
#
#     data.sort(function(a, b) {
#       return a.year - b.year;
#     });
#
#     x_py.domain([data[0].year, data[data.length - 1].year]);
#     y_py.domain([0, d3.max(data, function(d) { return d.value; })]);
#
#
#     var clip = svg_py.append("defs").append("svg:clipPath")
#         .attr("id", "clip")
#         .append("svg:rect")
#         .attr("id", "clip-rect")
#         .attr("x", "0")
#         .attr("y", "0")
#         .attr("width", width_py)
#         .attr("height", height_py);
#
#
#     svg_py.append("path")
#         .datum(data)
#         .attr("class", "line")
#         .attr("clip-path", "url(#clip)")
#         .attr("d", line_py);
#
#     svg_py.append("path")
#         .datum(data)
#         .attr("class", "area")
#         .attr("clip-path", "url(#clip)")
#         .attr("d", area_py);
#
#     var focus_py = svg_py.append("g")
#         .attr("class", "focus")
#         .style("display", "none");
#
#     focus_py.append("circle")
#         .attr("r", 4.5);
#
#     svg_py.append("rect")
#         .attr("class", "overlay")
#         .attr("width", width_py)
#         .attr("height", height_py)
#         .on("mouseover", function() {
#           focus_py.style("display", null);
#           tooltip_py.transition()
#           .duration(500)
#           .style("opacity", 1);
#         })
#         .on("mouseout", function() {
#           focus_py.style("display", "none");
#           tooltip_py.transition()
#           .duration(500)
#           .style("opacity", 1e-6);
#         })
#         .on("mousemove", mousemove_py);
#
#     function mousemove_py() {
#       var x0 = x_py.invert(d3.mouse(this)[0]),
#           i = bisectYear_py(data, x0, 1);
#
#       var d0, d1, d_py;
#       d0 = data[i - 1];
#       if (data.length > i) {
#         d1 = data[i];
#         d_py = x0 - d0.year > d1.year - x0 ? d1 : d0;
#       } else {
#       	d_py = d0;
#       }
#       focus_py.attr("transform", "translate(" + x_py(d_py.year) + "," + y_py(d_py.value) + ")");
#
#       tooltip_py.text(d_py.year + "(" + d_py.value + ")")
#       .style("left", x_py(d_py.year) + "px")
#       .style("top", y_py(d_py.value) - 25 + "px");
#     }
# });
#
# // slider
# $(function() {
#
#   $.getJSON(cur_url_im,function(data){
#
#     var startYear = Number(data[0].year),
#         endYear = Number(data[data.length-1].year);
#
#     $("#startYear_im").val(startYear);
#     $("#endYear_im").val(endYear);
#
#     $( "#slider_im" ).slider({
#       range: true,
#       min: startYear,
#       max: endYear,
#       values: [startYear,endYear],
#       slide: function( event, ui ) {
#
#         var maxv = d3.min([ui.values[1], data.length]);
#         var minv = d3.max([ui.values[0], 0]);
#
#         x_im.domain([ui.values[0], ui.values[1]]);
#
#         svg_im.transition().duration(750)
#         .select(".area").attr("d", area_im);
#
#         svg_im.transition().duration(750)
#         .select(".focus").attr("d", line_im(data));
#
#         svg_im.transition().duration(750)
#         .select(".line").attr("d", line_im(data));
#
#         // facet search
#         search_im(ui.values[0],ui.values[1]);
#
#       }
#     });
#   });
#
#   $.getJSON(cur_url_py,function(data){
#
#     var startYear = Number(data[0].year),
#         endYear = Number(data[data.length-1].year);
#
#     $("#startYear_py").val(startYear);
#     $("#endYear_py").val(endYear);
#
#     $( "#slider_py" ).slider({
#       range: true,
#       min: startYear,
#       max: endYear,
#       values: [startYear,endYear],
#       slide: function( event, ui ) {
#
#         var maxv = d3.min([ui.values[1], data.length]);
#         var minv = d3.max([ui.values[0], 0]);
#
#         x_py.domain([ui.values[0], ui.values[1]]);
#
#         svg_py.transition().duration(750)
#         .select(".area").attr("d", area_py);
#
#         svg_py.transition().duration(750)
#         .select(".focus").attr("d", line_py(data));
#
#         svg_py.transition().duration(750)
#         .select(".line").attr("d", line_py(data));
#
#         // facet search
#         search_py(ui.values[0],ui.values[1]);
#
#       }
#     });
#   });
#
# });
#
# function search_im(start,end){
#   $("#startYear_im").val(start);
#   $("#endYear_im").val(end);
# }
#
# function search_py(start,end){
#   $("#startYear_py").val(start);
#   $("#endYear_py").val(end);
# }
#
# </script>
# </div><!-- .sidebar -->
# </div><!-- .facet -->
# </div><!-- #facet-wrapper -->
# </div>
# <div id="result-list">
# <div class="listings">
# <div class="block-info clearfix">
# <p class="search-term-selected">検索結果: 237件 / 審査区分/研究分野: [審査区分:審査区分]大区分J</p>
# <div class="pagenumber">
# </div><!-- .pagenumber -->
# <div class="pull-left pagenumber">
# <input class="checkAll" id="chk_group" type="checkbox"/>
# <select class="form-control choice_type" id="ct" name="ct">
# <option selected="selected" value="all">すべて選択</option>
# <option value="page">ページ内選択</option>
# </select>
# <select class="form-control output_type" id="ot" name="ot">
# <option value="json">JSONで出力</option>
# <option value="csv">テキスト(CSV)で出力</option>
# </select>
# <input class="btn file_btn" id="file_btn" type="button" value="実行">
# <input id="is_over" type="hidden" value="0"/>
# <input id="max_file_msg" type="hidden" value=""/>
# </input></div><!-- .pull-left .pagenumber -->
# <div class="pull-left pageinfo">
# <strong>表示件数: </strong>
# <select class="form-control" id="rw" name="rw">
# <option value="20">20</option>
# <option value="50">50</option>
# <option value="100">100</option>
# <option value="200">200</option>
# <option selected="selected" value="500">500</option>
# </select>
# </div>
# <div class="pull-right">
# <select class="form-control" id="od" name="od">
# <option value="1">適合度</option>
# <option value="2">カナ: 昇順</option>
# <option value="3">カナ: 降順</option>
# <option value="4">アルファベット: 昇順</option>
# <option value="5">アルファベット: 降順</option>
# <option value="6">研究課題数: 昇順</option>
# <option selected="selected" value="7">研究課題数: 降順</option>
# </select>
# </div>
# </div><!-- block-info clearfix -->
# <div class="listContainer">
# <ul>
# <li>
# <div class="listitem xfolkentry">
# <h3 class="item_mainTitle">
# <div class="title">
# <input class="chk_group" id="chk_40156716" name="chk[]" type="checkbox" value="40156716"/>
# <span class="row-number"> 1. </span><i class="fa fa-user"></i> <a class="link-page" href="/nrid/1000040156716/">廣瀬 通孝<span class="subTitle">  Hirose Michitaka  (40156716)</span></a>
# </div>
# </h3>
# <table class="summary-table">
# <tr>
# <th>所属 (現在)</th>
# <td>
#
#                        東京工科大学, 片柳研究所, 教授
#                        <br/>
#                        東京大学, 先端科学技術研究センター, 名誉教授
#
#                        </td>
# </tr>
# <tr>
# <th>審査区分/研究分野</th>
# <td>
# <a class="link-page underline" href="/search/?qd=%5B%E7%A0%94%E7%A9%B6%E5%88%86%E9%87%8E%3A%E7%B4%B0%E7%9B%AE%5D%E7%B7%8F%E5%90%88%E3%83%BB%E6%96%B0%E9%A0%98%E5%9F%9F%E7%B3%BB/%E7%B7%8F%E5%90%88%E9%A0%98%E5%9F%9F/%E6%83%85%E5%A0%B1%E5%AD%A6/%E3%83%A1%E3%83%87%E3%82%A3%E3%82%A2%E6%83%85%E5%A0%B1%E5%AD%A6%E3%83%BB%E3%83%87%E3%83%BC%E3%82%BF%E3%83%99%E3%83%BC%E3%82%B9">メディア情報学・データベース</a> /
#
#                           <a class="link-page underline" href="/search/?qd=%5B%E7%A0%94%E7%A9%B6%E5%88%86%E9%87%8E%3A%E7%B4%B0%E7%9B%AE%5D%E7%B7%8F%E5%90%88%E7%B3%BB/%E6%83%85%E5%A0%B1%E5%AD%A6/%E4%BA%BA%E9%96%93%E6%83%85%E5%A0%B1%E5%AD%A6/%E3%83%92%E3%83%A5%E3%83%BC%E3%83%9E%E3%83%B3%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%95%E3%82%A7%E3%83%BC%E3%82%B9%E3%83%BB%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%A9%E3%82%AF%E3%82%B7%E3%83%A7%E3%83%B3">ヒューマンインタフェース・インタラクション</a> /
#
#                           <a class="link-page underline" href="/search/?qd=%5B%E5%AF%A9%E6%9F%BB%E5%8C%BA%E5%88%86%3A%E5%AF%A9%E6%9F%BB%E5%B8%8C%E6%9C%9B%E9%83%A8%E9%96%80%28%E7%89%B9%E5%AE%9A%E9%A0%98%E5%9F%9F%E7%A0%94%E7%A9%B6%29%5D%E7%90%86%E5%B7%A5%E7%B3%BB">理工系</a> /
#
#                           <a class="link-page underline" href="/search/?qd=%5B%E7%A0%94%E7%A9%B6%E5%88%86%E9%87%8E%3A%E7%B4%B0%E7%9B%AE%5D%E5
E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF">敵対的生成ネットワーク</a></td>
# </tr>
# <tr>
# <th>研究課題数</th>
# <td>1</td>
# </tr>
# </table>
# </div><!-- .listitem xfolkentry -->
# </li>
# </ul>
# </div><!-- .listContainer -->
# </div><!-- .listings -->
# </div><!-- #result-list -->
# </div><!-- .container -->
# </div><!-- #result-wrapper -->
# </div><!-- #results -->
# </div><!-- .body-wrap -->
# <input name="st" type="hidden" value="1"/>
# <input name="rw" type="hidden" value="500"/>
# </form>
# </div><!-- #content -->
# <div class="footer">
# <div class="footer-wrap">
# <div class="row">
# <div class="col-sm-8 col-xs-12">
# <p class="footer-links">
# <a class="win_open active" href="https://support.nii.ac.jp/kaken/">サービス概要</a>
# <a class="win_open" href="https://support.nii.ac.jp/kaken/researcher_quicksearch">検索マニュアル</a>
# <a class="win_open" href="https://support.nii.ac.jp/kaken/faq/general">よくある質問</a>
# <a class="win_open" href="https://support.nii.ac.jp/news/kaken">お知らせ</a>
# <a class="win_open" href="https://support.nii.ac.jp/kaken/about/terms">利用規程</a>
# <a class="win_open" href="https://support.nii.ac.jp/kaken/kakenhi">科研費による研究の帰属</a>
# </p>
# </div>
# <div class="col-sm-4 col-xs-12">
# <a class="pull-right" href="https://www.nii.ac.jp/" target="_blank"><strong>Powered by NII</strong></a>
# <a class="pull-right kakenhi-footer-logo" href="https://www.jsps.go.jp/" target="_blank"><img alt="kakenhi" class="kakenhi logo" height="43" src="/static/images/kaken_footer_logo_ja.png" width="100"/></a>
# </div>
# </div>
# </div>
# </div>
# <!-- Bootstrap core JavaScript
# ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <script src="/static/bootstrap/js/bootstrap.min.js?1697515897" type="text/javascript"></script>
# <script src="/static/js/jquery.flot.js?1691548633" type="text/javascript"></script>
# <script src="/static/js/dropzone.js?1691548633" type="text/javascript"></script>
# <script nonce="sV1wkYqNLCdoQLCPuJ9hug==" type="text/javascript">
# //<![CDATA[
# $(function() {
#     $(".checkAll").on("change", function() {
#         $("." + this.id).prop("checked", this.checked);
#         if ($(".chk_group:checked").length == 0) {
#         	$("#file_btn").addClass("invisible");
#         } else {
#         	$("#file_btn").removeClass("invisible");
#         }
#     });
#
#     $(".chk_group").on("change", function() {
# 		if ($(".chk_group:checked").length == 0) {
#         	$("#file_btn").addClass("invisible");
#         } else {
#         	$("#file_btn").removeClass("invisible");
#         }
#     });
#
#     if ($("select[name=ct]").val() == 'all') {
# 		$(".chk_group").prop('checked', false);
# 		$(".checkAll").prop('checked', false);
# 		$(".chk_group").prop("disabled", true);
# 		$(".checkAll").prop("disabled", true);
# 		$("#file_btn").removeClass("invisible");
#     }
#
#     $("#ct").on("change", function() {
#     	if ($("select[name=ct]").val() == 'all') {
#     		$(".chk_group").prop('checked', false);
#     		$(".checkAll").prop('checked', false);
#     		$(".chk_group").prop("disabled", true);
#     		$(".checkAll").prop("disabled", true);
#     		$("#file_btn").removeClass("invisible");
# 	    } else {
# 	        $(".chk_group").prop("disabled", false);
# 	        $(".checkAll").prop("disabled", false);
# 	        if ($(".chk_group:checked").length == 0) {
# 	        	$("#file_btn").addClass("invisible");
# 	        }
# 	    }
#     });
# });
# //]]>
# </script>
# </body>
# </html>

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -----------
# absl-py                                  2.1.0
# aiohttp                                  3.9.4
# aiosignal                                1.3.1
# annotated-types                          0.6.0
# anyio                                    4.3.0
# appnope                                  0.1.4
# asgiref                                  3.8.1
# asttokens                                2.4.1
# astunparse                               1.6.3
# attrs                                    23.2.0
# backoff                                  2.2.1
# bcrypt                                   4.1.2
# build                                    1.2.1
# cachetools                               5.3.3
# certifi                                  2025.1.31
# charset-normalizer                       3.4.1
# chroma-hnswlib                           0.7.3
# chromadb                                 0.4.24
# click                                    8.1.7
# coloredlogs                              15.0.1
# comm                                     0.2.2
# contourpy                                1.3.1
# cycler                                   0.12.1
# dataclasses-json                         0.6.4
# debugpy                                  1.8.1
# decorator                                5.1.1
# Deprecated                               1.2.14
# distro                                   1.9.0
# et-xmlfile                               1.1.0
# executing                                2.0.1
# faiss-cpu                                1.8.0
# fastapi                                  0.110.1
# filelock                                 3.17.0
# flatbuffers                              24.3.25
# fonttools                                4.56.0
# frozenlist                               1.4.1
# fsspec                                   2025.2.0
# gast                                     0.6.0
# google-auth                              2.29.0
# google-pasta                             0.2.0
# googleapis-common-protos                 1.63.0
# GPUtil                                   1.4.0
# grandalf                                 0.8
# grpcio                                   1.70.0
# h11                                      0.14.0
# h5py                                     3.12.1
# httpcore                                 1.0.5
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.29.1
# humanfriendly                            10.0
# idna                                     3.10
# importlib-metadata                       7.0.0
# importlib_resources                      6.4.0
# ipykernel                                6.29.4
# ipython                                  8.23.0
# ipywidgets                               8.1.2
# Janome                                   0.5.0
# jedi                                     0.19.1
# Jinja2                                   3.1.5
# joblib                                   1.4.2
# jsonpatch                                1.33
# jsonpointer                              2.4
# jupyter_client                           8.6.1
# jupyter_core                             5.7.2
# jupyterlab_widgets                       3.0.10
# keras                                    3.8.0
# kiwisolver                               1.4.8
# kubernetes                               29.0.0
# langchain                                0.1.16
# langchain-community                      0.0.32
# langchain-core                           0.1.52
# langchain-openai                         0.1.3
# langchain-text-splitters                 0.0.1
# langgraph                                0.0.49
# langsmith                                0.1.45
# Levenshtein                              0.26.1
# libclang                                 18.1.1
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               3.0.2
# marshmallow                              3.21.1
# matplotlib                               3.10.0
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mecab-python3                            1.0.8
# ml-dtypes                                0.4.1
# mmh3                                     4.1.0
# monotonic                                1.6
# mpmath                                   1.3.0
# multidict                                6.0.5
# mypy-extensions                          1.0.0
# namex                                    0.0.8
# narwhals                                 1.27.1
# nest-asyncio                             1.6.0
# networkx                                 3.4.2
# numpy                                    1.26.4
# oauthlib                                 3.2.2
# ompr                                     1.3.0
# onnxruntime                              1.17.3
# openai                                   1.17.0
# openpyxl                                 3.1.2
# opentelemetry-api                        1.24.0
# opentelemetry-exporter-otlp-proto-common 1.24.0
# opentelemetry-exporter-otlp-proto-grpc   1.24.0
# opentelemetry-instrumentation            0.45b0
# opentelemetry-instrumentation-asgi       0.45b0
# opentelemetry-instrumentation-fastapi    0.45b0
# opentelemetry-proto                      1.24.0
# opentelemetry-sdk                        1.24.0
# opentelemetry-semantic-conventions       0.45b0
# opentelemetry-util-http                  0.45b0
# opt_einsum                               3.4.0
# optree                                   0.14.0
# orjson                                   3.10.0
# overrides                                7.7.0
# packaging                                24.2
# pandas                                   2.2.3
# parso                                    0.8.4
# pexpect                                  4.9.0
# pillow                                   11.1.0
# pip                                      24.0
# plac                                     1.4.3
# platformdirs                             4.2.0
# plotly                                   6.0.0
# posthog                                  3.5.0
# prompt-toolkit                           3.0.43
# protobuf                                 5.29.3
# psutil                                   7.0.0
# ptyprocess                               0.7.0
# pulsar-client                            3.4.0
# pure-eval                                0.2.2
# pyasn1                                   0.6.0
# pyasn1_modules                           0.4.0
# pydantic                                 2.7.0
# pydantic_core                            2.18.1
# Pygments                                 2.17.2
# pypaq                                    1.7.1
# pyparsing                                3.2.1
# pypdf                                    4.2.0
# PyPika                                   0.48.9
# PyPokerEngine                            1.0.1
# pyproject_hooks                          1.0.0
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.0.1
# pytz                                     2025.1
# PyYAML                                   6.0.1
# pyzmq                                    25.1.2
# RapidFuzz                                3.12.1
# regex                                    2024.11.6
# requests                                 2.32.3
# requests-oauthlib                        2.0.0
# rich                                     13.7.1
# rsa                                      4.9
# safetensors                              0.5.2
# scikit-learn                             1.6.1
# scipy                                    1.15.2
# seaborn                                  0.13.2
# sentence-transformers                    3.4.1
# setuptools                               75.8.0
# shellingham                              1.5.4
# six                                      1.17.0
# sniffio                                  1.3.1
# SQLAlchemy                               2.0.29
# stack-data                               0.6.3
# starlette                                0.37.2
# sympy                                    1.13.3
# tenacity                                 8.2.3
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.18.0
# tensorflow-io-gcs-filesystem             0.37.1
# termcolor                                2.5.0
# threadpoolctl                            3.5.0
# tiktoken                                 0.6.0
# tokenizers                               0.21.0
# torch                                    2.2.1
# torchness                                1.3.1
# tornado                                  6.4
# tqdm                                     4.66.2
# traitlets                                5.14.2
# transformers                             4.49.0
# typer                                    0.12.3
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# tzdata                                   2025.1
# unidic                                   1.1.0
# unidic-lite                              1.0.8
# urllib3                                  2.3.0
# uvicorn                                  0.29.0
# uvloop                                   0.19.0
# wasabi                                   0.10.1
# watchfiles                               0.21.0
# wcwidth                                  0.2.13
# websocket-client                         1.7.0
# websockets                               12.0
# Werkzeug                                 3.1.3
# wheel                                    0.45.1
# widgetsnbextension                       4.0.10
# wrapt                                    1.16.0
# yarl                                     1.9.4
# zipp                                     3.18.1
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
